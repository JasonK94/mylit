# %% [markdown]
# # Utility

# %%
import os

def add_suffix_to_filename(file_path, suffix):
  """
  파일 경로의 확장자를 유지하면서 파일명에 접미사를 추가합니다.

  Args:
    file_path (str): 원본 파일 경로
    suffix (str): 파일명에 추가할 문자열

  Returns:
    str: 파일명이 변경된 새로운 파일 경로
  """
  # 1. 파일 경로를 파일명(루트)과 확장자로 분리
  # 예: "/path/to/document.txt" -> ("/path/to/document", ".txt")
  name_without_ext, extension = os.path.splitext(file_path)

  # 2. 파일명에 원하는 문자열 추가
  new_name_without_ext = name_without_ext + suffix

  # 3. 새로운 파일명과 확장자를 다시 합침
  new_file_path = new_name_without_ext + extension
  
  return new_file_path

# --- 사용 예시 ---
original_path = "/Users/test/documents/report.pdf"
suffix_to_add = "_final"

new_path = add_suffix_to_filename(original_path, suffix_to_add)

print(new_path)
# Out:
# /Users/test/documents/report_final.pdf

# %% [markdown]
# # Matrix Handler

# %% [markdown]
# ## Matrix 추출, CSV 변환

# %% [markdown]
# ### 함수정의부

# %%
import pandas as pd
import os

def convert_and_rename_xlsx_to_csv(folder_path):
    """
    XLSX 파일을 읽어 AOI 컬럼명을 고유하게 변경한 후 CSV로 저장합니다.
    """
    # CSV 파일들을 저장할 하위 폴더 생성
    csv_output_folder = os.path.join(folder_path, "csv_files_unique_names")
    os.makedirs(csv_output_folder, exist_ok=True)
    
    all_files = os.listdir(folder_path)
    xlsx_files = [f for f in all_files if f.endswith('.xlsx')]

    # 모든 파일에 공통으로 존재하는 기준 컬럼들
    base_cols = [
        'ProbeName', 'ProbeDisplayName', 'TargetName', 'HUGOSymbol', 
        'Accessions', 'GenomeBuild', 'GenomicPosition', 'AnalyteType', 
        'CodeClass', 'ProbePool', 'TargetGroup', 'GeneID'
    ]

    print(f"총 {len(xlsx_files)}개의 XLSX 파일을 CSV로 변환 및 컬럼명 변경 작업을 시작합니다...")
    for i, file in enumerate(xlsx_files):
        try:
            file_path = os.path.join(folder_path, file)
            df = pd.read_excel(file_path, sheet_name="BioProbeCountMatrix", engine='openpyxl')
            
            # 파일명을 기반으로 접두사(prefix) 생성 (확장자 제외)
            file_prefix = os.path.splitext(file)[0]
            
            # AOI 컬럼들 (base_cols에 속하지 않는 모든 컬럼)
            aoi_cols = [col for col in df.columns if col not in base_cols]
            
            # 새로운 컬럼명을 담을 딕셔너리 생성
            # 예: {'기존AOI_1': '파일명_기존AOI_1', '기존AOI_2': '파일명_기존AOI_2'}
            rename_dict = {col: f"{file_prefix}_{col}" for col in aoi_cols}
            
            # 컬럼명 변경 적용
            df.rename(columns=rename_dict, inplace=True)
            
            # CSV로 저장
            csv_filename = f"{file_prefix}.csv"
            df.to_csv(os.path.join(csv_output_folder, csv_filename), index=False)
            
            print(f"({i+1}/{len(xlsx_files)}) '{file}' -> '{csv_filename}' 변환 완료.")
        except Exception as e:
            print(f"'{file}' 처리 중 오류: {e}")
            
    print(f"\n✅ 작업 완료! 고유한 컬럼명을 가진 CSV 파일들이 '{csv_output_folder}' 폴더에 저장되었습니다.")

# %% [markdown]
# ### Claude style

# %% [markdown]
# #### utilities and configurations

# %%
import pandas as pd
import os
import warnings
from openpyxl import load_workbook
# 하위 폴더 이름 설정
subfolder_name="csv_files_1"

# warning 억제
warnings.filterwarnings('ignore', category=UserWarning, module='openpyxl')

# 설정값들
BASE_COLUMNS = [
    'ProbeName', 'ProbeDisplayName', 'TargetName', 'HUGOSymbol', 
    'Accessions', 'GenomeBuild', 'GenomicPosition', 'AnalyteType', 
    'CodeClass', 'ProbePool', 'TargetGroup', 'GeneID'
]

def get_excel_files(folder_path):
    """폴더에서 xlsx 파일들 찾기"""
    all_files = os.listdir(folder_path)
    return [f for f in all_files if f.endswith('.xlsx')]

def create_output_folder(folder_path):
    """CSV 파일 저장할 폴더 생성"""
    csv_output_folder = os.path.join(folder_path, subfolder_name)
    os.makedirs(csv_output_folder, exist_ok=True)
    return csv_output_folder

def has_target_sheet(file_path, sheet_name="BioProbeCountMatrix"):
    """시트 존재 여부를 빠르게 확인"""
    try:
        wb = load_workbook(file_path, read_only=True, data_only=True)
        result = sheet_name in wb.sheetnames
        wb.close()
        return result
    except Exception:
        return False

def process_single_file(file_path, file_prefix):
    """단일 파일 처리하여 DataFrame 반환"""
    # 파일 읽기 (read_only=True로 속도 향상)
    df = pd.read_excel(file_path, sheet_name="BioProbeCountMatrix", engine='openpyxl')
    
    # AOI 컬럼들 찾기 (기본 컬럼이 아닌 것들)
    aoi_cols = [col for col in df.columns if col not in BASE_COLUMNS]
    
    # 컬럼명 변경 (파일명_컬럼명)
    rename_dict = {col: f"{file_prefix}_{col}" for col in aoi_cols}
    df.rename(columns=rename_dict, inplace=True)
    
    return df, len(aoi_cols)

# %% [markdown]
# #### main function

# %%
def convert_xlsx_to_csv(folder_path):
    """XLSX 파일들을 CSV로 변환하는 메인 함수"""
    
    # Excel 파일들 찾기
    xlsx_files = get_excel_files(folder_path)
    if not xlsx_files:
        print("❌ XLSX 파일을 찾을 수 없습니다!")
        return
    
    # 출력 폴더 생성
    csv_output_folder = create_output_folder(folder_path)
    
    print(f"📁 총 {len(xlsx_files)}개의 XLSX 파일을 처리합니다...")
    
    # 각 파일 처리
    success_count = 0
    skip_count = 0
    
    for i, file in enumerate(xlsx_files):
        file_path = os.path.join(folder_path, file)
        file_prefix = os.path.splitext(file)[0]  # 확장자 제거
        
        # 먼저 시트 존재 여부 빠르게 확인
        if not has_target_sheet(file_path):
            skip_count += 1
            print(f"⏭️  ({i+1}/{len(xlsx_files)}) {file} - BioProbeCountMatrix 시트 없음, 건너뛰기")
            continue
        
        try:
            # 파일 처리
            df, aoi_count = process_single_file(file_path, file_prefix)
            
            # CSV로 저장
            csv_filename = f"{file_prefix}.csv"
            df.to_csv(os.path.join(csv_output_folder, csv_filename), index=False)
            
            success_count += 1
            print(f"✅ ({i+1}/{len(xlsx_files)}) {file} → {csv_filename} (AOI 컬럼 {aoi_count}개)")
            
        except Exception as e:
            print(f"❌ ({i+1}/{len(xlsx_files)}) {file} 처리 실패: {e}")
    
    print(f"\n🎉 완료! {success_count}개 변환, {skip_count}개 건너뛰기 (총 {len(xlsx_files)}개)")
    print(f"   결과는 '{csv_output_folder}' 폴더에 저장되었습니다.")

# %% [markdown]
# ### 변수정의

# %%
target_folder="/data/kjc1/projects/#999.GeoMxmeta/pooled"

# %% [markdown]
# ### 실행

# %%
convert_and_rename_xlsx_to_csv(target_folder)
# Claude style
# Out:
# 총 114개의 XLSX 파일을 CSV로 변환 및 컬럼명 변경 작업을 시작합니다...
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (1/114) 'DKD_20240125.xlsx' -> 'DKD_20240125.csv' 변환 완료.
# 't4p.xlsx' 처리 중 오류: Worksheet named 'BioProbeCountMatrix' not found
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (3/114) '#124_mIBD_biologics_95AOI.xlsx' -> '#124_mIBD_biologics_95AOI.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (4/114) 'e.xlsx' -> 'e.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (5/114) 'PC_multi_250219.xlsx' -> 'PC_multi_250219.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (6/114) '#124_mIBD_bologics_44AOI.xlsx' -> '#124_mIBD_bologics_44AOI.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (7/114) 'Kidney TPL_GeoMx_R1.xlsx' -> 'Kidney TPL_GeoMx_R1.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (8/114) '#377 Ari_ILC_mo.xlsx' -> '#377 Ari_ILC_mo.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (9/114) 'Keloid_LYI_4mm_20240528.xlsx' -> 'Keloid_LYI_4mm_20240528.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (10/114) '#377 ILC_Ari_Revision.xlsx' -> '#377 ILC_Ari_Revision.csv' 변환 완료.
# '(empty)BK melanoma.xlsx' 처리 중 오류: Worksheet named 'BioProbeCountMatrix' not found
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (12/114) 'CRC(2).xlsx' -> 'CRC(2).csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (13/114) 'NHS.xlsx' -> 'NHS.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (14/114) '(not aligned)20221207 bk,yk melanoma.xlsx' -> '(not aligned)20221207 bk,yk melanoma.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (15/114) 'IgAN_KMJ_BYJ_final.xlsx' -> 'IgAN_KMJ_BYJ_final.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (16/114) '22.12.08 GeoMx Analysis(2).xlsx' -> '22.12.08 GeoMx Analysis(2).csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (17/114) 'Kidney TPL_GeoMx_R2.xlsx' -> 'Kidney TPL_GeoMx_R2.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (18/114) '23.01.06(2) HCC.xlsx' -> '23.01.06(2) HCC.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (19/114) 'Final Thymus normal.xlsx' -> 'Final Thymus normal.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (20/114) '23.01.06_HY GeoMx analysis.xlsx' -> '23.01.06_HY GeoMx analysis.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (21/114) 'MN_A1.2.3.4_B1.2.xlsx' -> 'MN_A1.2.3.4_B1.2.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (22/114) '23.06.27 HCC2 vs HCC.x.xlsx' -> '23.06.27 HCC2 vs HCC.x.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (23/114) 'Koh_Breast cancer.xlsx' -> 'Koh_Breast cancer.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (24/114) '24.06.04 HCC final_GW2.xlsx' -> '24.06.04 HCC final_GW2.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (25/114) 'KSJ2.xlsx' -> 'KSJ2.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (26/114) 'TA3815.xlsx' -> 'TA3815.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (27/114) '307 Breast cancer.xlsx' -> '307 Breast cancer.csv' 변환 완료.
# '0408-2.xlsx' 처리 중 오류: Worksheet named 'BioProbeCountMatrix' not found
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (29/114) 'KT2_NEW_20230419.xlsx' -> 'KT2_NEW_20230419.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (30/114) '220905_AA Analysis_SHY.xlsx' -> '220905_AA Analysis_SHY.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (31/114) 'KSJ.xlsx' -> 'KSJ.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (32/114) 'TA3814.xlsx' -> 'TA3814.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (33/114) '221226_AA GeoMx_SHY.xlsx' -> '221226_AA GeoMx_SHY.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (34/114) 'GeoMx_Thuy,HY.xlsx' -> 'GeoMx_Thuy,HY.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (35/114) 'TA3854.xlsx' -> 'TA3854.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (36/114) '240708_TMA_Halo_nevus_FINAL.xlsx' -> '240708_TMA_Halo_nevus_FINAL.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (37/114) 'IFTA_250121_NEW_except1patient.xlsx' -> 'IFTA_250121_NEW_except1patient.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (38/114) '250114_TCR add on_final.xlsx' -> '250114_TCR add on_final.csv' 변환 완료.
# '20210315 analysis.xlsx' 처리 중 오류: Worksheet named 'BioProbeCountMatrix' not found
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (40/114) 'Lupus Nephritis2_202302224.xlsx' -> 'Lupus Nephritis2_202302224.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (41/114) '20220729 Th2 Psoriasis.xlsx' -> '20220729 Th2 Psoriasis.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (42/114) 'IgAN_KMJ_BYJ_20221004.xlsx' -> 'IgAN_KMJ_BYJ_20221004.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (43/114) '20220807 JSY HS analysis.xlsx' -> '20220807 JSY HS analysis.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (44/114) 'IFTA_20241028.xlsx' -> 'IFTA_20241028.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (45/114) 'TA3855.xlsx' -> 'TA3855.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (46/114) '20221207 melanoma_bk,yk final.xlsx' -> '20221207 melanoma_bk,yk final.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (47/114) 'JHK_Sebaceous carinoma.xlsx' -> 'JHK_Sebaceous carinoma.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (48/114) '20221209 melanoma_macrophage.xlsx' -> '20221209 melanoma_macrophage.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (49/114) 'KMJ_Crescent.xlsx' -> 'KMJ_Crescent.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (50/114) 'tnbc_ln.xlsx' -> 'tnbc_ln.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (51/114) '20221228_psoriasis_jsp, bk.xlsx' -> '20221228_psoriasis_jsp, bk.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (52/114) 'Lupus Nephritis.xlsx' -> 'Lupus Nephritis.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (53/114) '20230103 macrophage .xlsx' -> '20230103 macrophage .csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (54/114) 'JSY WTA.xlsx' -> 'JSY WTA.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (55/114) 'placenta_KHW.xlsx' -> 'placenta_KHW.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (56/114) '20230512 Brain preliminary 2.xlsx' -> '20230512 Brain preliminary 2.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (57/114) 'CRC.xlsx' -> 'CRC.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (58/114) 'MuOPKidney.xlsx' -> 'MuOPKidney.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (59/114) '20230515 brain original rna probe.xlsx' -> '20230515 brain original rna probe.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (60/114) 'Pancreatic Cancer 2.xlsx' -> 'Pancreatic Cancer 2.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (61/114) '20230609_GI_2.xlsx' -> '20230609_GI_2.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (62/114) 'Marmoset_EAE_ODS.xlsx' -> 'Marmoset_EAE_ODS.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (63/114) '20230615_LE_Rosa_1st.xlsx' -> '20230615_LE_Rosa_1st.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (64/114) 'MN_D1.E3.X1.C4.C3.C2.D4.xlsx' -> 'MN_D1.E3.X1.C4.C3.C2.D4.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (65/114) '20230703_GI_control.xlsx' -> '20230703_GI_control.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (66/114) 'MN_D1.E3.X1.C4.C3.C2.D4_.xlsx' -> 'MN_D1.E3.X1.C4.C3.C2.D4_.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (67/114) '20240214_Brain_PD.xlsx' -> '20240214_Brain_PD.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (68/114) 'MN_D1.E3.X1.C4.C3.C2.D4__.xlsx' -> 'MN_D1.E3.X1.C4.C3.C2.D4__.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (69/114) '20240723 PV_ChoiSeoyoung_GeoMx.xlsx' -> '20240723 PV_ChoiSeoyoung_GeoMx.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (70/114) 'Breast_Cancer_KHW.xlsx' -> 'Breast_Cancer_KHW.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (71/114) 'Dermatomyositis.xlsx' -> 'Dermatomyositis.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (72/114) 'Placenta_GeoMx.xlsx' -> 'Placenta_GeoMx.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (73/114) 'BC_stage_240607.xlsx' -> 'BC_stage_240607.csv' 변환 완료.
# 'SMC0408.xlsx' 처리 중 오류: Worksheet named 'BioProbeCountMatrix' not found
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (75/114) '20240910 Steatosis WTA_BYJ.xlsx' -> '20240910 Steatosis WTA_BYJ.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (76/114) 'MN_X3.B4.C1.X2.xlsx' -> 'MN_X3.B4.C1.X2.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (77/114) 'bk melanoma.xlsx' -> 'bk melanoma.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (78/114) 'Keloid GeoMx.xlsx' -> 'Keloid GeoMx.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (79/114) 'yu.xlsx' -> 'yu.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (80/114) 'BK_colon cancer.xlsx' -> 'BK_colon cancer.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (81/114) 'MT analysis_20220920.xlsx' -> 'MT analysis_20220920.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (82/114) 'Bladder_Cancer_Final.xlsx' -> 'Bladder_Cancer_Final.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (83/114) 'Bladder_Cancer_20230913.xlsx' -> 'Bladder_Cancer_20230913.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (84/114) 'BYC_Thymus_B cell_2021.xlsx' -> 'BYC_Thymus_B cell_2021.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (85/114) 'Keloid_LYI_2mm_20240528.xlsx' -> 'Keloid_LYI_2mm_20240528.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (86/114) 'BSB_Dermatomyositis.xlsx' -> 'BSB_Dermatomyositis.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (87/114) 'NC_20231011.xlsx' -> 'NC_20231011.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (88/114) 'bullous real data.xlsx' -> 'bullous real data.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (89/114) 'EoD_analysis_yjbaik.xlsx' -> 'EoD_analysis_yjbaik.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (90/114) 'HCC_7_10_Final.xlsx' -> 'HCC_7_10_Final.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (91/114) 'H Chung_Thymus #1_240921.xlsx' -> 'H Chung_Thymus #1_240921.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (92/114) 'HCC_VETC_HSH.xlsx' -> 'HCC_VETC_HSH.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (93/114) 'IgAN_TPL_20240329.xlsx' -> 'IgAN_TPL_20240329.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (94/114) 'HCC_NTvsTC_48_KDJ_real.xlsx' -> 'HCC_NTvsTC_48_KDJ_real.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (95/114) 'HCC_NT_vs_TC_48_KMJ.xlsx' -> 'HCC_NT_vs_TC_48_KMJ.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (96/114) 'HS_LYI_20240411.xlsx' -> 'HS_LYI_20240411.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (97/114) 'mouse_nasal_polyp....xlsx' -> 'mouse_nasal_polyp....csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (98/114) 'HCC_TMA_KMS.xlsx' -> 'HCC_TMA_KMS.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (99/114) 'HS_LYI_2023922.xlsx' -> 'HS_LYI_2023922.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (100/114) 'RCC_56+28AOI.xlsx' -> 'RCC_56+28AOI.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (101/114) 'Pancreatic Cancer_HSH_231218.xlsx' -> 'Pancreatic Cancer_HSH_231218.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (102/114) 'Preliminary MSA Brain 2023.03.22.xlsx' -> 'Preliminary MSA Brain 2023.03.22.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (103/114) 'Preliminary230404_GI.xlsx' -> 'Preliminary230404_GI.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (104/114) 'SCC GeoMx.xlsx' -> 'SCC GeoMx.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (105/114) 'SJ_HY geomx Thymus.xlsx' -> 'SJ_HY geomx Thymus.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (106/114) 'SDR_Hu_HT.xlsx' -> 'SDR_Hu_HT.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (107/114) 'steatosis cta.xlsx' -> 'steatosis cta.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (108/114) 'syringoma re.xlsx' -> 'syringoma re.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (109/114) 'thymus normal.xlsx' -> 'thymus normal.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (110/114) 'thymus240401.xlsx' -> 'thymus240401.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (111/114) 'Total(Ubiased clustering_DRESS123).xlsx' -> 'Total(Ubiased clustering_DRESS123).csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (112/114) 'TOF_geomx_analysis.xlsx' -> 'TOF_geomx_analysis.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (113/114) 'Wound_GeoMx.xlsx' -> 'Wound_GeoMx.csv' 변환 완료.
# /home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (114/114) 'Wound_KHW.xlsx' -> 'Wound_KHW.csv' 변환 완료.
#
# ✅ 작업 완료! 고유한 컬럼명을 가진 CSV 파일들이 '/data/kjc1/projects/#999. GeoMx meta/pooled/csv_files_unique_names' 폴더에 저장되었습니다.

# %% [markdown]
# ## Matrix Merger

# %% [markdown]
# ### Merger 함수정의부

# %%
import pandas as pd
import os
import numpy as np
from functools import reduce
from typing import Dict, List, Tuple, Optional
import warnings
warnings.filterwarnings('ignore')

class OptimizedDataMerger:
    """
    최적화된 데이터 병합 클래스
    - 파일 유형 자동 감지 (CTA, Human WTA, Mouse)
    - 메모리 효율적인 처리
    - 병렬 처리 가능한 구조
    """
    
    def __init__(self, csv_folder_path: str, temp_export: bool = False):
        self.csv_folder_path = csv_folder_path
        self.temp_export = temp_export
        self.output_folder = os.path.join(csv_folder_path, "merged")
        
        # 표준 메타데이터 컬럼
        self.standard_cols = [
            'ProbeName', 'ProbeDisplayName', 'TargetName', 'HUGOSymbol', 
            'Accessions', 'GenomeBuild', 'GenomicPosition', 'AnalyteType', 
            'CodeClass', 'ProbePool', 'TargetGroup', 'GeneID'
        ]
        
        # 컬럼명 정규화 맵
        self.normalization_map = {
            col.lower().replace(' ', '').replace('_', ''): col 
            for col in self.standard_cols
        }
        
        # 파일 유형별 데이터 컨테이너
        self.cta_data = {'aoi_dfs': [], 'meta_map': {}}
        self.human_wta_data = {'aoi_dfs': [], 'meta_map': {}}
        self.mouse_data = {'aoi_dfs': [], 'meta_map': {}}
        
    def detect_file_type(self, df: pd.DataFrame) -> str:
        """
        파일 유형을 자동으로 감지
        Returns: 'CTA', 'HUMAN_WTA', 'MOUSE', or None
        """
        # GenomeBuild로 먼저 Mouse 확인
        if 'GenomeBuild' in df.columns:
            genome_builds = df['GenomeBuild'].astype(str).str.lower()
            
            if genome_builds.str.contains('grcm', na=False).any():
                return 'MOUSE'
            
            # Human 데이터인 경우 CTA vs WTA 구분
            if genome_builds.str.contains('grch', na=False).any():
                # Negative Probe의 TargetName으로 구분
                if 'CodeClass' in df.columns and 'TargetName' in df.columns:
                    neg_probes = df[df['CodeClass'] == 'Negative']
                    if not neg_probes.empty:
                        target_names = neg_probes['TargetName'].unique()
                        if 'Negative Probe' in target_names:
                            return 'CTA'
                        elif 'NegProbe-WTX' in target_names:
                            return 'HUMAN_WTA'
                
                # Negative Probe가 없는 경우, 같은 Gene에 여러 Probe가 있는지 확인
                if 'GeneID' in df.columns and 'TargetName' in df.columns:
                    endogenous = df[df.get('CodeClass', '') == 'Endogenous']
                    if not endogenous.empty:
                        gene_probe_counts = endogenous.groupby(['GeneID', 'TargetName'])['ProbeName'].nunique()
                        if (gene_probe_counts > 1).any():
                            return 'CTA'
                        else:
                            return 'HUMAN_WTA'
        
        return None
    
    def optimize_dtypes(self, df: pd.DataFrame) -> pd.DataFrame:
        """데이터 타입 최적화로 메모리 사용량 감소"""
        for col in df.columns:
            if col == 'ProbeName':  # ProbeName은 문자열로 유지
                continue
                
            col_type = df[col].dtype
            
            if col_type != 'object':
                try:
                    # NaN이 아닌 값만 선택
                    non_null = df[col].dropna()
                    
                    if len(non_null) == 0:  # 모든 값이 NaN인 경우
                        continue
                    
                    c_min = non_null.min()
                    c_max = non_null.max()
                    
                    # Integer 최적화 (NaN이 있으면 float로 유지)
                    if str(col_type).startswith('int') and not df[col].isna().any():
                        if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                            df[col] = df[col].astype(np.int8)
                        elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                            df[col] = df[col].astype(np.int16)
                        elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                            df[col] = df[col].astype(np.int32)
                    
                    # Float 최적화
                    elif str(col_type).startswith('float'):
                        # float16은 정밀도 문제가 있을 수 있으므로 float32로 제한
                        if c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                            df[col] = df[col].astype(np.float32)
                            
                except Exception as e:
                    # 최적화 실패 시 원본 유지
                    continue
        
        return df
    
    def process_file(self, filepath: str, filename: str) -> None:
        """개별 파일 처리"""
        try:
            # 청크 단위로 읽어서 메모리 효율성 향상
            df = pd.read_csv(filepath, low_memory=False, chunksize=None)
        except Exception as e:
            print(f"  ❌ 파일 읽기 오류: {e}")
            return
        
        # 컬럼명 정규화
        df.rename(columns={
            col: self.normalization_map.get(
                col.lower().replace(' ', '').replace('_', ''), col
            ) for col in df.columns
        }, inplace=True)
        
        # 중복 컬럼 제거 (rename 후 발생 가능)
        df = df.loc[:, ~df.columns.duplicated()]
        
        if 'ProbeName' not in df.columns:
            print(f"  ⚠️  '{filename}'에 ProbeName 컬럼이 없어 건너뜁니다.")
            return
        
        # ProbeName을 문자열로 통일
        df['ProbeName'] = df['ProbeName'].astype(str)
        
        # 파일 유형 감지
        file_type = self.detect_file_type(df)
        if not file_type:
            print(f"  ⚠️  '{filename}'의 파일 유형을 확인할 수 없습니다.")
            return
        
        print(f"  📁 파일 유형: {file_type}")
        print(f"  📊 데이터 크기: {df.shape[0]} rows × {df.shape[1]} columns")
        
        # 데이터 타입 최적화
        df = self.optimize_dtypes(df)
        
        # 파일 유형에 따라 적절한 컨테이너에 저장
        if file_type == 'CTA':
            target_data = self.cta_data
        elif file_type == 'HUMAN_WTA':
            target_data = self.human_wta_data
        else:  # MOUSE
            target_data = self.mouse_data
        
        # AOI 컬럼 추출
        numeric_cols = df.select_dtypes(include=[np.number]).columns.tolist()
        aoi_cols = [col for col in numeric_cols if col not in self.standard_cols]
        
        if aoi_cols:
            # 파일명 접두사
            file_prefix = os.path.splitext(filename)[0]
            
            # AOI 데이터프레임 생성
            aoi_df = df[['ProbeName'] + aoi_cols].copy()
            
            # 컬럼명에 파일 접두사 추가
            rename_dict = {col: f"{file_prefix}_{col}" for col in aoi_cols}
            aoi_df.rename(columns=rename_dict, inplace=True)
            
            # AOI 데이터 저장
            target_data['aoi_dfs'].append(aoi_df)
            
            # 메타데이터 수집 (중복 제거)
            meta_cols_to_use = ['ProbeName'] + [col for col in self.standard_cols if col in df.columns and col != 'ProbeName']
            # 중복 컬럼 제거
            meta_cols_to_use = list(dict.fromkeys(meta_cols_to_use))
            
            meta_df = df[meta_cols_to_use].drop_duplicates(subset=['ProbeName'])
            
            for idx, row in meta_df.iterrows():
                # ProbeName을 스칼라 값으로 확실히 변환
                try:
                    probe_name = str(row['ProbeName']) if not isinstance(row['ProbeName'], str) else row['ProbeName']
                except Exception as e:
                    print(f"    ⚠️  ProbeName 변환 오류 (row {idx}): {e}")
                    continue
                    
                if probe_name not in target_data['meta_map']:
                    target_data['meta_map'][probe_name] = {
                        col: row.get(col) for col in self.standard_cols 
                        if col in df.columns and col != 'ProbeName'  # ProbeName은 키로 사용하므로 제외
                    }
        
        print(f"  ✅ 처리 완료: {len(aoi_cols)}개 AOI 컬럼")
    
    def merge_and_save(self, data_dict: dict, output_name: str) -> Optional[pd.DataFrame]:
        """데이터 병합 및 저장"""
        if not data_dict['aoi_dfs']:
            print(f"[{output_name}] 처리할 데이터가 없습니다.")
            return None
        
        print(f"\n[{output_name}] 병합 시작...")
        
        try:
            # 모든 데이터프레임의 ProbeName을 문자열로 통일
            for df in data_dict['aoi_dfs']:
                df['ProbeName'] = df['ProbeName'].astype(str)
            
            # 효율적인 병합: 작은 데이터프레임부터 병합
            data_dict['aoi_dfs'].sort(key=lambda x: len(x))
            
            # AOI 데이터 병합
            merged_aoi = reduce(
                lambda left, right: pd.merge(left, right, on='ProbeName', how='outer'),
                data_dict['aoi_dfs']
            )
            
            # 메타데이터 데이터프레임 생성
            if data_dict['meta_map']:
                meta_df = pd.DataFrame.from_dict(data_dict['meta_map'], orient='index')
                
                # index를 ProbeName 컬럼으로 변환
                # 이미 ProbeName 컬럼이 있다면 제거
                if 'ProbeName' in meta_df.columns:
                    meta_df = meta_df.drop(columns=['ProbeName'])
                
                meta_df.index.name = 'ProbeName'
                meta_df.reset_index(inplace=True)
                meta_df['ProbeName'] = meta_df['ProbeName'].astype(str)
                
                # 최종 병합
                final_df = pd.merge(meta_df, merged_aoi, on='ProbeName', how='right')
            else:
                # 메타데이터가 없는 경우
                final_df = merged_aoi
            
            # 컬럼 순서 정리
            meta_cols = [col for col in self.standard_cols if col in final_df.columns]
            data_cols = [col for col in final_df.columns if col not in meta_cols]
            final_df = final_df[meta_cols + data_cols]
            
            # 데이터 타입 최적화
            final_df = self.optimize_dtypes(final_df)
            
            # 파일 저장
            output_path = self.get_unique_filepath(f"merged_{output_name}.csv")
            final_df.to_csv(output_path, index=False)
            
            print(f"  ✅ 저장 완료: {output_path}")
            print(f"     크기: {final_df.shape[0]} rows × {final_df.shape[1]} columns")
            print(f"     메모리 사용량: {final_df.memory_usage(deep=True).sum() / 1024**2:.2f} MB")
            
            return final_df
            
        except Exception as e:
            print(f"  ❌ 병합 중 오류 발생: {e}")
            import traceback
            traceback.print_exc()
            return None
    
    def get_unique_filepath(self, filename: str) -> str:
        """중복되지 않는 파일명 생성"""
        base, ext = os.path.splitext(filename)
        counter = 1
        filepath = os.path.join(self.output_folder, filename)
        
        while os.path.exists(filepath):
            filepath = os.path.join(self.output_folder, f"{base}_{counter}{ext}")
            counter += 1
        
        return filepath
    
    def run(self) -> Dict[str, pd.DataFrame]:
        """전체 처리 프로세스 실행"""
        # 폴더 확인 및 생성
        try:
            all_files = os.listdir(self.csv_folder_path)
            csv_files = [
                f for f in all_files 
                if f.endswith('.csv') and not f.startswith('merged_')
            ]
            
            if not csv_files:
                print(f"'{self.csv_folder_path}' 폴더에 처리할 CSV 파일이 없습니다.")
                return {}
        
        except FileNotFoundError:
            print(f"오류: '{self.csv_folder_path}' 폴더를 찾을 수 없습니다.")
            return {}
        
        # 출력 폴더 생성
        os.makedirs(self.output_folder, exist_ok=True)
        
        print(f"🔄 총 {len(csv_files)}개 CSV 파일 처리 시작\n")
        print("="*60)
        
        # 각 파일 처리
        for i, filename in enumerate(csv_files, 1):
            print(f"\n[{i}/{len(csv_files)}] 처리 중: {filename}")
            filepath = os.path.join(self.csv_folder_path, filename)
            self.process_file(filepath, filename)
        
        print("\n" + "="*60)
        print("📊 최종 병합 및 저장")
        print("="*60)
        
        # 결과 저장
        results = {}
        
        # CTA 데이터 병합 및 저장
        if self.cta_data['aoi_dfs']:
            print(f"\n📝 CTA 파일 {len(self.cta_data['aoi_dfs'])}개 발견")
            result = self.merge_and_save(self.cta_data, 'CTA')
            if result is not None:
                results['CTA'] = result
        
        # Human WTA 데이터 병합 및 저장  
        if self.human_wta_data['aoi_dfs']:
            print(f"\n📝 Human WTA 파일 {len(self.human_wta_data['aoi_dfs'])}개 발견")
            result = self.merge_and_save(self.human_wta_data, 'HUMAN_WTA')
            if result is not None:
                results['HUMAN_WTA'] = result
        
        # Mouse 데이터 병합 및 저장
        if self.mouse_data['aoi_dfs']:
            print(f"\n📝 Mouse 파일 {len(self.mouse_data['aoi_dfs'])}개 발견")
            result = self.merge_and_save(self.mouse_data, 'MOUSE')
            if result is not None:
                results['MOUSE'] = result
        
        print("\n" + "="*60)
        print("✨ 모든 처리가 완료되었습니다!")
        print(f"📁 결과 파일 위치: {self.output_folder}")
        
        return results


def process_and_merge_data_optimized(csv_folder_path: str, temp_export: bool = False) -> Dict[str, pd.DataFrame]:
    """
    최적화된 데이터 병합 함수
    
    Parameters:
    -----------
    csv_folder_path : str
        CSV 파일들이 있는 폴더 경로
    temp_export : bool
        중간 파일 저장 여부 (현재 미사용)
    
    Returns:
    --------
    Dict[str, pd.DataFrame]
        파일 유형별 병합된 데이터프레임 딕셔너리
    """
    merger = OptimizedDataMerger(csv_folder_path, temp_export)
    return merger.run()


# # 사용 예시
# if __name__ == "__main__":
#     # 폴더 경로 설정
#     folder_path = "./data"  # 실제 경로로 변경하세요
    
#     try:
#         # 처리 실행
#         results = process_and_merge_data_optimized(folder_path, temp_export=False)
        
#         # 결과 확인
#         for file_type, df in results.items():
#             if df is not None:
#                 print(f"\n{file_type} 데이터:")
#                 print(f"  - Shape: {df.shape}")
#                 print(f"  - ProbeName 유니크 개수: {df['ProbeName'].nunique()}")
#                 if 'CodeClass' in df.columns:
#                     print(f"  - CodeClass 분포:")
#                     print(f"    {df['CodeClass'].value_counts().to_dict()}")
                    
#     except Exception as e:
#         print(f"\n❌ 처리 중 오류 발생: {e}")
#         import traceback
#         traceback.print_exc()

# %% [markdown]
# ### 변수 정의

# %%
csv_source_folder="/data/kjc1/projects/#999.GeoMxmeta/pooled/csv_files/"

# %% [markdown]
# ### 실행

# %%
# 사용 예시
if __name__ == "__main__":
    # 폴더 경로 설정
    folder_path = csv_source_folder  # 실제 경로로 변경하세요
    
    try:
        # 처리 실행
        results = process_and_merge_data_optimized(folder_path, temp_export=False)
        
        # 결과 확인
        for file_type, df in results.items():
            if df is not None:
                print(f"\n{file_type} 데이터:")
                print(f"  - Shape: {df.shape}")
                print(f"  - ProbeName 유니크 개수: {df['ProbeName'].nunique()}")
                if 'CodeClass' in df.columns:
                    print(f"  - CodeClass 분포:")
                    print(f"    {df['CodeClass'].value_counts().to_dict()}")
                    
    except Exception as e:
        print(f"\n❌ 처리 중 오류 발생: {e}")
        import traceback
        traceback.print_exc()

# %% [markdown]
# ## Filter

# %% [markdown]
# ### Filter 함수정의부

# %%
import pandas as pd
import numpy as np
import hashlib
from typing import Dict, List, Tuple, Optional, Union
import json
from pathlib import Path

class DuplicateAOIFilter:
    """
    중복 AOI(Area of Interest) 컬럼을 감지하고 필터링하는 클래스
    완전히 동일한 데이터를 가진 AOI 컬럼들을 찾아서 제거
    """
    
    def __init__(self, verbose: bool = True):
        """
        Parameters:
        -----------
        verbose : bool
            상세한 처리 과정 출력 여부
        """
        self.verbose = verbose
        self.duplicate_groups = {}
        self.removal_report = {}
        
    def generate_column_fingerprint(self, series: pd.Series) -> str:
        """
        컬럼의 고유한 fingerprint 생성
        NaN 값도 고려하여 동일한 패턴을 가진 컬럼들을 식별
        
        Parameters:
        -----------
        series : pd.Series
            fingerprint를 생성할 데이터 시리즈
            
        Returns:
        --------
        str : 해시된 fingerprint
        """
        # NaN 위치 정보 포함
        nan_mask = series.isna()
        
        # NaN이 아닌 값들을 정렬하지 않고 그대로 사용 (순서 보존)
        # 값들을 문자열로 변환하여 해시 생성
        values_str = '|'.join([
            f"{i}:{v}" if not pd.isna(v) else f"{i}:NaN" 
            for i, v in enumerate(series.values)
        ])
        
        # MD5 해시 생성 (충돌 가능성은 매우 낮음)
        hash_object = hashlib.md5(values_str.encode())
        return hash_object.hexdigest()
    
    def find_duplicate_aois(self, df: pd.DataFrame) -> Dict[str, List[str]]:
        """
        중복된 AOI 컬럼들을 찾아서 그룹화
        
        Parameters:
        -----------
        df : pd.DataFrame
            분석할 데이터프레임
            
        Returns:
        --------
        Dict[str, List[str]] : fingerprint별 중복 컬럼 리스트
        """
        # 메타데이터 컬럼 식별
        meta_columns = ['ProbeName', 'ProbeDisplayName', 'TargetName', 'HUGOSymbol', 
                       'Accessions', 'GenomeBuild', 'GenomicPosition', 'AnalyteType', 
                       'CodeClass', 'ProbePool', 'TargetGroup', 'GeneID']
        
        # AOI 컬럼만 추출 (메타데이터 제외)
        aoi_columns = [col for col in df.columns if col not in meta_columns]
        
        if self.verbose:
            print(f"📊 전체 컬럼 수: {len(df.columns)}")
            print(f"📊 AOI 컬럼 수: {len(aoi_columns)}")
            print(f"🔍 중복 검사 시작...\n")
        
        # 각 AOI 컬럼의 fingerprint 생성
        fingerprint_map = {}
        
        for col in aoi_columns:
            fp = self.generate_column_fingerprint(df[col])
            
            if fp not in fingerprint_map:
                fingerprint_map[fp] = []
            fingerprint_map[fp].append(col)
        
        # 중복 그룹만 추출 (2개 이상의 컬럼을 가진 그룹)
        duplicate_groups = {
            fp: cols for fp, cols in fingerprint_map.items() 
            if len(cols) > 1
        }
        
        self.duplicate_groups = duplicate_groups
        
        if self.verbose:
            print(f"🔍 발견된 중복 그룹: {len(duplicate_groups)}개")
            total_duplicates = sum(len(cols) - 1 for cols in duplicate_groups.values())
            print(f"📉 제거 가능한 중복 AOI: {total_duplicates}개\n")
            
            # 중복 그룹 상세 정보 출력
            for i, (fp, cols) in enumerate(duplicate_groups.items(), 1):
                print(f"  그룹 {i}: {len(cols)}개 동일한 AOI")
                print(f"    대표 AOI: {cols[0]}")
                print(f"    중복 AOI: {', '.join(cols[1:])}")
                print()
        
        return duplicate_groups
    
    def filter_duplicates(self, 
                          df: pd.DataFrame, 
                          keep_strategy: str = 'first',
                          custom_priority: Optional[List[str]] = None) -> pd.DataFrame:
        """
        중복 AOI를 제거한 데이터프레임 반환
        
        Parameters:
        -----------
        df : pd.DataFrame
            필터링할 데이터프레임
        keep_strategy : str
            유지할 컬럼 선택 전략
            - 'first': 각 그룹에서 첫 번째 컬럼 유지 (기본값)
            - 'last': 각 그룹에서 마지막 컬럼 유지
            - 'shortest': 가장 짧은 이름의 컬럼 유지
            - 'custom': custom_priority 리스트 기준으로 우선순위 결정
        custom_priority : List[str]
            keep_strategy='custom'일 때 사용할 우선순위 패턴
            예: ['slide1', 'slide2'] - slide1이 있으면 우선 선택
            
        Returns:
        --------
        pd.DataFrame : 중복이 제거된 데이터프레임
        """
        # 먼저 중복 찾기
        duplicate_groups = self.find_duplicate_aois(df)
        
        if not duplicate_groups:
            if self.verbose:
                print("✅ 중복된 AOI가 없습니다.")
            return df.copy()
        
        # 제거할 컬럼 리스트
        columns_to_remove = []
        self.removal_report = {}
        
        for fp, cols in duplicate_groups.items():
            if keep_strategy == 'first':
                keep_col = cols[0]
                remove_cols = cols[1:]
            elif keep_strategy == 'last':
                keep_col = cols[-1]
                remove_cols = cols[:-1]
            elif keep_strategy == 'shortest':
                keep_col = min(cols, key=len)
                remove_cols = [c for c in cols if c != keep_col]
            elif keep_strategy == 'custom' and custom_priority:
                # 우선순위에 따라 선택
                keep_col = cols[0]  # 기본값
                for pattern in custom_priority:
                    matching = [c for c in cols if pattern in c]
                    if matching:
                        keep_col = matching[0]
                        break
                remove_cols = [c for c in cols if c != keep_col]
            else:
                keep_col = cols[0]
                remove_cols = cols[1:]
            
            columns_to_remove.extend(remove_cols)
            self.removal_report[keep_col] = remove_cols
        
        # 중복 제거된 데이터프레임 생성
        filtered_df = df.drop(columns=columns_to_remove)
        
        if self.verbose:
            print(f"\n✂️  제거된 컬럼 수: {len(columns_to_remove)}")
            print(f"✅ 남은 전체 컬럼 수: {len(filtered_df.columns)}")
            print(f"💾 메모리 절감: {(1 - filtered_df.memory_usage(deep=True).sum() / df.memory_usage(deep=True).sum()) * 100:.1f}%")
        
        return filtered_df
    
    def get_removal_report(self) -> Dict[str, List[str]]:
        """
        제거 리포트 반환
        
        Returns:
        --------
        Dict[str, List[str]] : 유지된 컬럼과 제거된 컬럼들의 매핑
        """
        return self.removal_report
    
    def save_report(self, filepath: str = "duplicate_aoi_report.json"):
        """
        중복 제거 리포트를 JSON 파일로 저장
        
        Parameters:
        -----------
        filepath : str
            저장할 파일 경로
        """
        report = {
            'summary': {
                'total_duplicate_groups': len(self.duplicate_groups),
                'total_removed_columns': sum(len(v) for v in self.removal_report.values()),
                'kept_columns': list(self.removal_report.keys())
            },
            'details': self.removal_report,
            'duplicate_groups': {
                f"group_{i}": cols 
                for i, cols in enumerate(self.duplicate_groups.values(), 1)
            }
        }
        
        with open(filepath, 'w') as f:
            json.dump(report, f, indent=2)
        
        if self.verbose:
            print(f"\n📄 리포트 저장 완료: {filepath}")
    
    def validate_filtering(self, original_df: pd.DataFrame, filtered_df: pd.DataFrame) -> bool:
        """
        필터링 결과 검증
        중요한 데이터가 손실되지 않았는지 확인
        
        Parameters:
        -----------
        original_df : pd.DataFrame
            원본 데이터프레임
        filtered_df : pd.DataFrame
            필터링된 데이터프레임
            
        Returns:
        --------
        bool : 검증 성공 여부
        """
        # 메타데이터 컬럼은 모두 유지되었는지 확인
        meta_columns = ['ProbeName', 'ProbeDisplayName', 'TargetName', 'HUGOSymbol', 
                       'Accessions', 'GenomeBuild', 'GenomicPosition', 'AnalyteType', 
                       'CodeClass', 'ProbePool', 'TargetGroup', 'GeneID']
        
        original_meta = [col for col in meta_columns if col in original_df.columns]
        filtered_meta = [col for col in meta_columns if col in filtered_df.columns]
        
        if original_meta != filtered_meta:
            print("⚠️ 경고: 메타데이터 컬럼이 변경되었습니다!")
            return False
        
        # 행 수가 동일한지 확인
        if len(original_df) != len(filtered_df):
            print("⚠️ 경고: 행 수가 변경되었습니다!")
            return False
        
        if self.verbose:
            print("\n✅ 검증 완료: 데이터 무결성 확인")
        
        return True


def remove_duplicate_aois(filepath: Union[str, pd.DataFrame], 
                         output_path: Optional[str] = None,
                         keep_strategy: str = 'first',
                         verbose: bool = True) -> pd.DataFrame:
    """
    중복 AOI를 제거하는 간단한 wrapper 함수
    
    Parameters:
    -----------
    filepath : Union[str, pd.DataFrame]
        CSV 파일 경로 또는 데이터프레임
    output_path : Optional[str]
        결과를 저장할 CSV 파일 경로 (None이면 저장하지 않음)
    keep_strategy : str
        유지할 컬럼 선택 전략 ('first', 'last', 'shortest')
    verbose : bool
        상세 출력 여부
        
    Returns:
    --------
    pd.DataFrame : 중복이 제거된 데이터프레임
    
    Example:
    --------
    >>> # 파일 경로로 사용
    >>> filtered_df = remove_duplicate_aois('merged_CTA.csv', 
    ...                                     output_path='merged_CTA_filtered.csv')
    
    >>> # 데이터프레임으로 사용
    >>> df = pd.read_csv('merged_CTA.csv')
    >>> filtered_df = remove_duplicate_aois(df)
    """
    # 입력 처리
    if isinstance(filepath, str):
        if verbose:
            print(f"📁 파일 읽기: {filepath}")
        df = pd.read_csv(filepath, low_memory=False)
    else:
        df = filepath.copy()
    
    # 필터 객체 생성 및 처리
    filter_obj = DuplicateAOIFilter(verbose=verbose)
    filtered_df = filter_obj.filter_duplicates(df, keep_strategy=keep_strategy)
    
    # 검증
    filter_obj.validate_filtering(df, filtered_df)
    
    # 리포트 저장
    if output_path:
        # 리포트는 같은 디렉토리에 저장
        report_path = Path(output_path).parent / f"{Path(output_path).stem}_duplicate_report.json"
        filter_obj.save_report(str(report_path))
    
    # 결과 저장
    if output_path:
        filtered_df.to_csv(output_path, index=False)
        if verbose:
            print(f"💾 필터링된 파일 저장: {output_path}")
            print(f"   원본: {df.shape[1]} columns → 필터링: {filtered_df.shape[1]} columns")
    
    return filtered_df


def analyze_aoi_similarity(df: pd.DataFrame, threshold: float = 0.99) -> pd.DataFrame:
    """
    AOI 간의 유사도를 분석 (완전 동일하지 않지만 매우 유사한 경우 찾기)
    
    Parameters:
    -----------
    df : pd.DataFrame
        분석할 데이터프레임
    threshold : float
        유사도 임계값 (0-1, 기본값 0.99 = 99% 유사)
        
    Returns:
    --------
    pd.DataFrame : 유사한 AOI 쌍과 유사도 점수
    """
    # 메타데이터 컬럼 제외
    meta_columns = ['ProbeName', 'ProbeDisplayName', 'TargetName', 'HUGOSymbol', 
                   'Accessions', 'GenomeBuild', 'GenomicPosition', 'AnalyteType', 
                   'CodeClass', 'ProbePool', 'TargetGroup', 'GeneID']
    
    aoi_columns = [col for col in df.columns if col not in meta_columns]
    
    similar_pairs = []
    
    print(f"🔍 {len(aoi_columns)}개 AOI 컬럼 간 유사도 분석 중...")
    
    for i, col1 in enumerate(aoi_columns):
        for col2 in aoi_columns[i+1:]:
            # 두 컬럼의 상관계수 계산
            corr = df[col1].corr(df[col2])
            
            if corr >= threshold:
                # 값이 정확히 일치하는 비율 계산
                exact_match_ratio = (df[col1] == df[col2]).mean()
                
                similar_pairs.append({
                    'Column1': col1,
                    'Column2': col2,
                    'Correlation': corr,
                    'ExactMatchRatio': exact_match_ratio,
                    'IsDuplicate': exact_match_ratio == 1.0
                })
    
    result_df = pd.DataFrame(similar_pairs)
    
    if len(result_df) > 0:
        result_df = result_df.sort_values('Correlation', ascending=False)
        print(f"✅ {len(result_df)}개의 유사한 AOI 쌍 발견 (threshold: {threshold})")
        
        duplicates = result_df[result_df['IsDuplicate'] == True]
        if len(duplicates) > 0:
            print(f"   - 완전 중복: {len(duplicates)}쌍")
        
        high_similar = result_df[(result_df['IsDuplicate'] == False) & (result_df['Correlation'] >= threshold)]
        if len(high_similar) > 0:
            print(f"   - 높은 유사도: {len(high_similar)}쌍")
    else:
        print(f"ℹ️ 임계값 {threshold} 이상의 유사한 AOI 쌍이 없습니다.")
    
    return result_df


# 사용 예시
if __name__ == "__main__":
    # 기본 사용법
    print("=" * 60)
    print("중복 AOI 필터링 예시")
    print("=" * 60)
    
    # 1. 간단한 사용법
    # filtered_df = remove_duplicate_aois('merged_CTA.csv', 
    #                                     output_path='merged_CTA_filtered.csv')
    
    # 2. 상세 분석과 함께 사용
    # filter_obj = DuplicateAOIFilter(verbose=True)
    # df = pd.read_csv('merged_CTA.csv')
    # duplicate_groups = filter_obj.find_duplicate_aois(df)
    # filtered_df = filter_obj.filter_duplicates(df, keep_strategy='shortest')
    # filter_obj.save_report('cta_duplicate_report.json')
    
    # 3. 유사도 분석
    # df = pd.read_csv('merged_CTA.csv')
    # similarity_df = analyze_aoi_similarity(df, threshold=0.95)
    # print(similarity_df.head())
    
    print("\n사용 방법:")
    print("1. remove_duplicate_aois('merged_CTA.csv') - 간단 사용")
    print("2. DuplicateAOIFilter 클래스 - 상세 제어")
    print("3. analyze_aoi_similarity() - 유사도 분석")
# Out:
# ============================================================
# 중복 AOI 필터링 예시
# ============================================================
#
# 사용 방법:
# 1. remove_duplicate_aois('merged_CTA.csv') - 간단 사용
# 2. DuplicateAOIFilter 클래스 - 상세 제어
# 3. analyze_aoi_similarity() - 유사도 분석

# %% [markdown]
# ### 변수 정의

# %%
raw_merged_csv='/data/kjc1/projects/#999.GeoMxmeta/pooled/csv_files/merged/merged_HUMAN_WTA.csv'
output_path=add_suffix_to_filename(raw_merged_csv,"_filtered")
raw_merged_csv2='/data/kjc1/projects/#999.GeoMxmeta/pooled/csv_files/merged/merged_CTA.csv'
output_path2=add_suffix_to_filename(raw_merged_csv2,"_filtered")
raw_merged_csv3='/data/kjc1/projects/#999.GeoMxmeta/pooled/csv_files/merged/merged_MOUSE.csv'
output_path3=add_suffix_to_filename(raw_merged_csv3,"_filtered")
print(output_path)
print(output_path2)
print(output_path3)
# Out:
# /data/kjc1/projects/#999. GeoMx meta/pooled/csv_files/merged/merged_HUMAN_WTA_filtered.csv
# /data/kjc1/projects/#999. GeoMx meta/pooled/csv_files/merged/merged_CTA_filtered.csv
# /data/kjc1/projects/#999. GeoMx meta/pooled/csv_files/merged/merged_MOUSE_filtered.csv

# %% [markdown]
# ### 실행

# %%
# 사용 예시
if __name__ == "__main__":
    # 기본 사용법
    print("=" * 60)
    print("중복 AOI 필터링 예시")
    print("=" * 60)
    
    # 1. 간단한 사용법
    filtered_df = remove_duplicate_aois(raw_merged_csv, 
                                        output_path=output_path)
    
    # 2. 상세 분석과 함께 사용
    # filter_obj = DuplicateAOIFilter(verbose=True)
    # df = pd.read_csv('merged_CTA.csv')
    # duplicate_groups = filter_obj.find_duplicate_aois(df)
    # filtered_df = filter_obj.filter_duplicates(df, keep_strategy='shortest')
    # filter_obj.save_report('cta_duplicate_report.json')
    
    # 3. 유사도 분석
    # df = pd.read_csv('merged_CTA.csv')
    # similarity_df = analyze_aoi_similarity(df, threshold=0.95)
    # print(similarity_df.head())
    
    print("\n사용 방법:")
    print("1. remove_duplicate_aois('merged_CTA.csv') - 간단 사용")
    print("2. DuplicateAOIFilter 클래스 - 상세 제어")
    print("3. analyze_aoi_similarity() - 유사도 분석")
# Out:
# ============================================================
# 중복 AOI 필터링 예시
# ============================================================
# 📁 파일 읽기: /data/kjc1/projects/#999. GeoMx meta/pooled/csv_files/merged/merged_HUMAN_WTA.csv
# 📊 전체 컬럼 수: 5469
# 📊 AOI 컬럼 수: 5457
# 🔍 중복 검사 시작...
#
# 🔍 발견된 중복 그룹: 1137개
# 📉 제거 가능한 중복 AOI: 1643개
#
#   그룹 1: 137개 동일한 AOI
#     대표 AOI: (not aligned)20221207 bk,yk melanoma_melanoma | 001 | Segment 1
#     중복 AOI: (not aligned)20221207 bk,yk melanoma_melanoma | 001 | Segment 2, (not aligned)20221207 bk,yk melanoma_melanoma | 002 | Segment 1, (not aligned)20221207 bk,yk melanoma_melanoma | 002 | Segment 2, (not aligned)20221207 bk,yk melanoma_melanoma | 003 | Segment 1, (not aligned)20221207 bk,yk melanoma_melanoma | 003 | Segment 2, (not aligned)20221207 bk,yk melanoma_melanoma | 004 | Segment 1, (not aligned)20221207 bk,yk melanoma_melanoma | 004 | Segment 2, (not aligned)20221207 bk,yk melanoma_melanoma | 005 | Segment 1, (not aligned)20221207 bk,yk melanoma_melanoma | 005 | Segment 2, (not aligned)20221207 bk,yk melanoma_melanoma | 006 | Segment 1, (not aligned)20221207 bk,yk melanoma_melanoma | 006 | Segment 2, (not aligned)20221207 bk,yk melanoma_melanoma | 007 | Full ROI, (not aligned)20221207 bk,yk melanoma_melanoma | 008 | Full ROI, (not aligned)20221207 bk,yk melanoma_melanoma | 009 | Full ROI, (not aligned)20221207 bk,yk melanoma_melanoma | 010 | Full ROI, (not aligned)20221207 bk,yk melanoma_melanoma | 011 | Full ROI, (not aligned)20221207 bk,yk melanoma_melanoma | 012 | Full ROI, (not aligned)20221207 bk,yk melanoma_MELANOMA | 001 | Segment 1, (not aligned)20221207 bk,yk melanoma_MELANOMA | 001 | Segment 2, (not aligned)20221207 bk,yk melanoma_MELANOMA | 002 | Segment 1, (not aligned)20221207 bk,yk melanoma_MELANOMA | 002 | Segment 2, (not aligned)20221207 bk,yk melanoma_MELANOMA | 003 | Segment 1, (not aligned)20221207 bk,yk melanoma_MELANOMA | 003 | Segment 2, (not aligned)20221207 bk,yk melanoma_MELANOMA | 004 | Segment 1, (not aligned)20221207 bk,yk melanoma_MELANOMA | 004 | Segment 2, (not aligned)20221207 bk,yk melanoma_MELANOMA | 005 | Segment 1, (not aligned)20221207 bk,yk melanoma_MELANOMA | 005 | Segment 2, (not aligned)20221207 bk,yk melanoma_MELANOMA | 006 | Segment 1, (not aligned)20221207 bk,yk melanoma_MELANOMA | 006 | Segment 2, (not aligned)20221207 bk,yk melanoma_MELANOMA | 007 | Full ROI, (not aligned)20221207 bk,yk melanoma_MELANOMA | 008 | Full ROI, (not aligned)20221207 bk,yk melanoma_MELANOMA | 009 | Full ROI, (not aligned)20221207 bk,yk melanoma_MELANOMA | 010 | Full ROI, (not aligned)20221207 bk,yk melanoma_MELANOMA | 011 | Full ROI, (not aligned)20221207 bk,yk melanoma_MELANOMA | 012 | Full ROI, Keloid_LYI_4mm_20240528_Keloid_TMA_4mm_20240505 | 068 | Full ROI, DKD_20240125_DKD3_20231122_KMJ | 016 | Full ROI, DKD_20240125_DKD6_20231124_KMJ | 020 | Full ROI, Final Thymus normal_3_#13(1Y1M)_#2(6Y6M)_Geomx | 003 | PanCK+, TA3814_TA3814_Koh | 039 | Segment 2, IFTA_250121_NEW_except1patient_IFTA1_20240717 | 003 | Full ROI, IFTA_250121_NEW_except1patient_IFTA2_20240717 | 003 | Full ROI, IFTA_250121_NEW_except1patient_IFTA2_20240717 | 015 | Full ROI, IFTA_250121_NEW_except1patient_IFTA2_20240717 | 017 | Full ROI, IFTA_250121_NEW_except1patient_IFTA3_20240717 | 005 | Full ROI, IgAN_KMJ_BYJ_20221004_20220824 IgAN KMJ BYJ slide1 | 001 | Full ROI, IgAN_KMJ_BYJ_20221004_20220824 IgAN KMJ BYJ slide1 | 002 | Full ROI, IgAN_KMJ_BYJ_20221004_20220824 IgAN KMJ BYJ slide1 | 003 | Full ROI, IgAN_KMJ_BYJ_20221004_20220824 IgAN KMJ BYJ slide1 | 004 | Full ROI, IgAN_KMJ_BYJ_20221004_20220824 IgAN KMJ BYJ slide1 | 005 | Full ROI, IgAN_KMJ_BYJ_20221004_20220824 IgAN KMJ BYJ slide1 | 006 | Full ROI, IgAN_KMJ_BYJ_20221004_20220824 IgAN KMJ BYJ slide1 | 007 | Full ROI, IgAN_KMJ_BYJ_20221004_20220824 IgAN KMJ BYJ slide1 | 008 | Full ROI, IgAN_KMJ_BYJ_20221004_20220824 IgAN KMJ BYJ slide1 | 009 | Full ROI, IgAN_KMJ_BYJ_20221004_20220824 IgAN KMJ BYJ slide1 | 010 | Full ROI, IgAN_KMJ_BYJ_20221004_20220824 IgAN KMJ BYJ slide1 | 011 | Full ROI, IgAN_KMJ_BYJ_20221004_20220824 IgAN KMJ BYJ slide1 | 012 | Full ROI, IgAN_KMJ_BYJ_20221004_20220824 IgAN KMJ BYJ slide2 | 001 | Full ROI, IgAN_KMJ_BYJ_20221004_20220824 IgAN KMJ BYJ slide2 | 002 | Full ROI, IgAN_KMJ_BYJ_20221004_20220824 IgAN KMJ BYJ slide2 | 003 | Full ROI, IgAN_KMJ_BYJ_20221004_20220824 IgAN KMJ BYJ slide2 | 004 | Full ROI, IgAN_KMJ_BYJ_20221004_20220824 IgAN K ...
#
#   그룹 2: 5개 동일한 AOI
#     대표 AOI: 22.12.08 GeoMx Analysis(2)_HCC | 001 | Full ROI
#     중복 AOI: 23.01.06(2) HCC_HCC | 001 | Full ROI, 23.01.06_HY GeoMx analysis_HCC | 001 | Full ROI, 23.06.27 HCC2 vs HCC.x_HCC | 001 | Full ROI, GeoMx_Thuy,HY_HCC | 001 | Full ROI
#
#   그룹 3: 5개 동일한 AOI
#     대표 AOI: 22.12.08 GeoMx Analysis(2)_HCC | 002 | Full ROI
#     중복 AOI: 23.01.06(2) HCC_HCC | 002 | Full ROI, 23.01.06_HY GeoMx analysis_HCC | 002 | Full ROI, 23.06.27 HCC2 vs HCC.x_HCC | 002 | Full ROI, GeoMx_Thuy,HY_HCC | 002 | Full ROI
#
#   그룹 4: 5개 동일한 AOI
#     대표 AOI: 22.12.08 GeoMx Analysis(2)_HCC | 003 | Full ROI
#     중복 AOI: 23.01.06(2) HCC_HCC | 003 | Full ROI, 23.01.06_HY GeoMx analysis_HCC | 003 | Full ROI, 23.06.27 HCC2 vs HCC.x_HCC | 003 | Full ROI, GeoMx_Thuy,HY_HCC | 003 | Full ROI
#
#   그룹 5: 5개 동일한 AOI
#     대표 AOI: 22.12.08 GeoMx Analysis(2)_HCC | 004 | Full ROI
#     중복 AOI: 23.01.06(2) HCC_HCC | 004 | Full ROI, 23.01.06_HY GeoMx analysis_HCC | 004 | Full ROI, 23.06.27 HCC2 vs HCC.x_HCC | 004 | Full ROI, GeoMx_Thuy,HY_HCC | 004 | Full ROI
#
#   그룹 6: 5개 동일한 AOI
#     대표 AOI: 22.12.08 GeoMx Analysis(2)_HCC | 005 | Full ROI
#     중복 AOI: 23.01.06(2) HCC_HCC | 005 | Full ROI, 23.01.06_HY GeoMx analysis_HCC | 005 | Full ROI, 23.06.27 HCC2 vs HCC.x_HCC | 005 | Full ROI, GeoMx_Thuy,HY_HCC | 005 | Full ROI
#
#   그룹 7: 5개 동일한 AOI
#     대표 AOI: 22.12.08 GeoMx Analysis(2)_HCC | 006 | Full ROI
#     중복 AOI: 23.01.06(2) HCC_HCC | 006 | Full ROI, 23.01.06_HY GeoMx analysis_HCC | 006 | Full ROI, 23.06.27 HCC2 vs HCC.x_HCC | 006 | Full ROI, GeoMx_Thuy,HY_HCC | 006 | Full ROI
#
#   그룹 8: 5개 동일한 AOI
#     대표 AOI: 22.12.08 GeoMx Analysis(2)_HCC | 007 | Full ROI
#     중복 AOI: 23.01.06(2) HCC_HCC | 007 | Full ROI, 23.01.06_HY GeoMx analysis_HCC | 007 | Full ROI, 23.06.27 HCC2 vs HCC.x_HCC | 007 | Full ROI, GeoMx_Thuy,HY_HCC | 007 | Full ROI
#
#   그룹 9: 5개 동일한 AOI
#     대표 AOI: 22.12.08 GeoMx Analysis(2)_HCC | 008 | Full ROI
#     중복 AOI: 23.01.06(2) HCC_HCC | 008 | Full ROI, 23.01.06_HY GeoMx analysis_HCC | 008 | Full ROI, 23.06.27 HCC2 vs HCC.x_HCC | 008 | Full ROI, GeoMx_Thuy,HY_HCC | 008 | Full ROI
#
#   그룹 10: 5개 동일한 AOI
#     대표 AOI: 22.12.08 GeoMx Analysis(2)_HCC-x | 001 | Full ROI
#     중복 AOI: 23.01.06(2) HCC_HCC-x | 001 | Full ROI, 23.01.06_HY GeoMx analysis_HCC-x | 001 | Full ROI, 23.06.27 HCC2 vs HCC.x_HCC-x | 001 | Full ROI, GeoMx_Thuy,HY_HCC-x | 001 | Full ROI
#
#   그룹 11: 5개 동일한 AOI
#     대표 AOI: 22.12.08 GeoMx Analysis(2)_HCC-x | 002 | Full ROI
#     중복 AOI: 23.01.06(2) HCC_HCC-x | 002 | Full ROI, 23.01.06_HY GeoMx analysis_HCC-x | 002 | Full ROI, 23.06.27 HCC2 vs HCC.x_HCC-x | 002 | Full ROI, GeoMx_Thuy,HY_HCC-x | 002 | Full ROI
#
#   그룹 12: 5개 동일한 AOI
#     대표 AOI: 22.12.08 GeoMx Analysis(2)_HCC-x | 003 | Full ROI
#     중복 AOI: 23.01.06(2) HCC_HCC-x | 003 | Full ROI, 23.01.06_HY GeoMx analysis_HCC-x | 003 | Full ROI, 23.06.27 HCC2 vs HCC.x_HCC-x | 003 | Full ROI, GeoMx_Thuy,HY_HCC-x | 003 | Full ROI
#
#   그룹 13: 5개 동일한 AOI
#     대표 AOI: 22.12.08 GeoMx Analysis(2)_HCC-x | 004 | Full ROI
#     중복 AOI: 23.01.06(2) HCC_HCC-x | 004 | Full ROI, 23.01.06_HY GeoMx analysis_HCC-x | 004 | Full ROI, 23.06.27 HCC2 vs HCC.x_HCC-x | 004 | Full ROI, GeoMx_Thuy,HY_HCC-x | 004 | Full ROI
#
#   그룹 14: 2개 동일한 AOI
#     대표 AOI: Kidney TPL_GeoMx_R2_KidneyTPL_KMJ_R2_1_20221222 | 001 | Full ROI
#     중복 AOI: KT2_NEW_20230419_KidneyTPL_KMJ_R2_1_20221222 | 001 | Full ROI
#
#   그룹 15: 2개 동일한 AOI
#     대표 AOI: Kidney TPL_GeoMx_R2_KidneyTPL_KMJ_R2_1_20221222 | 002 | Full ROI
#     중복 AOI: KT2_NEW_20230419_KidneyTPL_KMJ_R2_1_20221222 | 002 | Full ROI
#
#   그룹 16: 2개 동일한 AOI
#     대표 AOI: Kidney TPL_GeoMx_R2_KidneyTPL_KMJ_R2_1_20221222 | 003 | Full ROI
#     중복 AOI: KT2_NEW_20230419_KidneyTPL_KMJ_R2_1_20221222 | 003 | Full ROI
#
#   그룹 17: 2개 동일한 AOI
#     대표 AOI: Kidney TPL_GeoMx_R2_KidneyTPL_KMJ_R2_1_20221222 | 004 | Full ROI
#     중복 AOI: KT2_NEW_20230419_KidneyTPL_KMJ_R2_1_20221222 | 004 | Full ROI
#
#   그룹 18: 2개 동일한 AOI
#     대표 AOI: Kidney TPL_GeoMx_R2_KidneyTPL_KMJ_R2_1_20221222 | 005 | Full ROI
#     중복 AOI: KT2_NEW_20230419_KidneyTPL_KMJ_R2_1_20221222 | 005 | Full ROI
#
#   그룹 19: 2개 동일한 AOI
#     대표 AOI: Kidney TPL_GeoMx_R2_KidneyTPL_KMJ_R2_1_20221222 | 006 | Full ROI
#     중복 AOI: KT2_NEW_20230419_KidneyTPL_KMJ_R2_1_20221222 | 006 | Full ROI
#
#   그룹 20: 2개 동일한 AOI
#     대표 AOI: Kidney TPL_GeoMx_R2_KidneyTPL_KMJ_R2_1_20221222 | 007 | Full ROI
#     중복 AOI: KT2_NEW_20230419_KidneyTPL_KMJ_R2_1_20221222 | 007 | Full ROI
#
#   그룹 21: 2개 동일한 AOI
#     대표 AOI: Kidney TPL_GeoMx_R2_KidneyTPL_KMJ_R2_1_20221222 | 008 | Full ROI
#     중복 AOI: KT2_NEW_20230419_KidneyTPL_KMJ_R2_1_20221222 | 008 | Full ROI
#
#   그룹 22: 2개 동일한 AOI
#     대표 AOI: Kidney TPL_GeoMx_R2_KidneyTPL_KMJ_R2_1_20221222 | 009 | Full ROI
#     중복 AOI: KT2_NEW_20230419_KidneyTPL_KMJ_R2_1_20221222 | 009 | Full ROI
#
#   그룹 23: 2개 동일한 AOI
#     대표 AOI: Kidney TPL_GeoMx_R2_KidneyTPL_KMJ_R2_1_20221222 | 010 | Full ROI
#     중복 AOI: KT2_NEW_20230419_KidneyTPL_KMJ_R2_1_20221222 | 010 | Full ROI
#
#   그룹 24: 2개 동일한 AOI
#     대표 AOI: Kidney TPL_GeoMx_R2_KidneyTPL_KMJ_R2_1_20221222 | 011 | Full ROI
#     중복 AOI: KT2_NEW_20230419_KidneyTPL_KMJ_R2_1_20221222 | 011 | Full ROI
#
#   그룹 25: 2개 동일한 AOI
#     대표 AOI: Kidney TPL_GeoMx_R2_KidneyTPL_KMJ_R2_1_20221222 | 012 | Full ROI
#     중복 AOI: KT2_NEW_20230419_KidneyTPL_KMJ_R2_1_20221222 | 012 | Full ROI
#
#   그룹 26: 2개 동일한 AOI
#     대표 AOI: Kidney TPL_GeoMx_R2_KidneyTPL_KMJ_R2_2_20221222 | 001 | Full ROI
#     중복 AOI: KT2_NEW_20230419_KidneyTPL_KMJ_R2_2_20221222 | 001 | Full ROI
#
#   그룹 27: 2개 동일한 AOI
#     대표 AOI: Kidney TPL_GeoMx_R2_KidneyTPL_KMJ_R2_2_20221222 | 002 | Full ROI
#     중복 AOI: KT2_NEW_20230419_KidneyTPL_KMJ_R2_2_20221222 | 002 | Full ROI
#
#   그룹 28: 2개 동일한 AOI
#     대표 AOI: Kidney TPL_GeoMx_R2_KidneyTPL_KMJ_R2_2_20221222 | 003 | Full ROI
#     중복 AOI: KT2_NEW_20230419_KidneyTPL_KMJ_R2_2_20221222 | 003 | Full ROI
#
#   그룹 29: 2개 동일한 AOI
#     대표 AOI: Kidney TPL_GeoMx_R2_KidneyTPL_KMJ_R2_2_20221222 | 004 | Full ROI
#     중복 AOI: KT2_NEW_20230419_KidneyTPL_KMJ_R2_2_20221222 | 004 | Full ROI
#
#   그룹 30: 2개 동일한 AOI
#     대표 AOI: Kidney TPL_GeoMx_R2_KidneyTPL_KMJ_R2_2_20221222 | 005 | Full ROI
#     중복 AOI: KT2_NEW_20230419_KidneyTPL_KMJ_R2_2_20221222 | 005 | Full ROI
#
#   그룹 31: 2개 동일한 AOI
#     대표 AOI: Kidney TPL_GeoMx_R2_KidneyTPL_KMJ_R2_2_20221222 | 006 | Full ROI
#     중복 AOI: KT2_NEW_20230419_KidneyTPL_KMJ_R2_2_20221222 | 006 | Full ROI
#
#   그룹 32: 2개 동일한 AOI
#     대표 AOI: Kidney TPL_GeoMx_R2_KidneyTPL_KMJ_R2_2_20221222 | 007 | Full ROI
#     중복 AOI: KT2_NEW_20230419_KidneyTPL_KMJ_R2_2_20221222 | 007 | Full ROI
#
#   그룹 33: 2개 동일한 AOI
#     대표 AOI: Kidney TPL_GeoMx_R2_KidneyTPL_KMJ_R2_2_20221222 | 008 | Full ROI
#     중복 AOI: KT2_NEW_20230419_KidneyTPL_KMJ_R2_2_20221222 | 008 | Full ROI
#
#   그룹 34: 2개 동일한 AOI
#     대표 AOI: Kidney TPL_GeoMx_R2_KidneyTPL_KMJ_R2_2_20221222 | 009 | Full ROI
#     중복 AOI: KT2_NEW_20230419_KidneyTPL_KMJ_R2_2_20221222 | 009 | Full ROI
#
#   그룹 35: 2개 동일한 AOI
#     대표 AOI: Kidney TPL_GeoMx_R2_KidneyTPL_KMJ_R2_2_20221222 | 010 | Full ROI
#     중복 AOI: KT2_NEW_20230419_KidneyTPL_KMJ_R2_2_20221222 | 010 | Full ROI
#
#   그룹 36: 2개 동일한 AOI
#     대표 AOI: Kidney TPL_GeoMx_R2_KidneyTPL_KMJ_R2_2_20221222 | 011 | Full ROI
#     중복 AOI: KT2_NEW_20230419_KidneyTPL_KMJ_R2_2_20221222 | 011 | Full ROI
#
#   그룹 37: 2개 동일한 AOI
#     대표 AOI: Kidney TPL_GeoMx_R2_KidneyTPL_KMJ_R2_2_20221222 | 012 | Full ROI
#     중복 AOI: KT2_NEW_20230419_KidneyTPL_KMJ_R2_2_20221222 | 012 | Full ROI
#
#   그룹 38: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_3_#13(1Y1M)_#2(6Y6M)_Geomx | 001 | PanCK+
#     중복 AOI: H Chung_Thymus #1_240921_3_#13(1Y1M)_#2(6Y6M)_Geomx | 001 | PanCK+, thymus normal_3_#13(1Y1M)_#2(6Y6M)_Geomx | 001 | PanCK+, thymus240401_3_#13(1Y1M)_#2(6Y6M)_Geomx | 001 | PanCK+
#
#   그룹 39: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_3_#13(1Y1M)_#2(6Y6M)_Geomx | 001 | T cell
#     중복 AOI: H Chung_Thymus #1_240921_3_#13(1Y1M)_#2(6Y6M)_Geomx | 001 | T cell, thymus normal_3_#13(1Y1M)_#2(6Y6M)_Geomx | 001 | T cell, thymus240401_3_#13(1Y1M)_#2(6Y6M)_Geomx | 001 | T cell
#
#   그룹 40: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_3_#13(1Y1M)_#2(6Y6M)_Geomx | 002 | PanCK+
#     중복 AOI: H Chung_Thymus #1_240921_3_#13(1Y1M)_#2(6Y6M)_Geomx | 002 | PanCK+, thymus normal_3_#13(1Y1M)_#2(6Y6M)_Geomx | 002 | PanCK+, thymus240401_3_#13(1Y1M)_#2(6Y6M)_Geomx | 002 | PanCK+
#
#   그룹 41: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_3_#13(1Y1M)_#2(6Y6M)_Geomx | 002 | T cell
#     중복 AOI: H Chung_Thymus #1_240921_3_#13(1Y1M)_#2(6Y6M)_Geomx | 002 | T cell, thymus normal_3_#13(1Y1M)_#2(6Y6M)_Geomx | 002 | T cell, thymus240401_3_#13(1Y1M)_#2(6Y6M)_Geomx | 002 | T cell
#
#   그룹 42: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_3_#13(1Y1M)_#2(6Y6M)_Geomx | 003 | T cell
#     중복 AOI: H Chung_Thymus #1_240921_3_#13(1Y1M)_#2(6Y6M)_Geomx | 003 | T cell, thymus normal_3_#13(1Y1M)_#2(6Y6M)_Geomx | 003 | T cell, thymus240401_3_#13(1Y1M)_#2(6Y6M)_Geomx | 003 | T cell
#
#   그룹 43: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_3_#13(1Y1M)_#2(6Y6M)_Geomx | 004 | PanCK+
#     중복 AOI: H Chung_Thymus #1_240921_3_#13(1Y1M)_#2(6Y6M)_Geomx | 004 | PanCK+, thymus normal_3_#13(1Y1M)_#2(6Y6M)_Geomx | 004 | PanCK+, thymus240401_3_#13(1Y1M)_#2(6Y6M)_Geomx | 004 | PanCK+
#
#   그룹 44: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_3_#13(1Y1M)_#2(6Y6M)_Geomx | 004 | T cell
#     중복 AOI: H Chung_Thymus #1_240921_3_#13(1Y1M)_#2(6Y6M)_Geomx | 004 | T cell, thymus normal_3_#13(1Y1M)_#2(6Y6M)_Geomx | 004 | T cell, thymus240401_3_#13(1Y1M)_#2(6Y6M)_Geomx | 004 | T cell
#
#   그룹 45: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_3_#13(1Y1M)_#2(6Y6M)_Geomx | 005 | PanCK+
#     중복 AOI: H Chung_Thymus #1_240921_3_#13(1Y1M)_#2(6Y6M)_Geomx | 005 | PanCK+, thymus normal_3_#13(1Y1M)_#2(6Y6M)_Geomx | 005 | PanCK+, thymus240401_3_#13(1Y1M)_#2(6Y6M)_Geomx | 005 | PanCK+
#
#   그룹 46: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_3_#13(1Y1M)_#2(6Y6M)_Geomx | 005 | T cell
#     중복 AOI: H Chung_Thymus #1_240921_3_#13(1Y1M)_#2(6Y6M)_Geomx | 005 | T cell, thymus normal_3_#13(1Y1M)_#2(6Y6M)_Geomx | 005 | T cell, thymus240401_3_#13(1Y1M)_#2(6Y6M)_Geomx | 005 | T cell
#
#   그룹 47: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_3_#13(1Y1M)_#2(6Y6M)_Geomx | 006 | PanCK+
#     중복 AOI: H Chung_Thymus #1_240921_3_#13(1Y1M)_#2(6Y6M)_Geomx | 006 | PanCK+, thymus normal_3_#13(1Y1M)_#2(6Y6M)_Geomx | 006 | PanCK+, thymus240401_3_#13(1Y1M)_#2(6Y6M)_Geomx | 006 | PanCK+
#
#   그룹 48: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_3_#13(1Y1M)_#2(6Y6M)_Geomx | 006 | T cell
#     중복 AOI: H Chung_Thymus #1_240921_3_#13(1Y1M)_#2(6Y6M)_Geomx | 006 | T cell, thymus normal_3_#13(1Y1M)_#2(6Y6M)_Geomx | 006 | T cell, thymus240401_3_#13(1Y1M)_#2(6Y6M)_Geomx | 006 | T cell
#
#   그룹 49: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_3_#13(1Y1M)_#2(6Y6M)_Geomx | 007 | PanCK+
#     중복 AOI: H Chung_Thymus #1_240921_3_#13(1Y1M)_#2(6Y6M)_Geomx | 007 | PanCK+, thymus normal_3_#13(1Y1M)_#2(6Y6M)_Geomx | 007 | PanCK+, thymus240401_3_#13(1Y1M)_#2(6Y6M)_Geomx | 007 | PanCK+
#
#   그룹 50: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_3_#13(1Y1M)_#2(6Y6M)_Geomx | 007 | T cell
#     중복 AOI: H Chung_Thymus #1_240921_3_#13(1Y1M)_#2(6Y6M)_Geomx | 007 | T cell, thymus normal_3_#13(1Y1M)_#2(6Y6M)_Geomx | 007 | T cell, thymus240401_3_#13(1Y1M)_#2(6Y6M)_Geomx | 007 | T cell
#
#   그룹 51: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_3_#13(1Y1M)_#2(6Y6M)_Geomx | 008 | PanCK+
#     중복 AOI: H Chung_Thymus #1_240921_3_#13(1Y1M)_#2(6Y6M)_Geomx | 008 | PanCK+, thymus normal_3_#13(1Y1M)_#2(6Y6M)_Geomx | 008 | PanCK+, thymus240401_3_#13(1Y1M)_#2(6Y6M)_Geomx | 008 | PanCK+
#
#   그룹 52: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_3_#13(1Y1M)_#2(6Y6M)_Geomx | 008 | T cell
#     중복 AOI: H Chung_Thymus #1_240921_3_#13(1Y1M)_#2(6Y6M)_Geomx | 008 | T cell, thymus normal_3_#13(1Y1M)_#2(6Y6M)_Geomx | 008 | T cell, thymus240401_3_#13(1Y1M)_#2(6Y6M)_Geomx | 008 | T cell
#
#   그룹 53: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_3_#13(1Y1M)_#2(6Y6M)_Geomx | 009 | PanCK+
#     중복 AOI: H Chung_Thymus #1_240921_3_#13(1Y1M)_#2(6Y6M)_Geomx | 009 | PanCK+, thymus normal_3_#13(1Y1M)_#2(6Y6M)_Geomx | 009 | PanCK+, thymus240401_3_#13(1Y1M)_#2(6Y6M)_Geomx | 009 | PanCK+
#
#   그룹 54: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_3_#13(1Y1M)_#2(6Y6M)_Geomx | 009 | T cell
#     중복 AOI: H Chung_Thymus #1_240921_3_#13(1Y1M)_#2(6Y6M)_Geomx | 009 | T cell, thymus normal_3_#13(1Y1M)_#2(6Y6M)_Geomx | 009 | T cell, thymus240401_3_#13(1Y1M)_#2(6Y6M)_Geomx | 009 | T cell
#
#   그룹 55: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_3_#13(1Y1M)_#2(6Y6M)_Geomx | 012 | PanCK+
#     중복 AOI: H Chung_Thymus #1_240921_3_#13(1Y1M)_#2(6Y6M)_Geomx | 012 | PanCK+, thymus normal_3_#13(1Y1M)_#2(6Y6M)_Geomx | 012 | PanCK+, thymus240401_3_#13(1Y1M)_#2(6Y6M)_Geomx | 012 | PanCK+
#
#   그룹 56: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_3_#13(1Y1M)_#2(6Y6M)_Geomx | 012 | T cell
#     중복 AOI: H Chung_Thymus #1_240921_3_#13(1Y1M)_#2(6Y6M)_Geomx | 012 | T cell, thymus normal_3_#13(1Y1M)_#2(6Y6M)_Geomx | 012 | T cell, thymus240401_3_#13(1Y1M)_#2(6Y6M)_Geomx | 012 | T cell
#
#   그룹 57: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_3_#13(1Y1M)_#2(6Y6M)_Geomx | 013 | PanCK+
#     중복 AOI: H Chung_Thymus #1_240921_3_#13(1Y1M)_#2(6Y6M)_Geomx | 013 | PanCK+, thymus normal_3_#13(1Y1M)_#2(6Y6M)_Geomx | 013 | PanCK+, thymus240401_3_#13(1Y1M)_#2(6Y6M)_Geomx | 013 | PanCK+
#
#   그룹 58: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_3_#13(1Y1M)_#2(6Y6M)_Geomx | 013 | T cell
#     중복 AOI: H Chung_Thymus #1_240921_3_#13(1Y1M)_#2(6Y6M)_Geomx | 013 | T cell, thymus normal_3_#13(1Y1M)_#2(6Y6M)_Geomx | 013 | T cell, thymus240401_3_#13(1Y1M)_#2(6Y6M)_Geomx | 013 | T cell
#
#   그룹 59: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_3_#13(1Y1M)_#2(6Y6M)_Geomx | 014 | PanCK+
#     중복 AOI: H Chung_Thymus #1_240921_3_#13(1Y1M)_#2(6Y6M)_Geomx | 014 | PanCK+, thymus normal_3_#13(1Y1M)_#2(6Y6M)_Geomx | 014 | PanCK+, thymus240401_3_#13(1Y1M)_#2(6Y6M)_Geomx | 014 | PanCK+
#
#   그룹 60: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_3_#13(1Y1M)_#2(6Y6M)_Geomx | 014 | T cell
#     중복 AOI: H Chung_Thymus #1_240921_3_#13(1Y1M)_#2(6Y6M)_Geomx | 014 | T cell, thymus normal_3_#13(1Y1M)_#2(6Y6M)_Geomx | 014 | T cell, thymus240401_3_#13(1Y1M)_#2(6Y6M)_Geomx | 014 | T cell
#
#   그룹 61: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_1_#5(1M)_#3(2M)_Geomx | 001 | PanCK+
#     중복 AOI: H Chung_Thymus #1_240921_1_#5(1M)_#3(2M)_Geomx | 001 | PanCK+, thymus normal_1_#5(1M)_#3(2M)_Geomx | 001 | PanCK+, thymus240401_1_#5(1M)_#3(2M)_Geomx | 001 | PanCK+
#
#   그룹 62: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_1_#5(1M)_#3(2M)_Geomx | 001 | CD3+
#     중복 AOI: H Chung_Thymus #1_240921_1_#5(1M)_#3(2M)_Geomx | 001 | CD3+, thymus normal_1_#5(1M)_#3(2M)_Geomx | 001 | CD3+, thymus240401_1_#5(1M)_#3(2M)_Geomx | 001 | CD3+
#
#   그룹 63: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_1_#5(1M)_#3(2M)_Geomx | 002 | PanCK+
#     중복 AOI: H Chung_Thymus #1_240921_1_#5(1M)_#3(2M)_Geomx | 002 | PanCK+, thymus normal_1_#5(1M)_#3(2M)_Geomx | 002 | PanCK+, thymus240401_1_#5(1M)_#3(2M)_Geomx | 002 | PanCK+
#
#   그룹 64: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_1_#5(1M)_#3(2M)_Geomx | 002 | CD3+
#     중복 AOI: H Chung_Thymus #1_240921_1_#5(1M)_#3(2M)_Geomx | 002 | CD3+, thymus normal_1_#5(1M)_#3(2M)_Geomx | 002 | CD3+, thymus240401_1_#5(1M)_#3(2M)_Geomx | 002 | CD3+
#
#   그룹 65: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_1_#5(1M)_#3(2M)_Geomx | 003 | PanCK+
#     중복 AOI: H Chung_Thymus #1_240921_1_#5(1M)_#3(2M)_Geomx | 003 | PanCK+, thymus normal_1_#5(1M)_#3(2M)_Geomx | 003 | PanCK+, thymus240401_1_#5(1M)_#3(2M)_Geomx | 003 | PanCK+
#
#   그룹 66: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_1_#5(1M)_#3(2M)_Geomx | 003 | CD3+
#     중복 AOI: H Chung_Thymus #1_240921_1_#5(1M)_#3(2M)_Geomx | 003 | CD3+, thymus normal_1_#5(1M)_#3(2M)_Geomx | 003 | CD3+, thymus240401_1_#5(1M)_#3(2M)_Geomx | 003 | CD3+
#
#   그룹 67: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_1_#5(1M)_#3(2M)_Geomx | 004 | PanCK+
#     중복 AOI: H Chung_Thymus #1_240921_1_#5(1M)_#3(2M)_Geomx | 004 | PanCK+, thymus normal_1_#5(1M)_#3(2M)_Geomx | 004 | PanCK+, thymus240401_1_#5(1M)_#3(2M)_Geomx | 004 | PanCK+
#
#   그룹 68: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_1_#5(1M)_#3(2M)_Geomx | 004 | CD3+
#     중복 AOI: H Chung_Thymus #1_240921_1_#5(1M)_#3(2M)_Geomx | 004 | CD3+, thymus normal_1_#5(1M)_#3(2M)_Geomx | 004 | CD3+, thymus240401_1_#5(1M)_#3(2M)_Geomx | 004 | CD3+
#
#   그룹 69: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_1_#5(1M)_#3(2M)_Geomx | 005 | PanCK+
#     중복 AOI: H Chung_Thymus #1_240921_1_#5(1M)_#3(2M)_Geomx | 005 | PanCK+, thymus normal_1_#5(1M)_#3(2M)_Geomx | 005 | PanCK+, thymus240401_1_#5(1M)_#3(2M)_Geomx | 005 | PanCK+
#
#   그룹 70: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_1_#5(1M)_#3(2M)_Geomx | 005 | CD3+
#     중복 AOI: H Chung_Thymus #1_240921_1_#5(1M)_#3(2M)_Geomx | 005 | CD3+, thymus normal_1_#5(1M)_#3(2M)_Geomx | 005 | CD3+, thymus240401_1_#5(1M)_#3(2M)_Geomx | 005 | CD3+
#
#   그룹 71: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_1_#5(1M)_#3(2M)_Geomx | 006 | PanCK+
#     중복 AOI: H Chung_Thymus #1_240921_1_#5(1M)_#3(2M)_Geomx | 006 | PanCK+, thymus normal_1_#5(1M)_#3(2M)_Geomx | 006 | PanCK+, thymus240401_1_#5(1M)_#3(2M)_Geomx | 006 | PanCK+
#
#   그룹 72: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_1_#5(1M)_#3(2M)_Geomx | 006 | CD3+
#     중복 AOI: H Chung_Thymus #1_240921_1_#5(1M)_#3(2M)_Geomx | 006 | CD3+, thymus normal_1_#5(1M)_#3(2M)_Geomx | 006 | CD3+, thymus240401_1_#5(1M)_#3(2M)_Geomx | 006 | CD3+
#
#   그룹 73: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_1_#5(1M)_#3(2M)_Geomx | 007 | PanCK+
#     중복 AOI: H Chung_Thymus #1_240921_1_#5(1M)_#3(2M)_Geomx | 007 | PanCK+, thymus normal_1_#5(1M)_#3(2M)_Geomx | 007 | PanCK+, thymus240401_1_#5(1M)_#3(2M)_Geomx | 007 | PanCK+
#
#   그룹 74: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_1_#5(1M)_#3(2M)_Geomx | 007 | CD3+
#     중복 AOI: H Chung_Thymus #1_240921_1_#5(1M)_#3(2M)_Geomx | 007 | CD3+, thymus normal_1_#5(1M)_#3(2M)_Geomx | 007 | CD3+, thymus240401_1_#5(1M)_#3(2M)_Geomx | 007 | CD3+
#
#   그룹 75: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_1_#5(1M)_#3(2M)_Geomx | 008 | PanCK+
#     중복 AOI: H Chung_Thymus #1_240921_1_#5(1M)_#3(2M)_Geomx | 008 | PanCK+, thymus normal_1_#5(1M)_#3(2M)_Geomx | 008 | PanCK+, thymus240401_1_#5(1M)_#3(2M)_Geomx | 008 | PanCK+
#
#   그룹 76: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_1_#5(1M)_#3(2M)_Geomx | 008 | CD3+
#     중복 AOI: H Chung_Thymus #1_240921_1_#5(1M)_#3(2M)_Geomx | 008 | CD3+, thymus normal_1_#5(1M)_#3(2M)_Geomx | 008 | CD3+, thymus240401_1_#5(1M)_#3(2M)_Geomx | 008 | CD3+
#
#   그룹 77: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_1_#5(1M)_#3(2M)_Geomx | 009 | PanCK+
#     중복 AOI: H Chung_Thymus #1_240921_1_#5(1M)_#3(2M)_Geomx | 009 | PanCK+, thymus normal_1_#5(1M)_#3(2M)_Geomx | 009 | PanCK+, thymus240401_1_#5(1M)_#3(2M)_Geomx | 009 | PanCK+
#
#   그룹 78: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_1_#5(1M)_#3(2M)_Geomx | 009 | CD3+
#     중복 AOI: H Chung_Thymus #1_240921_1_#5(1M)_#3(2M)_Geomx | 009 | CD3+, thymus normal_1_#5(1M)_#3(2M)_Geomx | 009 | CD3+, thymus240401_1_#5(1M)_#3(2M)_Geomx | 009 | CD3+
#
#   그룹 79: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_1_#5(1M)_#3(2M)_Geomx | 010 | PanCK+
#     중복 AOI: H Chung_Thymus #1_240921_1_#5(1M)_#3(2M)_Geomx | 010 | PanCK+, thymus normal_1_#5(1M)_#3(2M)_Geomx | 010 | PanCK+, thymus240401_1_#5(1M)_#3(2M)_Geomx | 010 | PanCK+
#
#   그룹 80: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_1_#5(1M)_#3(2M)_Geomx | 010 | CD3+
#     중복 AOI: H Chung_Thymus #1_240921_1_#5(1M)_#3(2M)_Geomx | 010 | CD3+, thymus normal_1_#5(1M)_#3(2M)_Geomx | 010 | CD3+, thymus240401_1_#5(1M)_#3(2M)_Geomx | 010 | CD3+
#
#   그룹 81: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_1_#5(1M)_#3(2M)_Geomx | 011 | PanCK+
#     중복 AOI: H Chung_Thymus #1_240921_1_#5(1M)_#3(2M)_Geomx | 011 | PanCK+, thymus normal_1_#5(1M)_#3(2M)_Geomx | 011 | PanCK+, thymus240401_1_#5(1M)_#3(2M)_Geomx | 011 | PanCK+
#
#   그룹 82: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_1_#5(1M)_#3(2M)_Geomx | 011 | CD3+
#     중복 AOI: H Chung_Thymus #1_240921_1_#5(1M)_#3(2M)_Geomx | 011 | CD3+, thymus normal_1_#5(1M)_#3(2M)_Geomx | 011 | CD3+, thymus240401_1_#5(1M)_#3(2M)_Geomx | 011 | CD3+
#
#   그룹 83: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_1_#5(1M)_#3(2M)_Geomx | 012 | PanCK+
#     중복 AOI: H Chung_Thymus #1_240921_1_#5(1M)_#3(2M)_Geomx | 012 | PanCK+, thymus normal_1_#5(1M)_#3(2M)_Geomx | 012 | PanCK+, thymus240401_1_#5(1M)_#3(2M)_Geomx | 012 | PanCK+
#
#   그룹 84: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_1_#5(1M)_#3(2M)_Geomx | 012 | CD3+
#     중복 AOI: H Chung_Thymus #1_240921_1_#5(1M)_#3(2M)_Geomx | 012 | CD3+, thymus normal_1_#5(1M)_#3(2M)_Geomx | 012 | CD3+, thymus240401_1_#5(1M)_#3(2M)_Geomx | 012 | CD3+
#
#   그룹 85: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_2_#16(4M)_#6(6M)_Geomx | 001 | PanCK+
#     중복 AOI: H Chung_Thymus #1_240921_2_#16(4M)_#6(6M)_Geomx | 001 | PanCK+, thymus normal_2_#16(4M)_#6(6M)_Geomx | 001 | PanCK+, thymus240401_2_#16(4M)_#6(6M)_Geomx | 001 | PanCK+
#
#   그룹 86: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_2_#16(4M)_#6(6M)_Geomx | 001 | T cell
#     중복 AOI: H Chung_Thymus #1_240921_2_#16(4M)_#6(6M)_Geomx | 001 | T cell, thymus normal_2_#16(4M)_#6(6M)_Geomx | 001 | T cell, thymus240401_2_#16(4M)_#6(6M)_Geomx | 001 | T cell
#
#   그룹 87: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_2_#16(4M)_#6(6M)_Geomx | 002 | PanCK+
#     중복 AOI: H Chung_Thymus #1_240921_2_#16(4M)_#6(6M)_Geomx | 002 | PanCK+, thymus normal_2_#16(4M)_#6(6M)_Geomx | 002 | PanCK+, thymus240401_2_#16(4M)_#6(6M)_Geomx | 002 | PanCK+
#
#   그룹 88: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_2_#16(4M)_#6(6M)_Geomx | 002 | T cell
#     중복 AOI: H Chung_Thymus #1_240921_2_#16(4M)_#6(6M)_Geomx | 002 | T cell, thymus normal_2_#16(4M)_#6(6M)_Geomx | 002 | T cell, thymus240401_2_#16(4M)_#6(6M)_Geomx | 002 | T cell
#
#   그룹 89: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_2_#16(4M)_#6(6M)_Geomx | 003 | PanCK+
#     중복 AOI: H Chung_Thymus #1_240921_2_#16(4M)_#6(6M)_Geomx | 003 | PanCK+, thymus normal_2_#16(4M)_#6(6M)_Geomx | 003 | PanCK+, thymus240401_2_#16(4M)_#6(6M)_Geomx | 003 | PanCK+
#
#   그룹 90: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_2_#16(4M)_#6(6M)_Geomx | 003 | T cell
#     중복 AOI: H Chung_Thymus #1_240921_2_#16(4M)_#6(6M)_Geomx | 003 | T cell, thymus normal_2_#16(4M)_#6(6M)_Geomx | 003 | T cell, thymus240401_2_#16(4M)_#6(6M)_Geomx | 003 | T cell
#
#   그룹 91: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_2_#16(4M)_#6(6M)_Geomx | 004 | PanCK+
#     중복 AOI: H Chung_Thymus #1_240921_2_#16(4M)_#6(6M)_Geomx | 004 | PanCK+, thymus normal_2_#16(4M)_#6(6M)_Geomx | 004 | PanCK+, thymus240401_2_#16(4M)_#6(6M)_Geomx | 004 | PanCK+
#
#   그룹 92: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_2_#16(4M)_#6(6M)_Geomx | 004 | T cell
#     중복 AOI: H Chung_Thymus #1_240921_2_#16(4M)_#6(6M)_Geomx | 004 | T cell, thymus normal_2_#16(4M)_#6(6M)_Geomx | 004 | T cell, thymus240401_2_#16(4M)_#6(6M)_Geomx | 004 | T cell
#
#   그룹 93: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_2_#16(4M)_#6(6M)_Geomx | 005 | PanCK+
#     중복 AOI: H Chung_Thymus #1_240921_2_#16(4M)_#6(6M)_Geomx | 005 | PanCK+, thymus normal_2_#16(4M)_#6(6M)_Geomx | 005 | PanCK+, thymus240401_2_#16(4M)_#6(6M)_Geomx | 005 | PanCK+
#
#   그룹 94: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_2_#16(4M)_#6(6M)_Geomx | 005 | T cell
#     중복 AOI: H Chung_Thymus #1_240921_2_#16(4M)_#6(6M)_Geomx | 005 | T cell, thymus normal_2_#16(4M)_#6(6M)_Geomx | 005 | T cell, thymus240401_2_#16(4M)_#6(6M)_Geomx | 005 | T cell
#
#   그룹 95: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_2_#16(4M)_#6(6M)_Geomx | 006 | PanCK+
#     중복 AOI: H Chung_Thymus #1_240921_2_#16(4M)_#6(6M)_Geomx | 006 | PanCK+, thymus normal_2_#16(4M)_#6(6M)_Geomx | 006 | PanCK+, thymus240401_2_#16(4M)_#6(6M)_Geomx | 006 | PanCK+
#
#   그룹 96: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_2_#16(4M)_#6(6M)_Geomx | 006 | T cell
#     중복 AOI: H Chung_Thymus #1_240921_2_#16(4M)_#6(6M)_Geomx | 006 | T cell, thymus normal_2_#16(4M)_#6(6M)_Geomx | 006 | T cell, thymus240401_2_#16(4M)_#6(6M)_Geomx | 006 | T cell
#
#   그룹 97: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_2_#16(4M)_#6(6M)_Geomx | 007 | PanCK+
#     중복 AOI: H Chung_Thymus #1_240921_2_#16(4M)_#6(6M)_Geomx | 007 | PanCK+, thymus normal_2_#16(4M)_#6(6M)_Geomx | 007 | PanCK+, thymus240401_2_#16(4M)_#6(6M)_Geomx | 007 | PanCK+
#
#   그룹 98: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_2_#16(4M)_#6(6M)_Geomx | 007 | T cell
#     중복 AOI: H Chung_Thymus #1_240921_2_#16(4M)_#6(6M)_Geomx | 007 | T cell, thymus normal_2_#16(4M)_#6(6M)_Geomx | 007 | T cell, thymus240401_2_#16(4M)_#6(6M)_Geomx | 007 | T cell
#
#   그룹 99: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_2_#16(4M)_#6(6M)_Geomx | 008 | PanCK+
#     중복 AOI: H Chung_Thymus #1_240921_2_#16(4M)_#6(6M)_Geomx | 008 | PanCK+, thymus normal_2_#16(4M)_#6(6M)_Geomx | 008 | PanCK+, thymus240401_2_#16(4M)_#6(6M)_Geomx | 008 | PanCK+
#
#   그룹 100: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_2_#16(4M)_#6(6M)_Geomx | 008 | T cell
#     중복 AOI: H Chung_Thymus #1_240921_2_#16(4M)_#6(6M)_Geomx | 008 | T cell, thymus normal_2_#16(4M)_#6(6M)_Geomx | 008 | T cell, thymus240401_2_#16(4M)_#6(6M)_Geomx | 008 | T cell
#
#   그룹 101: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_2_#16(4M)_#6(6M)_Geomx | 009 | PanCK+
#     중복 AOI: H Chung_Thymus #1_240921_2_#16(4M)_#6(6M)_Geomx | 009 | PanCK+, thymus normal_2_#16(4M)_#6(6M)_Geomx | 009 | PanCK+, thymus240401_2_#16(4M)_#6(6M)_Geomx | 009 | PanCK+
#
#   그룹 102: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_2_#16(4M)_#6(6M)_Geomx | 009 | T cell
#     중복 AOI: H Chung_Thymus #1_240921_2_#16(4M)_#6(6M)_Geomx | 009 | T cell, thymus normal_2_#16(4M)_#6(6M)_Geomx | 009 | T cell, thymus240401_2_#16(4M)_#6(6M)_Geomx | 009 | T cell
#
#   그룹 103: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_2_#16(4M)_#6(6M)_Geomx | 010 | PanCK+
#     중복 AOI: H Chung_Thymus #1_240921_2_#16(4M)_#6(6M)_Geomx | 010 | PanCK+, thymus normal_2_#16(4M)_#6(6M)_Geomx | 010 | PanCK+, thymus240401_2_#16(4M)_#6(6M)_Geomx | 010 | PanCK+
#
#   그룹 104: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_2_#16(4M)_#6(6M)_Geomx | 010 | T cell
#     중복 AOI: H Chung_Thymus #1_240921_2_#16(4M)_#6(6M)_Geomx | 010 | T cell, thymus normal_2_#16(4M)_#6(6M)_Geomx | 010 | T cell, thymus240401_2_#16(4M)_#6(6M)_Geomx | 010 | T cell
#
#   그룹 105: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_2_#16(4M)_#6(6M)_Geomx | 011 | PanCK+
#     중복 AOI: H Chung_Thymus #1_240921_2_#16(4M)_#6(6M)_Geomx | 011 | PanCK+, thymus normal_2_#16(4M)_#6(6M)_Geomx | 011 | PanCK+, thymus240401_2_#16(4M)_#6(6M)_Geomx | 011 | PanCK+
#
#   그룹 106: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_2_#16(4M)_#6(6M)_Geomx | 011 | T cell
#     중복 AOI: H Chung_Thymus #1_240921_2_#16(4M)_#6(6M)_Geomx | 011 | T cell, thymus normal_2_#16(4M)_#6(6M)_Geomx | 011 | T cell, thymus240401_2_#16(4M)_#6(6M)_Geomx | 011 | T cell
#
#   그룹 107: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_2_#16(4M)_#6(6M)_Geomx | 012 | PanCK+
#     중복 AOI: H Chung_Thymus #1_240921_2_#16(4M)_#6(6M)_Geomx | 012 | PanCK+, thymus normal_2_#16(4M)_#6(6M)_Geomx | 012 | PanCK+, thymus240401_2_#16(4M)_#6(6M)_Geomx | 012 | PanCK+
#
#   그룹 108: 4개 동일한 AOI
#     대표 AOI: Final Thymus normal_2_#16(4M)_#6(6M)_Geomx | 012 | T cell
#     중복 AOI: H Chung_Thymus #1_240921_2_#16(4M)_#6(6M)_Geomx | 012 | T cell, thymus normal_2_#16(4M)_#6(6M)_Geomx | 012 | T cell, thymus240401_2_#16(4M)_#6(6M)_Geomx | 012 | T cell
#
#   그룹 109: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ A1_20221122 | 001 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ A1_20221122 | 001 | Full ROI
#
#   그룹 110: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ A1_20221122 | 002 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ A1_20221122 | 002 | Full ROI
#
#   그룹 111: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ A1_20221122 | 003 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ A1_20221122 | 003 | Full ROI
#
#   그룹 112: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ A1_20221122 | 004 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ A1_20221122 | 004 | Full ROI
#
#   그룹 113: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ A1_20221122 | 005 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ A1_20221122 | 005 | Full ROI
#
#   그룹 114: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ A1_20221122 | 006 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ A1_20221122 | 006 | Full ROI
#
#   그룹 115: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ A1_20221122 | 007 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ A1_20221122 | 007 | Full ROI
#
#   그룹 116: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ A1_20221122 | 008 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ A1_20221122 | 008 | Full ROI
#
#   그룹 117: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ A1_20221122 | 009 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ A1_20221122 | 009 | Full ROI
#
#   그룹 118: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ A1_20221122 | 010 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ A1_20221122 | 010 | Full ROI
#
#   그룹 119: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ A1_20221122 | 011 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ A1_20221122 | 011 | Full ROI
#
#   그룹 120: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ A1_20221122 | 012 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ A1_20221122 | 012 | Full ROI
#
#   그룹 121: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ A2_20221122 | 001 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ A2_20221122 | 001 | Full ROI
#
#   그룹 122: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ A2_20221122 | 002 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ A2_20221122 | 002 | Full ROI
#
#   그룹 123: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ A2_20221122 | 003 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ A2_20221122 | 003 | Full ROI
#
#   그룹 124: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ A2_20221122 | 004 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ A2_20221122 | 004 | Full ROI
#
#   그룹 125: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ A2_20221122 | 005 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ A2_20221122 | 005 | Full ROI
#
#   그룹 126: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ A2_20221122 | 006 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ A2_20221122 | 006 | Full ROI
#
#   그룹 127: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ A2_20221122 | 007 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ A2_20221122 | 007 | Full ROI
#
#   그룹 128: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ A2_20221122 | 008 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ A2_20221122 | 008 | Full ROI
#
#   그룹 129: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ A2_20221122 | 009 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ A2_20221122 | 009 | Full ROI
#
#   그룹 130: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ A2_20221122 | 010 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ A2_20221122 | 010 | Full ROI
#
#   그룹 131: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ A2_20221122 | 011 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ A2_20221122 | 011 | Full ROI
#
#   그룹 132: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ A2_20221122 | 012 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ A2_20221122 | 012 | Full ROI
#
#   그룹 133: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ A3_20221122 | 001 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ A3_20221122 | 001 | Full ROI
#
#   그룹 134: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ A3_20221122 | 002 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ A3_20221122 | 002 | Full ROI
#
#   그룹 135: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ A3_20221122 | 003 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ A3_20221122 | 003 | Full ROI
#
#   그룹 136: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ A3_20221122 | 004 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ A3_20221122 | 004 | Full ROI
#
#   그룹 137: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ A3_20221122 | 005 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ A3_20221122 | 005 | Full ROI
#
#   그룹 138: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ A3_20221122 | 006 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ A3_20221122 | 006 | Full ROI
#
#   그룹 139: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ A3_20221122 | 007 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ A3_20221122 | 007 | Full ROI
#
#   그룹 140: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ A3_20221122 | 008 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ A3_20221122 | 008 | Full ROI
#
#   그룹 141: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ A3_20221122 | 009 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ A3_20221122 | 009 | Full ROI
#
#   그룹 142: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ A3_20221122 | 010 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ A3_20221122 | 010 | Full ROI
#
#   그룹 143: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ A3_20221122 | 011 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ A3_20221122 | 011 | Full ROI
#
#   그룹 144: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ A3_20221122 | 012 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ A3_20221122 | 012 | Full ROI
#
#   그룹 145: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ A4_20221122 | 001 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ A4_20221122 | 001 | Full ROI
#
#   그룹 146: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ A4_20221122 | 002 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ A4_20221122 | 002 | Full ROI
#
#   그룹 147: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ A4_20221122 | 003 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ A4_20221122 | 003 | Full ROI
#
#   그룹 148: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ A4_20221122 | 004 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ A4_20221122 | 004 | Full ROI
#
#   그룹 149: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ A4_20221122 | 005 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ A4_20221122 | 005 | Full ROI
#
#   그룹 150: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ A4_20221122 | 006 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ A4_20221122 | 006 | Full ROI
#
#   그룹 151: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ A4_20221122 | 007 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ A4_20221122 | 007 | Full ROI
#
#   그룹 152: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ A4_20221122 | 008 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ A4_20221122 | 008 | Full ROI
#
#   그룹 153: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ A4_20221122 | 009 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ A4_20221122 | 009 | Full ROI
#
#   그룹 154: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ A4_20221122 | 010 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ A4_20221122 | 010 | Full ROI
#
#   그룹 155: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ A4_20221122 | 011 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ A4_20221122 | 011 | Full ROI
#
#   그룹 156: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ A4_20221122 | 012 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ A4_20221122 | 012 | Full ROI
#
#   그룹 157: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ_B1_20221125 | 001 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ_B1_20221125 | 001 | Full ROI
#
#   그룹 158: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ_B1_20221125 | 002 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ_B1_20221125 | 002 | Full ROI
#
#   그룹 159: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ_B1_20221125 | 003 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ_B1_20221125 | 003 | Full ROI
#
#   그룹 160: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ_B1_20221125 | 004 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ_B1_20221125 | 004 | Full ROI
#
#   그룹 161: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ_B1_20221125 | 005 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ_B1_20221125 | 005 | Full ROI
#
#   그룹 162: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ_B1_20221125 | 006 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ_B1_20221125 | 006 | Full ROI
#
#   그룹 163: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ_B1_20221125 | 007 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ_B1_20221125 | 007 | Full ROI
#
#   그룹 164: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ_B1_20221125 | 008 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ_B1_20221125 | 008 | Full ROI
#
#   그룹 165: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ_B1_20221125 | 009 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ_B1_20221125 | 009 | Full ROI
#
#   그룹 166: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ_B1_20221125 | 010 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ_B1_20221125 | 010 | Full ROI
#
#   그룹 167: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ_B1_20221125 | 011 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ_B1_20221125 | 011 | Full ROI
#
#   그룹 168: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ_B1_20221125 | 012 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ_B1_20221125 | 012 | Full ROI
#
#   그룹 169: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ_B2_20221125 | 001 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ_B2_20221125 | 001 | Full ROI
#
#   그룹 170: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ_B2_20221125 | 002 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ_B2_20221125 | 002 | Full ROI
#
#   그룹 171: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ_B2_20221125 | 003 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ_B2_20221125 | 003 | Full ROI
#
#   그룹 172: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ_B2_20221125 | 004 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ_B2_20221125 | 004 | Full ROI
#
#   그룹 173: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ_B2_20221125 | 005 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ_B2_20221125 | 005 | Full ROI
#
#   그룹 174: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ_B2_20221125 | 006 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ_B2_20221125 | 006 | Full ROI
#
#   그룹 175: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ_B2_20221125 | 007 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ_B2_20221125 | 007 | Full ROI
#
#   그룹 176: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ_B2_20221125 | 008 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ_B2_20221125 | 008 | Full ROI
#
#   그룹 177: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ_B2_20221125 | 009 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ_B2_20221125 | 009 | Full ROI
#
#   그룹 178: 2개 동일한 AOI
#     대표 AOI: MN_A1.2.3.4_B1.2_MN_KMJ_B2_20221125 | 010 | Full ROI
#     중복 AOI: MN_D1.E3.X1.C4.C3.C2.D4___MN_KMJ_B2_20221125 | 010 | Full ROI
#
#   그룹 179: 2개 동일한 AOI
#     대표 AOI: KSJ2_20210916 test | 001_M1 | Segment 1
#     중복 AOI: KSJ_20210916 test | 001_M1 | Segment 1
#
#   그룹 180: 2개 동일한 AOI
#     대표 AOI: KSJ2_20210916 test | 002_M1 | Segment 1
#     중복 AOI: KSJ_20210916 test | 002_M1 | Segment 1
#
#   그룹 181: 2개 동일한 AOI
#     대표 AOI: KSJ2_20210916 test | 003_M2 | Segment 1
#     중복 AOI: KSJ_20210916 test | 003_M2 | Segment 1
#
#   그룹 182: 2개 동일한 AOI
#     대표 AOI: KSJ2_20210916 test | 003_M2 | Segment 2
#     중복 AOI: KSJ_20210916 test | 003_M2 | Segment 2
#
#   그룹 183: 2개 동일한 AOI
#     대표 AOI: KSJ2_20210916 test | 004_M2 | Segment 1
#     중복 AOI: KSJ_20210916 test | 004_M2 | Segment 1
#
#   그룹 184: 2개 동일한 AOI
#     대표 AOI: KSJ2_20210916 test | 004_M2 | Segment 2
#     중복 AOI: KSJ_20210916 test | 004_M2 | Segment 2
#
#   그룹 185: 2개 동일한 AOI
#     대표 AOI: KSJ2_20210916 test | 005_M2 | Segment 1
#     중복 AOI: KSJ_20210916 test | 005_M2 | Segment 1
#
#   그룹 186: 2개 동일한 AOI
#     대표 AOI: KSJ2_20210916 test | 005_M2 | Segment 2
#     중복 AOI: KSJ_20210916 test | 005_M2 | Segment 2
#
#   그룹 187: 2개 동일한 AOI
#     대표 AOI: KSJ2_20210916 test | 006_M2 | Segment 1
#     중복 AOI: KSJ_20210916 test | 006_M2 | Segment 1
#
#   그룹 188: 2개 동일한 AOI
#     대표 AOI: KSJ2_20210916 test | 006_M2 | Segment 2
#     중복 AOI: KSJ_20210916 test | 006_M2 | Segment 2
#
#   그룹 189: 2개 동일한 AOI
#     대표 AOI: KSJ2_20210916 test | 007_N | Segment 1
#     중복 AOI: KSJ_20210916 test | 007_N | Segment 1
#
#   그룹 190: 2개 동일한 AOI
#     대표 AOI: KSJ2_20210916 test | 007_N | Segment 2
#     중복 AOI: KSJ_20210916 test | 007_N | Segment 2
#
#   그룹 191: 2개 동일한 AOI
#     대표 AOI: KSJ2_20210916 test | 008_M4 | Segment 1
#     중복 AOI: KSJ_20210916 test | 008_M4 | Segment 1
#
#   그룹 192: 2개 동일한 AOI
#     대표 AOI: KSJ2_20210916 test | 008_M4 | Segment 2
#     중복 AOI: KSJ_20210916 test | 008_M4 | Segment 2
#
#   그룹 193: 2개 동일한 AOI
#     대표 AOI: KSJ2_20210916 test | 009_M4 | Segment 1
#     중복 AOI: KSJ_20210916 test | 009_M4 | Segment 1
#
#   그룹 194: 2개 동일한 AOI
#     대표 AOI: KSJ2_20210916 test | 009_M4 | Segment 2
#     중복 AOI: KSJ_20210916 test | 009_M4 | Segment 2
#
#   그룹 195: 2개 동일한 AOI
#     대표 AOI: KSJ2_20210916 test | 010_M4 | Segment 1
#     중복 AOI: KSJ_20210916 test | 010_M4 | Segment 1
#
#   그룹 196: 2개 동일한 AOI
#     대표 AOI: KSJ2_20210916 test | 010_M4 | Segment 2
#     중복 AOI: KSJ_20210916 test | 010_M4 | Segment 2
#
#   그룹 197: 2개 동일한 AOI
#     대표 AOI: KSJ2_20210916 test | 011_MP | Segment 1
#     중복 AOI: KSJ_20210916 test | 011_MP | Segment 1
#
#   그룹 198: 2개 동일한 AOI
#     대표 AOI: KSJ2_20210916 test | 012_Melanoma | Geometric Segment
#     중복 AOI: KSJ_20210916 test | 012_Melanoma | Geometric Segment
#
#   그룹 199: 2개 동일한 AOI
#     대표 AOI: KSJ2_20210916 test | 013_Peri_melanoma | Segment 1
#     중복 AOI: KSJ_20210916 test | 013_Peri_melanoma | Segment 1
#
#   그룹 200: 2개 동일한 AOI
#     대표 AOI: KSJ2_20210916 test | 013_Peri_melanoma | Segment 2
#     중복 AOI: KSJ_20210916 test | 013_Peri_melanoma | Segment 2
#
#   그룹 201: 2개 동일한 AOI
#     대표 AOI: KSJ2_20210916 test | 014_Normal_tissue | Geometric Segment
#     중복 AOI: KSJ_20210916 test | 014_Normal_tissue | Geometric Segment
#
#   그룹 202: 2개 동일한 AOI
#     대표 AOI: TA3815_CNB_4_20230429 | 001 | Full ROI
#     중복 AOI: tnbc_ln_CNB_4_20230429 | 001 | Full ROI
#
#   그룹 203: 2개 동일한 AOI
#     대표 AOI: TA3815_CNB_4_20230429 | 002 | Full ROI
#     중복 AOI: tnbc_ln_CNB_4_20230429 | 002 | Full ROI
#
#   그룹 204: 2개 동일한 AOI
#     대표 AOI: TA3815_CNB_4_20230429 | 003 | Full ROI
#     중복 AOI: tnbc_ln_CNB_4_20230429 | 003 | Full ROI
#
#   그룹 205: 2개 동일한 AOI
#     대표 AOI: TA3815_CNB_4_20230429 | 004 | Full ROI
#     중복 AOI: tnbc_ln_CNB_4_20230429 | 004 | Full ROI
#
#   그룹 206: 2개 동일한 AOI
#     대표 AOI: TA3815_CNB_4_20230429 | 005 | Full ROI
#     중복 AOI: tnbc_ln_CNB_4_20230429 | 005 | Full ROI
#
#   그룹 207: 2개 동일한 AOI
#     대표 AOI: TA3815_CNB_4_20230429 | 006 | Full ROI
#     중복 AOI: tnbc_ln_CNB_4_20230429 | 006 | Full ROI
#
#   그룹 208: 2개 동일한 AOI
#     대표 AOI: TA3815_CNB_4_20230429 | 007 | Full ROI
#     중복 AOI: tnbc_ln_CNB_4_20230429 | 007 | Full ROI
#
#   그룹 209: 2개 동일한 AOI
#     대표 AOI: TA3815_CNB_4_20230429 | 008 | Full ROI
#     중복 AOI: tnbc_ln_CNB_4_20230429 | 008 | Full ROI
#
#   그룹 210: 2개 동일한 AOI
#     대표 AOI: TA3815_CNB_4_20230429 | 009 | Full ROI
#     중복 AOI: tnbc_ln_CNB_4_20230429 | 009 | Full ROI
#
#   그룹 211: 2개 동일한 AOI
#     대표 AOI: TA3815_CNB_4_20230429 | 010 | Full ROI
#     중복 AOI: tnbc_ln_CNB_4_20230429 | 010 | Full ROI
#
#   그룹 212: 2개 동일한 AOI
#     대표 AOI: TA3815_CNB_4_20230429 | 011 | Full ROI
#     중복 AOI: tnbc_ln_CNB_4_20230429 | 011 | Full ROI
#
#   그룹 213: 2개 동일한 AOI
#     대표 AOI: TA3815_CNB_4_20230429 | 012 | Full ROI
#     중복 AOI: tnbc_ln_CNB_4_20230429 | 012 | Full ROI
#
#   그룹 214: 2개 동일한 AOI
#     대표 AOI: 307 Breast cancer_TA3872_231109 | 001 | PanCK+
#     중복 AOI: Breast_Cancer_KHW_TA3872_231109 | 001 | PanCK+
#
#   그룹 215: 2개 동일한 AOI
#     대표 AOI: 307 Breast cancer_TA3872_231109 | 001 | PanCK-
#     중복 AOI: Breast_Cancer_KHW_TA3872_231109 | 001 | PanCK-
#
#   그룹 216: 2개 동일한 AOI
#     대표 AOI: 307 Breast cancer_TA3872_231109 | 002 | PanCK+
#     중복 AOI: Breast_Cancer_KHW_TA3872_231109 | 002 | PanCK+
#
#   그룹 217: 2개 동일한 AOI
#     대표 AOI: 307 Breast cancer_TA3872_231109 | 002 | PanCK-
#     중복 AOI: Breast_Cancer_KHW_TA3872_231109 | 002 | PanCK-
#
#   그룹 218: 2개 동일한 AOI
#     대표 AOI: 307 Breast cancer_TA3872_231109 | 003 | PanCK+
#     중복 AOI: Breast_Cancer_KHW_TA3872_231109 | 003 | PanCK+
#
#   그룹 219: 2개 동일한 AOI
#     대표 AOI: 307 Breast cancer_TA3872_231109 | 003 | PanCK-
#     중복 AOI: Breast_Cancer_KHW_TA3872_231109 | 003 | PanCK-
#
#   그룹 220: 2개 동일한 AOI
#     대표 AOI: 307 Breast cancer_TA3872_231109 | 004 | PanCK+
#     중복 AOI: Breast_Cancer_KHW_TA3872_231109 | 004 | PanCK+
#
#   그룹 221: 2개 동일한 AOI
#     대표 AOI: 307 Breast cancer_TA3872_231109 | 004 | PanCK-
#     중복 AOI: Breast_Cancer_KHW_TA3872_231109 | 004 | PanCK-
#
# ...
#
#   그룹 1061: 3개 동일한 AOI
#     대표 AOI: HCC_VETC_HSH_HCC_NT_20230801_KMJ_SHW | 010 | CD68-
#     중복 AOI: HCC_NTvsTC_48_KDJ_real_HCC_NT_20230801_KMJ_SHW | 010 | CD68-, HCC_NT_vs_TC_48_KMJ_HCC_NT_20230801_KMJ_SHW | 010 | CD68-
#
#   그룹 1062: 3개 동일한 AOI
#     대표 AOI: HCC_VETC_HSH_HCC_NT_20230801_KMJ_SHW | 011 | CD68+
#     중복 AOI: HCC_NTvsTC_48_KDJ_real_HCC_NT_20230801_KMJ_SHW | 011 | CD68+, HCC_NT_vs_TC_48_KMJ_HCC_NT_20230801_KMJ_SHW | 011 | CD68+
#
#   그룹 1063: 3개 동일한 AOI
#     대표 AOI: HCC_VETC_HSH_HCC_NT_20230801_KMJ_SHW | 011 | CD68-
#     중복 AOI: HCC_NTvsTC_48_KDJ_real_HCC_NT_20230801_KMJ_SHW | 011 | CD68-, HCC_NT_vs_TC_48_KMJ_HCC_NT_20230801_KMJ_SHW | 011 | CD68-
#
#   그룹 1064: 3개 동일한 AOI
#     대표 AOI: HCC_VETC_HSH_HCC_NT_20230801_KMJ_SHW | 012 | CD68+
#     중복 AOI: HCC_NTvsTC_48_KDJ_real_HCC_NT_20230801_KMJ_SHW | 012 | CD68+, HCC_NT_vs_TC_48_KMJ_HCC_NT_20230801_KMJ_SHW | 012 | CD68+
#
#   그룹 1065: 3개 동일한 AOI
#     대표 AOI: HCC_VETC_HSH_HCC_NT_20230801_KMJ_SHW | 012 | CD68-
#     중복 AOI: HCC_NTvsTC_48_KDJ_real_HCC_NT_20230801_KMJ_SHW | 012 | CD68-, HCC_NT_vs_TC_48_KMJ_HCC_NT_20230801_KMJ_SHW | 012 | CD68-
#
#   그룹 1066: 3개 동일한 AOI
#     대표 AOI: HCC_VETC_HSH_HCC_NT_20230801_KMJ_SHW | 013 | CD68+
#     중복 AOI: HCC_NTvsTC_48_KDJ_real_HCC_NT_20230801_KMJ_SHW | 013 | CD68+, HCC_NT_vs_TC_48_KMJ_HCC_NT_20230801_KMJ_SHW | 013 | CD68+
#
#   그룹 1067: 3개 동일한 AOI
#     대표 AOI: HCC_VETC_HSH_HCC_NT_20230801_KMJ_SHW | 013 | CD68-
#     중복 AOI: HCC_NTvsTC_48_KDJ_real_HCC_NT_20230801_KMJ_SHW | 013 | CD68-, HCC_NT_vs_TC_48_KMJ_HCC_NT_20230801_KMJ_SHW | 013 | CD68-
#
#   그룹 1068: 3개 동일한 AOI
#     대표 AOI: HCC_VETC_HSH_HCC_NT_20230801_KMJ_SHW | 014 | CD68+
#     중복 AOI: HCC_NTvsTC_48_KDJ_real_HCC_NT_20230801_KMJ_SHW | 014 | CD68+, HCC_NT_vs_TC_48_KMJ_HCC_NT_20230801_KMJ_SHW | 014 | CD68+
#
#   그룹 1069: 3개 동일한 AOI
#     대표 AOI: HCC_VETC_HSH_HCC_NT_20230801_KMJ_SHW | 014 | CD68-
#     중복 AOI: HCC_NTvsTC_48_KDJ_real_HCC_NT_20230801_KMJ_SHW | 014 | CD68-, HCC_NT_vs_TC_48_KMJ_HCC_NT_20230801_KMJ_SHW | 014 | CD68-
#
#   그룹 1070: 3개 동일한 AOI
#     대표 AOI: HCC_VETC_HSH_HCC_NT_20230801_KMJ_SHW | 015 | CD68+
#     중복 AOI: HCC_NTvsTC_48_KDJ_real_HCC_NT_20230801_KMJ_SHW | 015 | CD68+, HCC_NT_vs_TC_48_KMJ_HCC_NT_20230801_KMJ_SHW | 015 | CD68+
#
#   그룹 1071: 3개 동일한 AOI
#     대표 AOI: HCC_VETC_HSH_HCC_NT_20230801_KMJ_SHW | 015 | CD68-
#     중복 AOI: HCC_NTvsTC_48_KDJ_real_HCC_NT_20230801_KMJ_SHW | 015 | CD68-, HCC_NT_vs_TC_48_KMJ_HCC_NT_20230801_KMJ_SHW | 015 | CD68-
#
#   그룹 1072: 3개 동일한 AOI
#     대표 AOI: HCC_VETC_HSH_HCC_NT_20230801_KMJ_SHW | 016 | CD68+
#     중복 AOI: HCC_NTvsTC_48_KDJ_real_HCC_NT_20230801_KMJ_SHW | 016 | CD68+, HCC_NT_vs_TC_48_KMJ_HCC_NT_20230801_KMJ_SHW | 016 | CD68+
#
#   그룹 1073: 3개 동일한 AOI
#     대표 AOI: HCC_VETC_HSH_HCC_NT_20230801_KMJ_SHW | 017 | CD68+
#     중복 AOI: HCC_NTvsTC_48_KDJ_real_HCC_NT_20230801_KMJ_SHW | 017 | CD68+, HCC_NT_vs_TC_48_KMJ_HCC_NT_20230801_KMJ_SHW | 017 | CD68+
#
#   그룹 1074: 3개 동일한 AOI
#     대표 AOI: HCC_VETC_HSH_HCC_NT_20230801_KMJ_SHW | 017 | CD68-
#     중복 AOI: HCC_NTvsTC_48_KDJ_real_HCC_NT_20230801_KMJ_SHW | 017 | CD68-, HCC_NT_vs_TC_48_KMJ_HCC_NT_20230801_KMJ_SHW | 017 | CD68-
#
#   그룹 1075: 3개 동일한 AOI
#     대표 AOI: HCC_VETC_HSH_HCC_NT_20230801_KMJ_SHW | 018 | CD68+
#     중복 AOI: HCC_NTvsTC_48_KDJ_real_HCC_NT_20230801_KMJ_SHW | 018 | CD68+, HCC_NT_vs_TC_48_KMJ_HCC_NT_20230801_KMJ_SHW | 018 | CD68+
#
#   그룹 1076: 3개 동일한 AOI
#     대표 AOI: HCC_VETC_HSH_HCC_NT_20230801_KMJ_SHW | 018 | CD68-
#     중복 AOI: HCC_NTvsTC_48_KDJ_real_HCC_NT_20230801_KMJ_SHW | 018 | CD68-, HCC_NT_vs_TC_48_KMJ_HCC_NT_20230801_KMJ_SHW | 018 | CD68-
#
#   그룹 1077: 3개 동일한 AOI
#     대표 AOI: HCC_VETC_HSH_HCC_NT_20230801_KMJ_SHW | 019 | CD68+
#     중복 AOI: HCC_NTvsTC_48_KDJ_real_HCC_NT_20230801_KMJ_SHW | 019 | CD68+, HCC_NT_vs_TC_48_KMJ_HCC_NT_20230801_KMJ_SHW | 019 | CD68+
#
#   그룹 1078: 3개 동일한 AOI
#     대표 AOI: HCC_VETC_HSH_HCC_NT_20230801_KMJ_SHW | 019 | CD68-
#     중복 AOI: HCC_NTvsTC_48_KDJ_real_HCC_NT_20230801_KMJ_SHW | 019 | CD68-, HCC_NT_vs_TC_48_KMJ_HCC_NT_20230801_KMJ_SHW | 019 | CD68-
#
#   그룹 1079: 3개 동일한 AOI
#     대표 AOI: HCC_VETC_HSH_HCC_NT_20230801_KMJ_SHW | 020 | CD68+
#     중복 AOI: HCC_NTvsTC_48_KDJ_real_HCC_NT_20230801_KMJ_SHW | 020 | CD68+, HCC_NT_vs_TC_48_KMJ_HCC_NT_20230801_KMJ_SHW | 020 | CD68+
#
#   그룹 1080: 3개 동일한 AOI
#     대표 AOI: HCC_VETC_HSH_HCC_NT_20230801_KMJ_SHW | 020 | CD68-
#     중복 AOI: HCC_NTvsTC_48_KDJ_real_HCC_NT_20230801_KMJ_SHW | 020 | CD68-, HCC_NT_vs_TC_48_KMJ_HCC_NT_20230801_KMJ_SHW | 020 | CD68-
#
#   그룹 1081: 3개 동일한 AOI
#     대표 AOI: HCC_VETC_HSH_HCC_NT_20230801_KMJ_SHW | 021 | CD68+
#     중복 AOI: HCC_NTvsTC_48_KDJ_real_HCC_NT_20230801_KMJ_SHW | 021 | CD68+, HCC_NT_vs_TC_48_KMJ_HCC_NT_20230801_KMJ_SHW | 021 | CD68+
#
#   그룹 1082: 3개 동일한 AOI
#     대표 AOI: HCC_VETC_HSH_HCC_NT_20230801_KMJ_SHW | 021 | CD68-
#     중복 AOI: HCC_NTvsTC_48_KDJ_real_HCC_NT_20230801_KMJ_SHW | 021 | CD68-, HCC_NT_vs_TC_48_KMJ_HCC_NT_20230801_KMJ_SHW | 021 | CD68-
#
#   그룹 1083: 3개 동일한 AOI
#     대표 AOI: HCC_VETC_HSH_HCC_NT_20230801_KMJ_SHW | 022 | CD68+
#     중복 AOI: HCC_NTvsTC_48_KDJ_real_HCC_NT_20230801_KMJ_SHW | 022 | CD68+, HCC_NT_vs_TC_48_KMJ_HCC_NT_20230801_KMJ_SHW | 022 | CD68+
#
#   그룹 1084: 3개 동일한 AOI
#     대표 AOI: HCC_VETC_HSH_HCC_NT_20230801_KMJ_SHW | 022 | CD68-
#     중복 AOI: HCC_NTvsTC_48_KDJ_real_HCC_NT_20230801_KMJ_SHW | 022 | CD68-, HCC_NT_vs_TC_48_KMJ_HCC_NT_20230801_KMJ_SHW | 022 | CD68-
#
#   그룹 1085: 3개 동일한 AOI
#     대표 AOI: HCC_VETC_HSH_HCC_NT_20230801_KMJ_SHW | 023 | CD68+
#     중복 AOI: HCC_NTvsTC_48_KDJ_real_HCC_NT_20230801_KMJ_SHW | 023 | CD68+, HCC_NT_vs_TC_48_KMJ_HCC_NT_20230801_KMJ_SHW | 023 | CD68+
#
#   그룹 1086: 3개 동일한 AOI
#     대표 AOI: HCC_VETC_HSH_HCC_NT_20230801_KMJ_SHW | 023 | CD68-
#     중복 AOI: HCC_NTvsTC_48_KDJ_real_HCC_NT_20230801_KMJ_SHW | 023 | CD68-, HCC_NT_vs_TC_48_KMJ_HCC_NT_20230801_KMJ_SHW | 023 | CD68-
#
#   그룹 1087: 3개 동일한 AOI
#     대표 AOI: HCC_VETC_HSH_HCC_NT_20230801_KMJ_SHW | 024 | CD68+
#     중복 AOI: HCC_NTvsTC_48_KDJ_real_HCC_NT_20230801_KMJ_SHW | 024 | CD68+, HCC_NT_vs_TC_48_KMJ_HCC_NT_20230801_KMJ_SHW | 024 | CD68+
#
#   그룹 1088: 3개 동일한 AOI
#     대표 AOI: HCC_VETC_HSH_HCC_NT_20230801_KMJ_SHW | 024 | CD68-
#     중복 AOI: HCC_NTvsTC_48_KDJ_real_HCC_NT_20230801_KMJ_SHW | 024 | CD68-, HCC_NT_vs_TC_48_KMJ_HCC_NT_20230801_KMJ_SHW | 024 | CD68-
#
#   그룹 1089: 2개 동일한 AOI
#     대표 AOI: HCC_NTvsTC_48_KDJ_real_HCC_TC_48_20230801_KMJ_SHW | 001 | CD68+
#     중복 AOI: HCC_NT_vs_TC_48_KMJ_HCC_TC_48_20230801_KMJ_SHW | 001 | CD68+
#
#   그룹 1090: 2개 동일한 AOI
#     대표 AOI: HCC_NTvsTC_48_KDJ_real_HCC_TC_48_20230801_KMJ_SHW | 001 | CD68-
#     중복 AOI: HCC_NT_vs_TC_48_KMJ_HCC_TC_48_20230801_KMJ_SHW | 001 | CD68-
#
#   그룹 1091: 2개 동일한 AOI
#     대표 AOI: HCC_NTvsTC_48_KDJ_real_HCC_TC_48_20230801_KMJ_SHW | 002 | CD68+
#     중복 AOI: HCC_NT_vs_TC_48_KMJ_HCC_TC_48_20230801_KMJ_SHW | 002 | CD68+
#
#   그룹 1092: 2개 동일한 AOI
#     대표 AOI: HCC_NTvsTC_48_KDJ_real_HCC_TC_48_20230801_KMJ_SHW | 002 | CD68-
#     중복 AOI: HCC_NT_vs_TC_48_KMJ_HCC_TC_48_20230801_KMJ_SHW | 002 | CD68-
#
#   그룹 1093: 2개 동일한 AOI
#     대표 AOI: HCC_NTvsTC_48_KDJ_real_HCC_TC_48_20230801_KMJ_SHW | 003 | CD68+
#     중복 AOI: HCC_NT_vs_TC_48_KMJ_HCC_TC_48_20230801_KMJ_SHW | 003 | CD68+
#
#   그룹 1094: 2개 동일한 AOI
#     대표 AOI: HCC_NTvsTC_48_KDJ_real_HCC_TC_48_20230801_KMJ_SHW | 003 | CD68-
#     중복 AOI: HCC_NT_vs_TC_48_KMJ_HCC_TC_48_20230801_KMJ_SHW | 003 | CD68-
#
#   그룹 1095: 2개 동일한 AOI
#     대표 AOI: HCC_NTvsTC_48_KDJ_real_HCC_TC_48_20230801_KMJ_SHW | 004 | CD68+
#     중복 AOI: HCC_NT_vs_TC_48_KMJ_HCC_TC_48_20230801_KMJ_SHW | 004 | CD68+
#
#   그룹 1096: 2개 동일한 AOI
#     대표 AOI: HCC_NTvsTC_48_KDJ_real_HCC_TC_48_20230801_KMJ_SHW | 004 | CD68-
#     중복 AOI: HCC_NT_vs_TC_48_KMJ_HCC_TC_48_20230801_KMJ_SHW | 004 | CD68-
#
#   그룹 1097: 2개 동일한 AOI
#     대표 AOI: HCC_NTvsTC_48_KDJ_real_HCC_TC_48_20230801_KMJ_SHW | 005 | CD68+
#     중복 AOI: HCC_NT_vs_TC_48_KMJ_HCC_TC_48_20230801_KMJ_SHW | 005 | CD68+
#
#   그룹 1098: 2개 동일한 AOI
#     대표 AOI: HCC_NTvsTC_48_KDJ_real_HCC_TC_48_20230801_KMJ_SHW | 005 | CD68-
#     중복 AOI: HCC_NT_vs_TC_48_KMJ_HCC_TC_48_20230801_KMJ_SHW | 005 | CD68-
#
#   그룹 1099: 2개 동일한 AOI
#     대표 AOI: HCC_NTvsTC_48_KDJ_real_HCC_TC_48_20230801_KMJ_SHW | 006 | CD68+
#     중복 AOI: HCC_NT_vs_TC_48_KMJ_HCC_TC_48_20230801_KMJ_SHW | 006 | CD68+
#
#   그룹 1100: 2개 동일한 AOI
#     대표 AOI: HCC_NTvsTC_48_KDJ_real_HCC_TC_48_20230801_KMJ_SHW | 006 | CD68-
#     중복 AOI: HCC_NT_vs_TC_48_KMJ_HCC_TC_48_20230801_KMJ_SHW | 006 | CD68-
#
#   그룹 1101: 2개 동일한 AOI
#     대표 AOI: HCC_NTvsTC_48_KDJ_real_HCC_TC_48_20230801_KMJ_SHW | 007 | CD68+
#     중복 AOI: HCC_NT_vs_TC_48_KMJ_HCC_TC_48_20230801_KMJ_SHW | 007 | CD68+
#
#   그룹 1102: 2개 동일한 AOI
#     대표 AOI: HCC_NTvsTC_48_KDJ_real_HCC_TC_48_20230801_KMJ_SHW | 007 | CD68-
#     중복 AOI: HCC_NT_vs_TC_48_KMJ_HCC_TC_48_20230801_KMJ_SHW | 007 | CD68-
#
#   그룹 1103: 2개 동일한 AOI
#     대표 AOI: HCC_NTvsTC_48_KDJ_real_HCC_TC_48_20230801_KMJ_SHW | 008 | CD68+
#     중복 AOI: HCC_NT_vs_TC_48_KMJ_HCC_TC_48_20230801_KMJ_SHW | 008 | CD68+
#
#   그룹 1104: 2개 동일한 AOI
#     대표 AOI: HCC_NTvsTC_48_KDJ_real_HCC_TC_48_20230801_KMJ_SHW | 008 | CD68-
#     중복 AOI: HCC_NT_vs_TC_48_KMJ_HCC_TC_48_20230801_KMJ_SHW | 008 | CD68-
#
#   그룹 1105: 2개 동일한 AOI
#     대표 AOI: HCC_NTvsTC_48_KDJ_real_HCC_TC_48_20230801_KMJ_SHW | 009 | CD68+
#     중복 AOI: HCC_NT_vs_TC_48_KMJ_HCC_TC_48_20230801_KMJ_SHW | 009 | CD68+
#
#   그룹 1106: 2개 동일한 AOI
#     대표 AOI: HCC_NTvsTC_48_KDJ_real_HCC_TC_48_20230801_KMJ_SHW | 009 | CD68-
#     중복 AOI: HCC_NT_vs_TC_48_KMJ_HCC_TC_48_20230801_KMJ_SHW | 009 | CD68-
#
#   그룹 1107: 2개 동일한 AOI
#     대표 AOI: HCC_NTvsTC_48_KDJ_real_HCC_TC_48_20230801_KMJ_SHW | 010 | CD68+
#     중복 AOI: HCC_NT_vs_TC_48_KMJ_HCC_TC_48_20230801_KMJ_SHW | 010 | CD68+
#
#   그룹 1108: 2개 동일한 AOI
#     대표 AOI: HCC_NTvsTC_48_KDJ_real_HCC_TC_48_20230801_KMJ_SHW | 010 | CD68-
#     중복 AOI: HCC_NT_vs_TC_48_KMJ_HCC_TC_48_20230801_KMJ_SHW | 010 | CD68-
#
#   그룹 1109: 2개 동일한 AOI
#     대표 AOI: HCC_NTvsTC_48_KDJ_real_HCC_TC_48_20230801_KMJ_SHW | 011 | CD68+
#     중복 AOI: HCC_NT_vs_TC_48_KMJ_HCC_TC_48_20230801_KMJ_SHW | 011 | CD68+
#
#   그룹 1110: 2개 동일한 AOI
#     대표 AOI: HCC_NTvsTC_48_KDJ_real_HCC_TC_48_20230801_KMJ_SHW | 011 | CD68-
#     중복 AOI: HCC_NT_vs_TC_48_KMJ_HCC_TC_48_20230801_KMJ_SHW | 011 | CD68-
#
#   그룹 1111: 2개 동일한 AOI
#     대표 AOI: HCC_NTvsTC_48_KDJ_real_HCC_TC_48_20230801_KMJ_SHW | 012 | CD68+
#     중복 AOI: HCC_NT_vs_TC_48_KMJ_HCC_TC_48_20230801_KMJ_SHW | 012 | CD68+
#
#   그룹 1112: 2개 동일한 AOI
#     대표 AOI: HCC_NTvsTC_48_KDJ_real_HCC_TC_48_20230801_KMJ_SHW | 012 | CD68-
#     중복 AOI: HCC_NT_vs_TC_48_KMJ_HCC_TC_48_20230801_KMJ_SHW | 012 | CD68-
#
#   그룹 1113: 2개 동일한 AOI
#     대표 AOI: HCC_NTvsTC_48_KDJ_real_HCC_TC_48_20230801_KMJ_SHW | 013 | CD68+
#     중복 AOI: HCC_NT_vs_TC_48_KMJ_HCC_TC_48_20230801_KMJ_SHW | 013 | CD68+
#
#   그룹 1114: 2개 동일한 AOI
#     대표 AOI: HCC_NTvsTC_48_KDJ_real_HCC_TC_48_20230801_KMJ_SHW | 013 | CD68-
#     중복 AOI: HCC_NT_vs_TC_48_KMJ_HCC_TC_48_20230801_KMJ_SHW | 013 | CD68-
#
#   그룹 1115: 2개 동일한 AOI
#     대표 AOI: HCC_NTvsTC_48_KDJ_real_HCC_TC_48_20230801_KMJ_SHW | 014 | CD68+
#     중복 AOI: HCC_NT_vs_TC_48_KMJ_HCC_TC_48_20230801_KMJ_SHW | 014 | CD68+
#
#   그룹 1116: 2개 동일한 AOI
#     대표 AOI: HCC_NTvsTC_48_KDJ_real_HCC_TC_48_20230801_KMJ_SHW | 014 | CD68-
#     중복 AOI: HCC_NT_vs_TC_48_KMJ_HCC_TC_48_20230801_KMJ_SHW | 014 | CD68-
#
#   그룹 1117: 2개 동일한 AOI
#     대표 AOI: HCC_NTvsTC_48_KDJ_real_HCC_TC_48_20230801_KMJ_SHW | 015 | CD68+
#     중복 AOI: HCC_NT_vs_TC_48_KMJ_HCC_TC_48_20230801_KMJ_SHW | 015 | CD68+
#
#   그룹 1118: 2개 동일한 AOI
#     대표 AOI: HCC_NTvsTC_48_KDJ_real_HCC_TC_48_20230801_KMJ_SHW | 015 | CD68-
#     중복 AOI: HCC_NT_vs_TC_48_KMJ_HCC_TC_48_20230801_KMJ_SHW | 015 | CD68-
#
#   그룹 1119: 2개 동일한 AOI
#     대표 AOI: HCC_NTvsTC_48_KDJ_real_HCC_TC_48_20230801_KMJ_SHW | 016 | CD68+
#     중복 AOI: HCC_NT_vs_TC_48_KMJ_HCC_TC_48_20230801_KMJ_SHW | 016 | CD68+
#
#   그룹 1120: 2개 동일한 AOI
#     대표 AOI: HCC_NTvsTC_48_KDJ_real_HCC_TC_48_20230801_KMJ_SHW | 016 | CD68-
#     중복 AOI: HCC_NT_vs_TC_48_KMJ_HCC_TC_48_20230801_KMJ_SHW | 016 | CD68-
#
#   그룹 1121: 2개 동일한 AOI
#     대표 AOI: HCC_NTvsTC_48_KDJ_real_HCC_TC_48_20230801_KMJ_SHW | 017 | CD68+
#     중복 AOI: HCC_NT_vs_TC_48_KMJ_HCC_TC_48_20230801_KMJ_SHW | 017 | CD68+
#
#   그룹 1122: 2개 동일한 AOI
#     대표 AOI: HCC_NTvsTC_48_KDJ_real_HCC_TC_48_20230801_KMJ_SHW | 017 | CD68-
#     중복 AOI: HCC_NT_vs_TC_48_KMJ_HCC_TC_48_20230801_KMJ_SHW | 017 | CD68-
#
#   그룹 1123: 2개 동일한 AOI
#     대표 AOI: HCC_NTvsTC_48_KDJ_real_HCC_TC_48_20230801_KMJ_SHW | 018 | CD68+
#     중복 AOI: HCC_NT_vs_TC_48_KMJ_HCC_TC_48_20230801_KMJ_SHW | 018 | CD68+
#
#   그룹 1124: 2개 동일한 AOI
#     대표 AOI: HCC_NTvsTC_48_KDJ_real_HCC_TC_48_20230801_KMJ_SHW | 018 | CD68-
#     중복 AOI: HCC_NT_vs_TC_48_KMJ_HCC_TC_48_20230801_KMJ_SHW | 018 | CD68-
#
#   그룹 1125: 2개 동일한 AOI
#     대표 AOI: HCC_NTvsTC_48_KDJ_real_HCC_TC_48_20230801_KMJ_SHW | 019 | CD68+
#     중복 AOI: HCC_NT_vs_TC_48_KMJ_HCC_TC_48_20230801_KMJ_SHW | 019 | CD68+
#
#   그룹 1126: 2개 동일한 AOI
#     대표 AOI: HCC_NTvsTC_48_KDJ_real_HCC_TC_48_20230801_KMJ_SHW | 019 | CD68-
#     중복 AOI: HCC_NT_vs_TC_48_KMJ_HCC_TC_48_20230801_KMJ_SHW | 019 | CD68-
#
#   그룹 1127: 2개 동일한 AOI
#     대표 AOI: HCC_NTvsTC_48_KDJ_real_HCC_TC_48_20230801_KMJ_SHW | 020 | CD68+
#     중복 AOI: HCC_NT_vs_TC_48_KMJ_HCC_TC_48_20230801_KMJ_SHW | 020 | CD68+
#
#   그룹 1128: 2개 동일한 AOI
#     대표 AOI: HCC_NTvsTC_48_KDJ_real_HCC_TC_48_20230801_KMJ_SHW | 020 | CD68-
#     중복 AOI: HCC_NT_vs_TC_48_KMJ_HCC_TC_48_20230801_KMJ_SHW | 020 | CD68-
#
#   그룹 1129: 2개 동일한 AOI
#     대표 AOI: HCC_NTvsTC_48_KDJ_real_HCC_TC_48_20230801_KMJ_SHW | 021 | CD68+
#     중복 AOI: HCC_NT_vs_TC_48_KMJ_HCC_TC_48_20230801_KMJ_SHW | 021 | CD68+
#
#   그룹 1130: 2개 동일한 AOI
#     대표 AOI: HCC_NTvsTC_48_KDJ_real_HCC_TC_48_20230801_KMJ_SHW | 021 | CD68-
#     중복 AOI: HCC_NT_vs_TC_48_KMJ_HCC_TC_48_20230801_KMJ_SHW | 021 | CD68-
#
#   그룹 1131: 2개 동일한 AOI
#     대표 AOI: HCC_NTvsTC_48_KDJ_real_HCC_TC_48_20230801_KMJ_SHW | 022 | CD68+
#     중복 AOI: HCC_NT_vs_TC_48_KMJ_HCC_TC_48_20230801_KMJ_SHW | 022 | CD68+
#
#   그룹 1132: 2개 동일한 AOI
#     대표 AOI: HCC_NTvsTC_48_KDJ_real_HCC_TC_48_20230801_KMJ_SHW | 022 | CD68-
#     중복 AOI: HCC_NT_vs_TC_48_KMJ_HCC_TC_48_20230801_KMJ_SHW | 022 | CD68-
#
#   그룹 1133: 2개 동일한 AOI
#     대표 AOI: HCC_NTvsTC_48_KDJ_real_HCC_TC_48_20230801_KMJ_SHW | 023 | CD68+
#     중복 AOI: HCC_NT_vs_TC_48_KMJ_HCC_TC_48_20230801_KMJ_SHW | 023 | CD68+
#
#   그룹 1134: 2개 동일한 AOI
#     대표 AOI: HCC_NTvsTC_48_KDJ_real_HCC_TC_48_20230801_KMJ_SHW | 023 | CD68-
#     중복 AOI: HCC_NT_vs_TC_48_KMJ_HCC_TC_48_20230801_KMJ_SHW | 023 | CD68-
#
#   그룹 1135: 2개 동일한 AOI
#     대표 AOI: HCC_NTvsTC_48_KDJ_real_HCC_TC_48_20230801_KMJ_SHW | 024 | CD68+
#     중복 AOI: HCC_NT_vs_TC_48_KMJ_HCC_TC_48_20230801_KMJ_SHW | 024 | CD68+
#
#   그룹 1136: 2개 동일한 AOI
#     대표 AOI: HCC_NTvsTC_48_KDJ_real_HCC_TC_48_20230801_KMJ_SHW | 024 | CD68-
#     중복 AOI: HCC_NT_vs_TC_48_KMJ_HCC_TC_48_20230801_KMJ_SHW | 024 | CD68-
#
#   그룹 1137: 16개 동일한 AOI
#     대표 AOI: 250114_TCR add on_final_Thymus Geomx 240910 | Donor10_B | CD3
#     중복 AOI: 250114_TCR add on_final_Thymus Geomx 240910 | Donor10_epi | CD3, 250114_TCR add on_final_Thymus Geomx 240910 | Donor10_T | PanCK, 250114_TCR add on_final_Thymus Geomx 240910 | Donor11_B | PanCK, 250114_TCR add on_final_Thymus Geomx 240910 | Donor11_B | CD3, 250114_TCR add on_final_Thymus Geomx 240910 | Donor14_B | PanCK, 250114_TCR add on_final_Thymus Geomx 240910 | Donor14_B | CD3, 250114_TCR add on_final_Thymus Geomx 240910 | Donor14_epi | CD3, 250114_TCR add on_final_Thymus Geomx 240910 | Donor14_T | PanCK, 250114_TCR add on_final_Thymus Geomx 240910 | Donor5_B | CD3, 250114_TCR add on_final_Thymus Geomx 240910 | Donor5_epi | CD3, 250114_TCR add on_final_Thymus Geomx 240910 | Donor5_T | PanCK, 250114_TCR add on_final_Thymus Geomx 240910 | Donor9_B | PanCK, 250114_TCR add on_final_Thymus Geomx 240910 | Donor9_B | CD3, 250114_TCR add on_final_Thymus Geomx 240910 | Donor9_epi | CD19, 250114_TCR add on_final_Thymus Geomx 240910 | Donor9_epi | CD3
#
#
# ✂️  제거된 컬럼 수: 1643
# ✅ 남은 전체 컬럼 수: 3826
# 💾 메모리 절감: 29.6%
#
# ✅ 검증 완료: 데이터 무결성 확인
#
# 📄 리포트 저장 완료: /data/kjc1/projects/#999. GeoMx meta/pooled/csv_files/merged/merged_HUMAN_WTA_filtered_duplicate_report.json
# 💾 필터링된 파일 저장: /data/kjc1/projects/#999. GeoMx meta/pooled/csv_files/merged/merged_HUMAN_WTA_filtered.csv
#    원본: 5469 columns → 필터링: 3826 columns
#
# 사용 방법:
# 1. remove_duplicate_aois('merged_CTA.csv') - 간단 사용
# 2. DuplicateAOIFilter 클래스 - 상세 제어
# 3. analyze_aoi_similarity() - 유사도 분석

# %%
filtered_df = remove_duplicate_aois(raw_merged_csv,output_path=output_path)
filtered_df2 = remove_duplicate_aois(raw_merged_csv2,output_path=output_path2)
filtered_df3 = remove_duplicate_aois(raw_merged_csv3,output_path=output_path3)
# Out:
# 📁 파일 읽기: /data/kjc1/projects/#999. GeoMx meta/pooled/csv_files/merged/merged_CTA.csv
# 📊 전체 컬럼 수: 85
# 📊 AOI 컬럼 수: 73
# 🔍 중복 검사 시작...
#
# 🔍 발견된 중복 그룹: 21개
# 📉 제거 가능한 중복 AOI: 34개
#
#   그룹 1: 2개 동일한 AOI
#     대표 AOI: CRC(2)_20211007 slide1 | 001 | Macrophage
#     중복 AOI: CRC_20211007 slide1 | 001 | Macrophage
#
#   그룹 2: 4개 동일한 AOI
#     대표 AOI: CRC(2)_20211007 slide1 | 002 | Macrophage
#     중복 AOI: CRC(2)_20211007 slide1 | 006 | Macrophage, CRC_20211007 slide1 | 002 | Macrophage, CRC_20211007 slide1 | 006 | Macrophage
#
#   그룹 3: 2개 동일한 AOI
#     대표 AOI: CRC(2)_20211007 slide1 | 003 | Macrophage
#     중복 AOI: CRC_20211007 slide1 | 003 | Macrophage
#
#   그룹 4: 2개 동일한 AOI
#     대표 AOI: CRC(2)_20211007 slide1 | 004 | Macrophage
#     중복 AOI: CRC_20211007 slide1 | 004 | Macrophage
#
#   그룹 5: 2개 동일한 AOI
#     대표 AOI: CRC(2)_20211007 slide1 | 005 | Macrophage
#     중복 AOI: CRC_20211007 slide1 | 005 | Macrophage
#
#   그룹 6: 2개 동일한 AOI
#     대표 AOI: CRC(2)_20211007 slide1 | 007 | Macrophage
#     중복 AOI: CRC_20211007 slide1 | 007 | Macrophage
#
#   그룹 7: 2개 동일한 AOI
#     대표 AOI: CRC(2)_20211007 slide1 | 008 | Macrophage
#     중복 AOI: CRC_20211007 slide1 | 008 | Macrophage
#
#   그룹 8: 2개 동일한 AOI
#     대표 AOI: CRC(2)_20211007 slide1 | 009 | Macrophage
#     중복 AOI: CRC_20211007 slide1 | 009 | Macrophage
#
#   그룹 9: 2개 동일한 AOI
#     대표 AOI: CRC(2)_20211007 slide1 | 010 | Macrophage
#     중복 AOI: CRC_20211007 slide1 | 010 | Macrophage
#
#   그룹 10: 2개 동일한 AOI
#     대표 AOI: CRC(2)_20211007 slide1 | 011 | Macrophage
#     중복 AOI: CRC_20211007 slide1 | 011 | Macrophage
#
#   그룹 11: 3개 동일한 AOI
#     대표 AOI: CRC(2)_20211007 slide2 | 001 | w_o tumor
#     중복 AOI: CRC_20211007 slide2 | 001 | w_o tumor, BK_colon cancer_20211007 slide2 | 001 | w_o tumor
#
#   그룹 12: 3개 동일한 AOI
#     대표 AOI: CRC(2)_20211007 slide2 | 002 | w_o tumor
#     중복 AOI: CRC_20211007 slide2 | 002 | w_o tumor, BK_colon cancer_20211007 slide2 | 002 | w_o tumor
#
#   그룹 13: 3개 동일한 AOI
#     대표 AOI: CRC(2)_20211007 slide2 | 003 | w_o tumor
#     중복 AOI: CRC_20211007 slide2 | 003 | w_o tumor, BK_colon cancer_20211007 slide2 | 003 | w_o tumor
#
#   그룹 14: 3개 동일한 AOI
#     대표 AOI: CRC(2)_20211007 slide2 | 004 | w_o tumor
#     중복 AOI: CRC_20211007 slide2 | 004 | w_o tumor, BK_colon cancer_20211007 slide2 | 004 | w_o tumor
#
#   그룹 15: 3개 동일한 AOI
#     대표 AOI: CRC(2)_20211007 slide2 | 005 | w_o tumor
#     중복 AOI: CRC_20211007 slide2 | 005 | w_o tumor, BK_colon cancer_20211007 slide2 | 005 | w_o tumor
#
#   그룹 16: 3개 동일한 AOI
#     대표 AOI: CRC(2)_20211007 slide2 | 006 | w_o tumor
#     중복 AOI: CRC_20211007 slide2 | 006 | w_o tumor, BK_colon cancer_20211007 slide2 | 006 | w_o tumor
#
#   그룹 17: 3개 동일한 AOI
#     대표 AOI: CRC(2)_20211007 slide2 | 007 | w_o tumor
#     중복 AOI: CRC_20211007 slide2 | 007 | w_o tumor, BK_colon cancer_20211007 slide2 | 007 | w_o tumor
#
#   그룹 18: 3개 동일한 AOI
#     대표 AOI: CRC(2)_20211007 slide2 | 008 | w_o tumor
#     중복 AOI: CRC_20211007 slide2 | 008 | w_o tumor, BK_colon cancer_20211007 slide2 | 008 | w_o tumor
#
#   그룹 19: 3개 동일한 AOI
#     대표 AOI: CRC(2)_20211007 slide2 | 009 | w_o tumor
#     중복 AOI: CRC_20211007 slide2 | 009 | w_o tumor, BK_colon cancer_20211007 slide2 | 009 | w_o tumor
#
#   그룹 20: 3개 동일한 AOI
#     대표 AOI: CRC(2)_20211007 slide2 | 010 | w_o tumor
#     중복 AOI: CRC_20211007 slide2 | 010 | w_o tumor, BK_colon cancer_20211007 slide2 | 010 | w_o tumor
#
#   그룹 21: 3개 동일한 AOI
#     대표 AOI: CRC(2)_20211007 slide2 | 011 | w_o tumor
#     중복 AOI: CRC_20211007 slide2 | 011 | w_o tumor, BK_colon cancer_20211007 slide2 | 011 | w_o tumor
#
#
# ✂️  제거된 컬럼 수: 34
# ✅ 남은 전체 컬럼 수: 51
# 💾 메모리 절감: 20.2%
#
# ✅ 검증 완료: 데이터 무결성 확인
#
# 📄 리포트 저장 완료: /data/kjc1/projects/#999. GeoMx meta/pooled/csv_files/merged/merged_CTA_filtered_duplicate_report.json
# 💾 필터링된 파일 저장: /data/kjc1/projects/#999. GeoMx meta/pooled/csv_files/merged/merged_CTA_filtered.csv
#    원본: 85 columns → 필터링: 51 columns
# 📁 파일 읽기: /data/kjc1/projects/#999. GeoMx meta/pooled/csv_files/merged/merged_MOUSE.csv
# 📊 전체 컬럼 수: 330
# 📊 AOI 컬럼 수: 318
# 🔍 중복 검사 시작...
#
# 🔍 발견된 중복 그룹: 102개
# 📉 제거 가능한 중복 AOI: 102개
#
#   그룹 1: 2개 동일한 AOI
#     대표 AOI: NHS_H | 001 | Segment 1
#     중복 AOI: mouse_nasal_polyp..._H | 001 | Segment 1
#
#   그룹 2: 2개 동일한 AOI
#     대표 AOI: NHS_H | 002 | Segment 1
#     중복 AOI: mouse_nasal_polyp..._H | 002 | Segment 1
#
#   그룹 3: 2개 동일한 AOI
#     대표 AOI: NHS_H | 003 | Segment 1
#     중복 AOI: mouse_nasal_polyp..._H | 003 | Segment 1
#
#   그룹 4: 2개 동일한 AOI
#     대표 AOI: NHS_H | 004 | Segment 1
#     중복 AOI: mouse_nasal_polyp..._H | 004 | Segment 1
#
#   그룹 5: 2개 동일한 AOI
#     대표 AOI: NHS_H | 005 | Segment 1
#     중복 AOI: mouse_nasal_polyp..._H | 005 | Segment 1
#
#   그룹 6: 2개 동일한 AOI
#     대표 AOI: NHS_H | 006 | Segment 1
#     중복 AOI: mouse_nasal_polyp..._H | 006 | Segment 1
#
#   그룹 7: 2개 동일한 AOI
#     대표 AOI: NHS_H | 007 | Segment 1
#     중복 AOI: mouse_nasal_polyp..._H | 007 | Segment 1
#
#   그룹 8: 2개 동일한 AOI
#     대표 AOI: NHS_H | 008 | Segment 1
#     중복 AOI: mouse_nasal_polyp..._H | 008 | Segment 1
#
#   그룹 9: 2개 동일한 AOI
#     대표 AOI: NHS_H | 009 | Segment 1
#     중복 AOI: mouse_nasal_polyp..._H | 009 | Segment 1
#
#   그룹 10: 2개 동일한 AOI
#     대표 AOI: NHS_H | 010 | Segment 1
#     중복 AOI: mouse_nasal_polyp..._H | 010 | Segment 1
#
#   그룹 11: 2개 동일한 AOI
#     대표 AOI: NHS_H | 011 | Segment 1
#     중복 AOI: mouse_nasal_polyp..._H | 011 | Segment 1
#
#   그룹 12: 2개 동일한 AOI
#     대표 AOI: NHS_H | 012 | Segment 1
#     중복 AOI: mouse_nasal_polyp..._H | 012 | Segment 1
#
#   그룹 13: 2개 동일한 AOI
#     대표 AOI: NHS_SHIN_ROZA_241217 | 001 | Segment 1
#     중복 AOI: mouse_nasal_polyp..._SHIN_ROZA_241217 | 001 | Segment 1
#
#   그룹 14: 2개 동일한 AOI
#     대표 AOI: NHS_SHIN_ROZA_241217 | 002 | Segment 1
#     중복 AOI: mouse_nasal_polyp..._SHIN_ROZA_241217 | 002 | Segment 1
#
#   그룹 15: 2개 동일한 AOI
#     대표 AOI: NHS_SHIN_ROZA_241217 | 003 | Segment 1
#     중복 AOI: mouse_nasal_polyp..._SHIN_ROZA_241217 | 003 | Segment 1
#
#   그룹 16: 2개 동일한 AOI
#     대표 AOI: NHS_SHIN_ROZA_241217 | 004 | Segment 1
#     중복 AOI: mouse_nasal_polyp..._SHIN_ROZA_241217 | 004 | Segment 1
#
#   그룹 17: 2개 동일한 AOI
#     대표 AOI: NHS_SHIN_ROZA_241217 | 005 | Segment 1
#     중복 AOI: mouse_nasal_polyp..._SHIN_ROZA_241217 | 005 | Segment 1
#
#   그룹 18: 2개 동일한 AOI
#     대표 AOI: NHS_SHIN_ROZA_241217 | 006 | Segment 1
#     중복 AOI: mouse_nasal_polyp..._SHIN_ROZA_241217 | 006 | Segment 1
#
#   그룹 19: 2개 동일한 AOI
#     대표 AOI: NHS_SHIN_ROZA_241217 | 007 | Segment 1
#     중복 AOI: mouse_nasal_polyp..._SHIN_ROZA_241217 | 007 | Segment 1
#
#   그룹 20: 2개 동일한 AOI
#     대표 AOI: NHS_SHIN_ROZA_241217 | 008 | Segment 1
#     중복 AOI: mouse_nasal_polyp..._SHIN_ROZA_241217 | 008 | Segment 1
#
#   그룹 21: 2개 동일한 AOI
#     대표 AOI: NHS_SHIN_ROZA_241217 | 009 | Segment 1
#     중복 AOI: mouse_nasal_polyp..._SHIN_ROZA_241217 | 009 | Segment 1
#
#   그룹 22: 2개 동일한 AOI
#     대표 AOI: NHS_SHIN_ROZA_241217 | 010 | Segment 1
#     중복 AOI: mouse_nasal_polyp..._SHIN_ROZA_241217 | 010 | Segment 1
#
#   그룹 23: 2개 동일한 AOI
#     대표 AOI: NHS_SHIN_ROZA_241217 | 011 | Segment 1
#     중복 AOI: mouse_nasal_polyp..._SHIN_ROZA_241217 | 011 | Segment 1
#
#   그룹 24: 2개 동일한 AOI
#     대표 AOI: NHS_SHIN_ROZA_241217 | 012 | Segment 1
#     중복 AOI: mouse_nasal_polyp..._SHIN_ROZA_241217 | 012 | Segment 1
#
#   그룹 25: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 001 | PanCK+
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 001 | PanCK+
#
#   그룹 26: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 001 | Iba+
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 001 | Iba+
#
#   그룹 27: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 001 | PanCK-Iba-
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 001 | PanCK-Iba-
#
#   그룹 28: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 002 | PanCK+
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 002 | PanCK+
#
#   그룹 29: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 002 | Iba+
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 002 | Iba+
#
#   그룹 30: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 002 | PanCK-Iba-
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 002 | PanCK-Iba-
#
#   그룹 31: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 003 | PanCK+
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 003 | PanCK+
#
#   그룹 32: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 003 | Iba+
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 003 | Iba+
#
#   그룹 33: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 003 | PanCK-Iba-
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 003 | PanCK-Iba-
#
#   그룹 34: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 004 | PanCK+
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 004 | PanCK+
#
#   그룹 35: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 004 | Iba+
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 004 | Iba+
#
#   그룹 36: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 004 | PanCK-Iba-
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 004 | PanCK-Iba-
#
#   그룹 37: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 005 | PanCK+
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 005 | PanCK+
#
#   그룹 38: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 005 | Iba+
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 005 | Iba+
#
#   그룹 39: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 005 | PanCK-Iba-
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 005 | PanCK-Iba-
#
#   그룹 40: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 006 | PanCK+
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 006 | PanCK+
#
#   그룹 41: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 006 | Iba+
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 006 | Iba+
#
#   그룹 42: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 006 | PanCK-Iba-
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 006 | PanCK-Iba-
#
#   그룹 43: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 007 | PanCK+
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 007 | PanCK+
#
#   그룹 44: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 007 | Iba+
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 007 | Iba+
#
#   그룹 45: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 007 | PanCK-Iba-
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 007 | PanCK-Iba-
#
#   그룹 46: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 008 | PanCK+
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 008 | PanCK+
#
#   그룹 47: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 008 | Iba+
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 008 | Iba+
#
#   그룹 48: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 008 | PanCK-Iba-
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 008 | PanCK-Iba-
#
#   그룹 49: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 009 | PanCK+
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 009 | PanCK+
#
#   그룹 50: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 009 | Iba+
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 009 | Iba+
#
#   그룹 51: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 009 | PanCK-Iba-
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 009 | PanCK-Iba-
#
#   그룹 52: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 010 | Iba+
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 010 | Iba+
#
#   그룹 53: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 010 | PanCK-Iba-
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 010 | PanCK-Iba-
#
#   그룹 54: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 011 | Iba+
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 011 | Iba+
#
#   그룹 55: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 011 | PanCK-Iba-
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 011 | PanCK-Iba-
#
#   그룹 56: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 012 | Iba+
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 012 | Iba+
#
#   그룹 57: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 012 | PanCK-Iba-
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 012 | PanCK-Iba-
#
#   그룹 58: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 013 | PanCK+
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 013 | PanCK+
#
#   그룹 59: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 013 | Iba+
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 013 | Iba+
#
#   그룹 60: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 013 | PanCK-Iba-
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 013 | PanCK-Iba-
#
#   그룹 61: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 014 | PanCK+
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 014 | PanCK+
#
#   그룹 62: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 014 | Iba+
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 014 | Iba+
#
#   그룹 63: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 014 | PanCK-Iba-
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 014 | PanCK-Iba-
#
#   그룹 64: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 015 | PanCK+
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 015 | PanCK+
#
#   그룹 65: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 015 | Iba+
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 015 | Iba+
#
#   그룹 66: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 015 | PanCK-Iba-
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 015 | PanCK-Iba-
#
#   그룹 67: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 016 | PanCK+
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 016 | PanCK+
#
#   그룹 68: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 016 | Iba+
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 016 | Iba+
#
#   그룹 69: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 016 | PanCK-Iba-
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 016 | PanCK-Iba-
#
#   그룹 70: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 017 | PanCK+
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 017 | PanCK+
#
#   그룹 71: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 017 | Iba+
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 017 | Iba+
#
#   그룹 72: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 017 | PanCK-Iba-
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 017 | PanCK-Iba-
#
#   그룹 73: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 018 | PanCK+
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 018 | PanCK+
#
#   그룹 74: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 018 | Iba+
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 018 | Iba+
#
#   그룹 75: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 018 | PanCK-Iba-
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 018 | PanCK-Iba-
#
#   그룹 76: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 019 | PanCK+
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 019 | PanCK+
#
#   그룹 77: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 019 | Iba+
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 019 | Iba+
#
#   그룹 78: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 019 | PanCK-Iba-
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 019 | PanCK-Iba-
#
#   그룹 79: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 020 | PanCK+
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 020 | PanCK+
#
#   그룹 80: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 020 | Iba+
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 020 | Iba+
#
#   그룹 81: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 020 | PanCK-Iba-
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 020 | PanCK-Iba-
#
#   그룹 82: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 021 | PanCK+
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 021 | PanCK+
#
#   그룹 83: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 021 | Iba+
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 021 | Iba+
#
#   그룹 84: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 021 | PanCK-Iba-
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 021 | PanCK-Iba-
#
#   그룹 85: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 022 | PanCK+
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 022 | PanCK+
#
#   그룹 86: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 022 | Iba+
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 022 | Iba+
#
#   그룹 87: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 022 | PanCK-Iba-
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 022 | PanCK-Iba-
#
#   그룹 88: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 023 | PanCK+
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 023 | PanCK+
#
#   그룹 89: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 023 | Iba+
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 023 | Iba+
#
#   그룹 90: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 023 | PanCK-Iba-
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 023 | PanCK-Iba-
#
#   그룹 91: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 024 | PanCK+
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 024 | PanCK+
#
#   그룹 92: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 024 | Iba+
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 024 | Iba+
#
#   그룹 93: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 024 | PanCK-Iba-
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 024 | PanCK-Iba-
#
#   그룹 94: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 025 | PanCK+
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 025 | PanCK+
#
#   그룹 95: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 025 | Iba+
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 025 | Iba+
#
#   그룹 96: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 025 | PanCK-Iba-
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 025 | PanCK-Iba-
#
#   그룹 97: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 026 | PanCK+
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 026 | PanCK+
#
#   그룹 98: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 026 | Iba+
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 026 | Iba+
#
#   그룹 99: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 026 | PanCK-Iba-
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 026 | PanCK-Iba-
#
#   그룹 100: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 027 | PanCK+
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 027 | PanCK+
#
#   그룹 101: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 027 | Iba+
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 027 | Iba+
#
#   그룹 102: 2개 동일한 AOI
#     대표 AOI: Wound_GeoMx_240610_wound_GeoMx | 027 | PanCK-Iba-
#     중복 AOI: Wound_KHW_240610_wound_GeoMx | 027 | PanCK-Iba-
#
#
# ✂️  제거된 컬럼 수: 102
# ✅ 남은 전체 컬럼 수: 228
# 💾 메모리 절감: 25.3%
#
# ✅ 검증 완료: 데이터 무결성 확인
#
# 📄 리포트 저장 완료: /data/kjc1/projects/#999. GeoMx meta/pooled/csv_files/merged/merged_MOUSE_filtered_duplicate_report.json
# 💾 필터링된 파일 저장: /data/kjc1/projects/#999. GeoMx meta/pooled/csv_files/merged/merged_MOUSE_filtered.csv
#    원본: 330 columns → 필터링: 228 columns

# %% [markdown]
# # Metadata Handler

# %% [markdown]
# ## Metadata 추출, csv 변환

# %% [markdown]
# ### 오류!

# %% [markdown]
# 함수 설명
#
# GeomXProcessor 하에..
# <!-- detect_data_type: columns를 다 합쳐서, "LOT_Cancer_Transcriptome_Atlas"가 있으면 CTA, "LOT_Mouse_NGS"가 있으면 mouse, 아니면 WTA로 분류
# extract_segment_properties: openpyxl로 xlsx 읽어서 SegmentProperties sheet 찾아 pa로 출력
# analyze_unique_columns:(AUC) WTA/CTA/mouse에 따라 common columns를 제한 unique columns 얻어내기. 데이터타입 알아내고, 고유값 샘플 (최대 10개) 얻어냄. unique_columns_analysis에 저장. 전체 데이터 얻어내 files_data에 저장.
# infer_column_type: 데이터 타입 알아내는 함수. AUC내에서 사용됨. true, false, yes, no, 1, 0, t, f, y, n이 사용되면 boolean으로 간주. Empty, Boolean, Numeric, Category(가짓수가 AOI수의 10% 미만), String
# process_directory: 디렉토리 내 모든 xlsx파일 찾아 처리
# save_analysis_results: 결과를 csv파일로 출력
# generate_mapping_template: column 매핑 템플릿 생성; 즉, dataset 1, 2, 3에서 사용된 PanCK, Panck, ck 같은 서로 다른 column명들을 어떻게 바꿔줄지 (예: "CK"), 값들은 뭘로 바꿔줄지 (예: True->TRUE)
# apply_mappings_and_merge: 위에서 만든 매핑 파일을 읽어서, 모든 메타데이터를 변환시키고, 병합. -->
# AOIMatcher 하에...
# <!-- match_aoi_columns: merged matrix & merged metadata를 읽어서 매칭시킴.
# 매칭 딕셔너리를 생성한다. metadata의 AOI명에 대하여, 1) 이것이 matrix의 AOI명에 있으면 그냥 매칭시키고, 2) 없으면, pattern은 _{}, | {}, {}이 _로 분리된 것의 마지막에 있는지, |로 분리된 것의 마지막에 있는지로 찾음.
# # -> 이거 좀 많이 잘못된거같은데..? 오히려 맨 앞에 나와야 하는데.
# Matrix에만 있는 column를 정리해둠. 매칭안된 것들. -->

# %% [raw]
# 몇 개 안 읽히는 문제,
# 무의미한 열 추가,
# colum_mapping_template.csv 안 생기는 문제,
# 디버깅하여 v2가 됨.
#
#
# v1 실행 오류,
# Traceback (most recent call last):
#   File "/data/kjc1/mylit/ipynb/geomx_processor.py", line 491, in <module>
#     main()
#   File "/data/kjc1/mylit/ipynb/geomx_processor.py", line 481, in main
#     processor.apply_mappings_and_merge(args.mapping_file, args.output)
#   File "/data/kjc1/mylit/ipynb/geomx_processor.py", line 301, in apply_mappings_and_merge
#     merged_metadata = pd.concat(merged_dfs, ignore_index=True, sort=False)
#   File "/home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/pandas/core/reshape/concat.py", line 395, in concat
#     return op.get_result()
#   File "/home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/pandas/core/reshape/concat.py", line 680, in get_result
#     indexers[ax] = obj_labels.get_indexer(new_labels)
#   File "/home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/pandas/core/indexes/base.py", line 3885, in get_indexer
#     raise InvalidIndexError(self._requires_unique_msg)
# pandas.errors.InvalidIndexError: Reindexing only valid with uniquely valued Index objects
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 get_ipython().run_cell_magic('bash', '', '# 4. Metadata 통합\nxlsx_folder="/data/kjc1/projects/#999.GeoMxmeta/pooled/"\npython geomx_processor.py merge $xlsx_folder ./output/column_mapping_template.csv -o ./output\n')
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2478, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2476 with self.builtin_trap:
#    2477     args = (magic_arg_s, cell)
# -> 2478     result = fn(*args, **kwargs)
#    2480 # The code below prevents the output from being displayed
#    2481 # when using magics with decodator @output_can_be_silenced
#    2482 # when the last Python token in the expression is a ';'.
#    2483 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/magics/script.py:153, in ScriptMagics._make_script_magic.<locals>.named_script_magic(line, cell)
#     151 else:
#     152     line = script
# --> 153 return self.shebang(line, cell)
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/magics/script.py:305, in ScriptMagics.shebang(self, line, cell)
#     300 if args.raise_error and p.returncode != 0:
#     301     # If we get here and p.returncode is still None, we must have
#     302     # killed it but not yet seen its return code. We don't wait for it,
#     303     # in case it's stuck in uninterruptible sleep. -9 = SIGKILL
#     304     rc = p.returncode or -9
# --> 305     raise CalledProcessError(rc, cell)
#
# CalledProcessError: Command 'b'# 4. Metadata \xed\x86\xb5\xed\x95\xa9\nxlsx_folder="/data/kjc1/projects/#999.GeoMxmeta/pooled/"\npython geomx_processor.py merge $xlsx_folder ./output/column_mapping_template.csv -o ./output\n'' returned non-zero exit status 1.
# v2 실행 오류
# Traceback (most recent call last):
#   File "/data/kjc1/mylit/ipynb/geomx_processor_v2.py", line 653, in <module>
#     main()
#   File "/data/kjc1/mylit/ipynb/geomx_processor_v2.py", line 643, in main
#     processor.apply_mappings_and_merge(args.mapping_file, args.output)
#   File "/data/kjc1/mylit/ipynb/geomx_processor_v2.py", line 460, in apply_mappings_and_merge
#     merged_metadata = pd.concat(merged_dfs, ignore_index=True, sort=False)
#   File "/home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/pandas/core/reshape/concat.py", line 395, in concat
#     return op.get_result()
#   File "/home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/pandas/core/reshape/concat.py", line 680, in get_result
#     indexers[ax] = obj_labels.get_indexer(new_labels)
#   File "/home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/pandas/core/indexes/base.py", line 3885, in get_indexer
#     raise InvalidIndexError(self._requires_unique_msg)
# pandas.errors.InvalidIndexError: Reindexing only valid with uniquely valued Index objects
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 get_ipython().run_cell_magic('bash', '', '# 4. Metadata 통합\nxlsx_folder="/data/kjc1/projects/#999.GeoMxmeta/pooled/"\npython geomx_processor_v2.py merge $xlsx_folder ./output/column_mapping_template.csv -o ./output\n')
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2478, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2476 with self.builtin_trap:
#    2477     args = (magic_arg_s, cell)
# -> 2478     result = fn(*args, **kwargs)
#    2480 # The code below prevents the output from being displayed
#    2481 # when using magics with decodator @output_can_be_silenced
#    2482 # when the last Python token in the expression is a ';'.
#    2483 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/magics/script.py:153, in ScriptMagics._make_script_magic.<locals>.named_script_magic(line, cell)
#     151 else:
#     152     line = script
# --> 153 return self.shebang(line, cell)
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/magics/script.py:305, in ScriptMagics.shebang(self, line, cell)
#     300 if args.raise_error and p.returncode != 0:
#     301     # If we get here and p.returncode is still None, we must have
#     302     # killed it but not yet seen its return code. We don't wait for it,
#     303     # in case it's stuck in uninterruptible sleep. -9 = SIGKILL
#     304     rc = p.returncode or -9
# --> 305     raise CalledProcessError(rc, cell)
#
# CalledProcessError: Command 'b'# 4. Metadata \xed\x86\xb5\xed\x95\xa9\nxlsx_folder="/data/kjc1/projects/#999.GeoMxmeta/pooled/"\npython geomx_processor_v2.py merge $xlsx_folder ./output/column_mapping_template.csv -o ./output\n'' returned non-zero exit status 1.

# %% [markdown]
# ### ver1. 함수정의부; .py 문서로 사용되어야 함.

# %%
#!/usr/bin/env python3
"""
GeomX Data Processor - Metadata Column Harmonization Tool
리눅스 서버 환경용 Python CLI 버전
"""

import pandas as pd
import numpy as np
import os
import sys
import argparse
import hashlib
import json
from pathlib import Path
from typing import Dict, List, Tuple, Optional
import warnings
warnings.filterwarnings('ignore')

# 공통 columns 정의 (다양한 데이터 타입별로)
COMMON_COLUMNS = {
    'WTA': [
        'SlideName', 'ScanLabel', 'ROILabel', 'SegmentLabel', 'SegmentDisplayName',
        'Origin Instrument ID', 'QCFlags', 'AOISurfaceArea', 'AOINucleiCount',
        'ROICoordinateX', 'ROICoordinateY', 'RawReads', 'AlignedReads',
        'DeduplicatedReads', 'TrimmedReads', 'StitchedReads', 'SequencingSaturation',
        'SequencingSetID', 'UMIQ30', 'RTSQ30', 'GeoMxNgsPipelineVersion',
        'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1_0', 'ROIID', 'SegmentID',
        'ScanWidth', 'ScanHeight', 'ScanOffsetX', 'ScanOffsetY'
    ],
    'CTA': [
        'SlideName', 'ScanLabel', 'ROILabel', 'SegmentLabel', 'SegmentDisplayName',
        'Origin Instrument ID', 'QCFlags', 'AOISurfaceArea', 'AOINucleiCount',
        'ROICoordinateX', 'ROICoordinateY', 'RawReads', 'AlignedReads',
        'DeduplicatedReads', 'TrimmedReads', 'StitchedReads', 'SequencingSaturation',
        'SequencingSetID', 'UMIQ30', 'RTSQ30', 'GeoMxNgsPipelineVersion',
        'LOT_Cancer_Transcriptome_Atlas', 'ROIID', 'SegmentID',
        'ScanWidth', 'ScanHeight', 'ScanOffsetX', 'ScanOffsetY'
    ],
    'MOUSE': [
        'SlideName', 'ScanLabel', 'ROILabel', 'SegmentLabel', 'SegmentDisplayName',
        'Origin Instrument ID', 'QCFlags', 'AOISurfaceArea', 'AOINucleiCount',
        'ROICoordinateX', 'ROICoordinateY', 'RawReads', 'AlignedReads',
        'DeduplicatedReads', 'TrimmedReads', 'StitchedReads', 'SequencingSaturation',
        'SequencingSetID', 'UMIQ30', 'RTSQ30', 'GeoMxNgsPipelineVersion',
        'LOT_Mouse_NGS_Whole_Transcriptome_Atlas_RNA_1_0', 'ROIID', 'SegmentID',
        'ScanWidth', 'ScanHeight', 'ScanOffsetX', 'ScanOffsetY'
    ]
}

class GeomXProcessor:
    def __init__(self, verbose=True):
        self.verbose = verbose
        self.files_data = []
        self.unique_columns_analysis = []
        self.column_mappings = {}
        
    def log(self, message):
        if self.verbose:
            print(f"[INFO] {message}")
    
    def detect_data_type(self, df_columns):
        """데이터 타입 자동 감지 (WTA, CTA, MOUSE)"""
        columns_str = ' '.join(df_columns)
        
        if 'LOT_Cancer_Transcriptome_Atlas' in columns_str:
            return 'CTA'
        elif 'LOT_Mouse_NGS' in columns_str:
            return 'MOUSE'
        else:
            return 'WTA'
    
    def extract_segment_properties(self, file_path):
        """xlsx 파일에서 SegmentProperties 시트 추출"""
        try:
            # openpyxl 엔진 사용하여 안정적으로 읽기
            excel_file = pd.ExcelFile(file_path, engine='openpyxl')
            
            # SegmentProperties 시트 찾기
            sheet_name = None
            for sheet in excel_file.sheet_names:
                if 'SegmentProperties' in sheet:
                    sheet_name = sheet
                    break
            
            if not sheet_name:
                self.log(f"Warning: SegmentProperties sheet not found in {file_path}")
                return None
            
            df = pd.read_excel(excel_file, sheet_name=sheet_name)
            return df
            
        except Exception as e:
            self.log(f"Error reading {file_path}: {str(e)}")
            return None
    
    def analyze_unique_columns(self, file_path):
        """파일의 고유 column 분석"""
        df = self.extract_segment_properties(file_path)
        if df is None:
            return
        
        file_name = Path(file_path).stem
        data_type = self.detect_data_type(df.columns.tolist())
        common_cols = COMMON_COLUMNS.get(data_type, COMMON_COLUMNS['WTA'])
        
        # 고유 columns 찾기
        unique_cols = [col for col in df.columns if col not in common_cols]
        
        self.log(f"File: {file_name}")
        self.log(f"  Data Type: {data_type}")
        self.log(f"  Total Columns: {len(df.columns)}")
        self.log(f"  Unique Columns: {len(unique_cols)}")
        
        # 각 고유 column 분석
        for col in unique_cols:
            # 데이터 타입 추론
            dtype = self.infer_column_type(df[col])
            
            # 고유값 샘플
            unique_values = df[col].dropna().unique()
            value_sample = list(unique_values[:10])  # 최대 10개
            
            self.unique_columns_analysis.append({
                'dataset': file_name,
                'data_type': data_type,
                'column_name': col,
                'dtype': dtype,
                'unique_values': value_sample,
                'unique_count': len(unique_values),
                'null_count': df[col].isna().sum(),
                'total_count': len(df)
            })
        
        # 전체 데이터 저장
        self.files_data.append({
            'file_name': file_name,
            'data_type': data_type,
            'dataframe': df,
            'unique_columns': unique_cols
        })
    
    def infer_column_type(self, series):
        """Column의 데이터 타입 추론"""
        non_null = series.dropna()
        if len(non_null) == 0:
            return 'Empty'
        
        # Boolean 체크
        unique_lower = set(str(v).lower() for v in non_null.unique())
        bool_values = {'true', 'false', 'yes', 'no', '1', '0', 't', 'f', 'y', 'n'}
        if unique_lower.issubset(bool_values):
            return 'Boolean'
        
        # Numeric 체크
        try:
            pd.to_numeric(non_null)
            return 'Numeric'
        except:
            pass
        
        # Category 체크 (고유값이 전체의 10% 미만)
        if len(non_null.unique()) < len(non_null) * 0.1:
            return 'Category'
        
        return 'String'
    
    def process_directory(self, directory_path):
        """디렉토리 내 모든 xlsx 파일 처리"""
        xlsx_files = list(Path(directory_path).glob("*.xlsx"))
        self.log(f"Found {len(xlsx_files)} xlsx files")
        
        for file_path in xlsx_files:
            self.analyze_unique_columns(str(file_path))
    
    def save_analysis_results(self, output_dir):
        """분석 결과 저장"""
        output_path = Path(output_dir)
        output_path.mkdir(exist_ok=True)
        
        # 1. 고유 column 분석 결과
        if self.unique_columns_analysis:
            df_analysis = pd.DataFrame(self.unique_columns_analysis)
            
            # unique_values를 문자열로 변환
            df_analysis['unique_values'] = df_analysis['unique_values'].apply(
                lambda x: ', '.join(map(str, x)) if isinstance(x, list) else str(x)
            )
            
            output_file = output_path / 'unique_columns_analysis.csv'
            df_analysis.to_csv(output_file, index=False)
            self.log(f"Saved unique columns analysis to {output_file}")
            
            # 요약 통계
            print("\n=== Unique Columns Summary ===")
            print(df_analysis.groupby(['data_type', 'column_name']).size().to_string())
    
    def generate_mapping_template(self, output_dir):
        """Column 매핑 템플릿 생성"""
        if not self.unique_columns_analysis:
            self.log("No analysis data available")
            return
        
        df = pd.DataFrame(self.unique_columns_analysis)
        
        # column별 그룹화
        mapping_template = []
        for col_name in df['column_name'].unique():
            col_data = df[df['column_name'] == col_name]
            
            # 모든 고유값 수집
            all_values = set()
            for values_str in col_data['unique_values']:
                if pd.notna(values_str):
                    values = values_str.split(', ') if isinstance(values_str, str) else []
                    all_values.update(values)
            
            mapping_template.append({
                'original_column': col_name,
                'unified_name': col_name,  # 기본값
                'data_types': ', '.join(col_data['data_type'].unique()),
                'datasets': ', '.join(col_data['dataset'].unique()),
                'sample_values': ', '.join(list(all_values)[:20]),
                'value_mapping': '',  # 사용자가 채울 부분
                'notes': ''
            })
        
        df_template = pd.DataFrame(mapping_template)
        output_file = Path(output_dir) / 'column_mapping_template.csv'
        df_template.to_csv(output_file, index=False)
        self.log(f"Saved mapping template to {output_file}")
        
        return df_template
    
    def apply_mappings_and_merge(self, mapping_file, output_dir):
        """매핑 적용 및 metadata 통합"""
        # 매핑 파일 읽기
        df_mapping = pd.read_csv(mapping_file)
        
        # 매핑 딕셔너리 생성
        column_mappings = {}
        value_mappings = {}
        
        for _, row in df_mapping.iterrows():
            original = row['original_column']
            unified = row['unified_name']
            column_mappings[original] = unified
            
            # 값 매핑 파싱
            if pd.notna(row.get('value_mapping', '')):
                mappings = row['value_mapping'].split(',')
                value_map = {}
                for mapping in mappings:
                    if '=' in mapping:
                        old, new = mapping.strip().split('=', 1)
                        value_map[old.strip()] = new.strip()
                if value_map:
                    value_mappings[original] = value_map
        
        # 모든 데이터프레임 통합
        merged_dfs = []
        
        for file_data in self.files_data:
            df = file_data['dataframe'].copy()
            df['_source_file'] = file_data['file_name']
            df['_data_type'] = file_data['data_type']
            
            # Column 이름 매핑
            rename_dict = {}
            for col in df.columns:
                if col in column_mappings:
                    rename_dict[col] = column_mappings[col]
            
            if rename_dict:
                df = df.rename(columns=rename_dict)
            
            # 값 매핑 적용
            for original_col, value_map in value_mappings.items():
                mapped_col = column_mappings.get(original_col, original_col)
                if mapped_col in df.columns:
                    df[mapped_col] = df[mapped_col].replace(value_map)
            
            merged_dfs.append(df)
        
        # 최종 통합
        if merged_dfs:
            merged_metadata = pd.concat(merged_dfs, ignore_index=True, sort=False)
            
            output_file = Path(output_dir) / 'merged_metadata.csv'
            merged_metadata.to_csv(output_file, index=False)
            self.log(f"Saved merged metadata to {output_file}")
            
            print(f"\n=== Merge Summary ===")
            print(f"Total rows: {len(merged_metadata)}")
            print(f"Total columns: {len(merged_metadata.columns)}")
            print(f"Data types: {merged_metadata['_data_type'].value_counts().to_dict()}")
            
            return merged_metadata
        
        return None

class AOIMatcher:
    """Count Matrix와 Metadata 매칭"""
    
    def __init__(self, verbose=True):
        self.verbose = verbose
        
    def log(self, message):
        if self.verbose:
            print(f"[INFO] {message}")
    
    def match_aoi_columns(self, matrix_csv, metadata_csv, output_dir):
        """
        사용자가 이미 처리한 count matrix CSV와 metadata CSV를 매칭
        
        matrix_csv: 첫 column은 gene, 나머지는 AOI columns
        metadata_csv: SegmentDisplayName column이 있는 metadata
        """
        # 파일 읽기
        self.log("Reading count matrix...")
        df_matrix = pd.read_csv(matrix_csv, index_col=0)  # 첫 column을 index로
        matrix_columns = df_matrix.columns.tolist()
        
        self.log("Reading metadata...")
        df_metadata = pd.read_csv(metadata_csv)
        
        if 'SegmentDisplayName' not in df_metadata.columns:
            raise ValueError("Metadata must have 'SegmentDisplayName' column")
        
        # 매칭 수행
        metadata_segments = df_metadata['SegmentDisplayName'].unique()
        
        matched = []
        unmatched_metadata = []
        fuzzy_matched = []
        
        # 매칭 딕셔너리 생성
        match_dict = {}
        
        for segment in metadata_segments:
            if pd.isna(segment):
                continue
                
            segment_str = str(segment)
            
            # 1. 정확 매칭
            if segment_str in matrix_columns:
                matched.append(segment_str)
                match_dict[segment_str] = segment_str
                
            else:
                # 2. Fuzzy 매칭 시도
                found = False
                
                # 파일명_AOI명 형식 찾기
                for col in matrix_columns:
                    # 여러 패턴 시도
                    patterns = [
                        col.endswith(f'_{segment_str}'),
                        col.endswith(f' | {segment_str}'),
                        segment_str in col.split('_')[-1],
                        col.split(' | ')[-1] == segment_str if ' | ' in col else False
                    ]
                    
                    if any(patterns):
                        fuzzy_matched.append((segment_str, col))
                        match_dict[segment_str] = col
                        found = True
                        break
                
                if not found:
                    unmatched_metadata.append(segment_str)
        
        # Matrix에만 있는 columns
        matched_matrix_cols = set(match_dict.values())
        unmatched_matrix = [col for col in matrix_columns if col not in matched_matrix_cols]
        
        # 결과 출력
        print("\n=== Matching Results ===")
        print(f"Exact matches: {len(matched)}")
        print(f"Fuzzy matches: {len(fuzzy_matched)}")
        print(f"Unmatched metadata: {len(unmatched_metadata)}")
        print(f"Unmatched matrix columns: {len(unmatched_matrix)}")
        
        # Fuzzy 매칭 상세
        if fuzzy_matched:
            print("\n=== Fuzzy Matches (Top 10) ===")
            for meta, matrix in fuzzy_matched[:10]:
                print(f"  {meta} → {matrix}")
        
        # 매칭된 metadata 저장
        df_metadata['matrix_column'] = df_metadata['SegmentDisplayName'].map(match_dict)
        df_matched = df_metadata[df_metadata['matrix_column'].notna()]
        
        output_path = Path(output_dir)
        output_path.mkdir(exist_ok=True)
        
        # 매칭된 metadata 저장
        matched_file = output_path / 'matched_metadata.csv'
        df_matched.to_csv(matched_file, index=False)
        self.log(f"Saved matched metadata to {matched_file}")
        
        # 매칭 리포트 저장
        report_file = output_path / 'matching_report.json'
        report = {
            'summary': {
                'total_metadata_segments': len(metadata_segments),
                'exact_matches': len(matched),
                'fuzzy_matches': len(fuzzy_matched),
                'unmatched_metadata': len(unmatched_metadata),
                'unmatched_matrix': len(unmatched_matrix)
            },
            'fuzzy_matches': fuzzy_matched,
            'unmatched_metadata': unmatched_metadata,
            'unmatched_matrix': unmatched_matrix[:50]  # 최대 50개만
        }
        
        with open(report_file, 'w') as f:
            json.dump(report, f, indent=2)
        self.log(f"Saved matching report to {report_file}")
        
        # 매칭된 matrix subset 저장 (옵션)
        if len(df_matched) > 0:
            matched_cols = df_matched['matrix_column'].unique()
            matched_cols = [col for col in matched_cols if col in matrix_columns]
            
            if matched_cols:
                df_matrix_matched = df_matrix[matched_cols]
                matrix_file = output_path / 'matched_count_matrix.csv'
                df_matrix_matched.to_csv(matrix_file)
                self.log(f"Saved matched count matrix to {matrix_file}")
        
        return df_matched, report

def main():
    parser = argparse.ArgumentParser(description='GeomX Data Processor')
    subparsers = parser.add_subparsers(dest='command', help='Commands')
    
    # analyze 명령
    analyze_parser = subparsers.add_parser('analyze', help='Analyze unique columns in xlsx files')
    analyze_parser.add_argument('input_dir', help='Directory containing xlsx files')
    analyze_parser.add_argument('-o', '--output', default='./output', help='Output directory')
    
    # merge 명령
    merge_parser = subparsers.add_parser('merge', help='Apply mappings and merge metadata')
    merge_parser.add_argument('input_dir', help='Directory containing xlsx files')
    merge_parser.add_argument('mapping_file', help='CSV file with column mappings')
    merge_parser.add_argument('-o', '--output', default='./output', help='Output directory')
    
    # match 명령
    match_parser = subparsers.add_parser('match', help='Match count matrix with metadata')
    match_parser.add_argument('matrix_csv', help='Count matrix CSV file')
    match_parser.add_argument('metadata_csv', help='Metadata CSV file')
    match_parser.add_argument('-o', '--output', default='./output', help='Output directory')
    
    args = parser.parse_args()
    
    if args.command == 'analyze':
        processor = GeomXProcessor()
        processor.process_directory(args.input_dir)
        processor.save_analysis_results(args.output)
        processor.generate_mapping_template(args.output)
        
    elif args.command == 'merge':
        processor = GeomXProcessor()
        processor.process_directory(args.input_dir)
        processor.apply_mappings_and_merge(args.mapping_file, args.output)
        
    elif args.command == 'match':
        matcher = AOIMatcher()
        matcher.match_aoi_columns(args.matrix_csv, args.metadata_csv, args.output)
        
    else:
        parser.print_help()

if __name__ == "__main__":
    main()

# %% [markdown]
# ### ver1. .py 사용부

# %%
# %%bash
# # 2. 고유 column 분석
# xlsx_folder="/data/kjc1/projects/#999.GeoMxmeta/pooled/"
# echo $xlsx_folder
# python geomx_processor.py analyze $xlsx_folder -o ./output
#
# # %%bash를 치면 그 아랫줄은 다 bash로 실행된다.
# # %system ls를 치면 한줄씩 실행된다.
# # subprocess.run을 사용할 수도 있다.
# Out:
# /data/kjc1/projects/#999.GeoMxmeta/pooled/
# [INFO] Found 114 xlsx files
# [INFO] Error reading /data/kjc1/projects/#999.GeoMxmeta/pooled/DKD_20240125.xlsx: invalid literal for int() with base 10: 'NaN'
# [INFO] Warning: SegmentProperties sheet not found in /data/kjc1/projects/#999.GeoMxmeta/pooled/t4p.xlsx
# [INFO] File: #124_mIBD_biologics_95AOI
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 30
# [INFO]   Unique Columns: 2
# [INFO] File: e
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 29
# [INFO]   Unique Columns: 1
# [INFO] File: PC_multi_250219
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 33
# [INFO]   Unique Columns: 5
# [INFO] File: #124_mIBD_bologics_44AOI
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 30
# [INFO]   Unique Columns: 2
# [INFO] File: Kidney TPL_GeoMx_R1
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 40
# [INFO]   Unique Columns: 13
# [INFO] File: #377 Ari_ILC_mo
# [INFO]   Data Type: MOUSE
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 0
# [INFO] Error reading /data/kjc1/projects/#999.GeoMxmeta/pooled/Keloid_LYI_4mm_20240528.xlsx: invalid literal for int() with base 10: 'NaN'
# [INFO] File: #377 ILC_Ari_Revision
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 35
# [INFO]   Unique Columns: 7
# [INFO] Warning: SegmentProperties sheet not found in /data/kjc1/projects/#999.GeoMxmeta/pooled/(empty)BK melanoma.xlsx
# [INFO] Error reading /data/kjc1/projects/#999.GeoMxmeta/pooled/CRC(2).xlsx: invalid literal for int() with base 10: 'NaN'
# [INFO] File: NHS
# [INFO]   Data Type: MOUSE
# [INFO]   Total Columns: 29
# [INFO]   Unique Columns: 1
# [INFO] Error reading /data/kjc1/projects/#999.GeoMxmeta/pooled/(not aligned)20221207 bk,yk melanoma.xlsx: invalid literal for int() with base 10: 'NaN'
# [INFO] File: IgAN_KMJ_BYJ_final
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 34
# [INFO]   Unique Columns: 7
# [INFO] File: 22.12.08 GeoMx Analysis(2)
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 33
# [INFO]   Unique Columns: 6
# [INFO] File: Kidney TPL_GeoMx_R2
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 43
# [INFO]   Unique Columns: 16
# [INFO] File: 23.01.06(2) HCC
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 39
# [INFO]   Unique Columns: 12
# [INFO] Error reading /data/kjc1/projects/#999.GeoMxmeta/pooled/Final Thymus normal.xlsx: invalid literal for int() with base 10: 'NaN'
# [INFO] File: 23.01.06_HY GeoMx analysis
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 54
# [INFO]   Unique Columns: 27
# [INFO] File: MN_A1.2.3.4_B1.2
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 1
# [INFO] File: 23.06.27 HCC2 vs HCC.x
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 1
# [INFO] File: Koh_Breast cancer
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 43
# [INFO]   Unique Columns: 16
# [INFO] File: 24.06.04 HCC final_GW2
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 29
# [INFO]   Unique Columns: 1
# [INFO] File: KSJ2
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 30
# [INFO]   Unique Columns: 3
# [INFO] File: TA3815
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 1
# [INFO] File: 307 Breast cancer
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 42
# [INFO]   Unique Columns: 14
# [INFO] Warning: SegmentProperties sheet not found in /data/kjc1/projects/#999.GeoMxmeta/pooled/0408-2.xlsx
# [INFO] File: KT2_NEW_20230419
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 35
# [INFO]   Unique Columns: 8
# [INFO] File: 220905_AA Analysis_SHY
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 34
# [INFO]   Unique Columns: 7
# [INFO] File: KSJ
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 64
# [INFO]   Unique Columns: 37
# [INFO] Error reading /data/kjc1/projects/#999.GeoMxmeta/pooled/TA3814.xlsx: invalid literal for int() with base 10: 'NaN'
# [INFO] File: 221226_AA GeoMx_SHY
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 31
# [INFO]   Unique Columns: 4
# [INFO] File: GeoMx_Thuy,HY
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 45
# [INFO]   Unique Columns: 18
# [INFO] File: TA3854
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 30
# [INFO]   Unique Columns: 2
# [INFO] File: 240708_TMA_Halo_nevus_FINAL
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 36
# [INFO]   Unique Columns: 8
# [INFO] Error reading /data/kjc1/projects/#999.GeoMxmeta/pooled/IFTA_250121_NEW_except1patient.xlsx: invalid literal for int() with base 10: 'NaN'
# [INFO] Error reading /data/kjc1/projects/#999.GeoMxmeta/pooled/250114_TCR add on_final.xlsx: invalid literal for int() with base 10: 'NaN'
# [INFO] Warning: SegmentProperties sheet not found in /data/kjc1/projects/#999.GeoMxmeta/pooled/20210315 analysis.xlsx
# [INFO] File: Lupus Nephritis2_202302224
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 1
# [INFO] File: 20220729 Th2 Psoriasis
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 44
# [INFO]   Unique Columns: 17
# [INFO] Error reading /data/kjc1/projects/#999.GeoMxmeta/pooled/IgAN_KMJ_BYJ_20221004.xlsx: invalid literal for int() with base 10: 'NaN'
# [INFO] File: 20220807 JSY HS analysis
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 73
# [INFO]   Unique Columns: 46
# [INFO] Error reading /data/kjc1/projects/#999.GeoMxmeta/pooled/IFTA_20241028.xlsx: invalid literal for int() with base 10: 'NaN'
# [INFO] File: TA3855
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 30
# [INFO]   Unique Columns: 2
# [INFO] File: 20221207 melanoma_bk,yk final
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 40
# [INFO]   Unique Columns: 13
# [INFO] File: JHK_Sebaceous carinoma
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 77
# [INFO]   Unique Columns: 50
# [INFO] File: 20221209 melanoma_macrophage
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 34
# [INFO]   Unique Columns: 7
# [INFO] File: KMJ_Crescent
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 1
# [INFO] File: tnbc_ln
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 55
# [INFO]   Unique Columns: 28
# [INFO] File: 20221228_psoriasis_jsp, bk
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 41
# [INFO]   Unique Columns: 14
# [INFO] Error reading /data/kjc1/projects/#999.GeoMxmeta/pooled/Lupus Nephritis.xlsx: invalid literal for int() with base 10: 'NaN'
# [INFO] File: 20230103 macrophage
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 42
# [INFO]   Unique Columns: 15
# [INFO] File: JSY WTA
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 30
# [INFO]   Unique Columns: 3
# [INFO] File: placenta_KHW
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 36
# [INFO]   Unique Columns: 8
# [INFO] File: 20230512 Brain preliminary 2
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 33
# [INFO]   Unique Columns: 6
# [INFO] Error reading /data/kjc1/projects/#999.GeoMxmeta/pooled/CRC.xlsx: invalid literal for int() with base 10: 'NaN'
# [INFO] File: MuOPKidney
# [INFO]   Data Type: MOUSE
# [INFO]   Total Columns: 33
# [INFO]   Unique Columns: 5
# [INFO] File: 20230515 brain original rna probe
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 1
# [INFO] File: Pancreatic Cancer 2
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 74
# [INFO]   Unique Columns: 46
# [INFO] File: 20230609_GI_2
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 1
# [INFO] File: Marmoset_EAE_ODS
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 43
# [INFO]   Unique Columns: 15
# [INFO] Error reading /data/kjc1/projects/#999.GeoMxmeta/pooled/20230615_LE_Rosa_1st.xlsx: invalid literal for int() with base 10: 'NaN'
# [INFO] Error reading /data/kjc1/projects/#999.GeoMxmeta/pooled/MN_D1.E3.X1.C4.C3.C2.D4.xlsx: invalid literal for int() with base 10: 'NaN'
# [INFO] File: 20230703_GI_control
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 1
# [INFO] Error reading /data/kjc1/projects/#999.GeoMxmeta/pooled/MN_D1.E3.X1.C4.C3.C2.D4_.xlsx: invalid literal for int() with base 10: 'NaN'
# [INFO] File: 20240214_Brain_PD
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 0
# [INFO] File: MN_D1.E3.X1.C4.C3.C2.D4__
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 1
# [INFO] File: 20240723 PV_ChoiSeoyoung_GeoMx
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 0
# [INFO] File: Breast_Cancer_KHW
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 30
# [INFO]   Unique Columns: 2
# [INFO] File: Dermatomyositis
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 37
# [INFO]   Unique Columns: 9
# [INFO] File: Placenta_GeoMx
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 49
# [INFO]   Unique Columns: 21
# [INFO] File: BC_stage_240607
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 167
# [INFO]   Unique Columns: 139
# [INFO] Warning: SegmentProperties sheet not found in /data/kjc1/projects/#999.GeoMxmeta/pooled/SMC0408.xlsx
# [INFO] File: 20240910 Steatosis WTA_BYJ
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 37
# [INFO]   Unique Columns: 9
# [INFO] File: MN_X3.B4.C1.X2
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 1
# [INFO] File: bk melanoma
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 88
# [INFO]   Unique Columns: 61
# [INFO] File: Keloid GeoMx
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 42
# [INFO]   Unique Columns: 14
# [INFO] File: yu
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 32
# [INFO]   Unique Columns: 5
# [INFO] File: BK_colon cancer
# [INFO]   Data Type: CTA
# [INFO]   Total Columns: 29
# [INFO]   Unique Columns: 1
# [INFO] File: MT analysis_20220920
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 30
# [INFO]   Unique Columns: 3
# [INFO] File: Bladder_Cancer_Final
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 69
# [INFO]   Unique Columns: 42
# [INFO] File: Bladder_Cancer_20230913
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 45
# [INFO]   Unique Columns: 18
# [INFO] File: BYC_Thymus_B cell_2021
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 34
# [INFO]   Unique Columns: 6
# [INFO] File: Keloid_LYI_2mm_20240528
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 37
# [INFO]   Unique Columns: 9
# [INFO] File: BSB_Dermatomyositis
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 37
# [INFO]   Unique Columns: 9
# [INFO] File: NC_20231011
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 1
# [INFO] File: bullous real data
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 45
# [INFO]   Unique Columns: 18
# [INFO] File: EoD_analysis_yjbaik
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 48
# [INFO]   Unique Columns: 21
# [INFO] File: HCC_7_10_Final
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 29
# [INFO]   Unique Columns: 1
# [INFO] Error reading /data/kjc1/projects/#999.GeoMxmeta/pooled/H Chung_Thymus #1_240921.xlsx: invalid literal for int() with base 10: 'NaN'
# [INFO] Error reading /data/kjc1/projects/#999.GeoMxmeta/pooled/HCC_VETC_HSH.xlsx: invalid literal for int() with base 10: 'NaN'
# [INFO] File: IgAN_TPL_20240329
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 0
# [INFO] Error reading /data/kjc1/projects/#999.GeoMxmeta/pooled/HCC_NTvsTC_48_KDJ_real.xlsx: invalid literal for int() with base 10: 'NaN'
# [INFO] Error reading /data/kjc1/projects/#999.GeoMxmeta/pooled/HCC_NT_vs_TC_48_KMJ.xlsx: invalid literal for int() with base 10: 'NaN'
# [INFO] File: HS_LYI_20240411
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 30
# [INFO]   Unique Columns: 2
# [INFO] File: mouse_nasal_polyp...
# [INFO]   Data Type: MOUSE
# [INFO]   Total Columns: 29
# [INFO]   Unique Columns: 1
# [INFO] File: HCC_TMA_KMS
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 30
# [INFO]   Unique Columns: 2
# [INFO] File: HS_LYI_2023922
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 48
# [INFO]   Unique Columns: 21
# [INFO] File: RCC_56+28AOI
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 35
# [INFO]   Unique Columns: 7
# [INFO] File: Pancreatic Cancer_HSH_231218
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 39
# [INFO]   Unique Columns: 11
# [INFO] File: Preliminary MSA Brain 2023.03.22
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 1787
# [INFO]   Unique Columns: 1760
# [INFO] File: Preliminary230404_GI
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 79
# [INFO]   Unique Columns: 52
# [INFO] File: SCC GeoMx
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 39
# [INFO]   Unique Columns: 11
# [INFO] Error reading /data/kjc1/projects/#999.GeoMxmeta/pooled/SJ_HY geomx Thymus.xlsx: invalid literal for int() with base 10: 'NaN'
# [INFO] File: SDR_Hu_HT
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 30
# [INFO]   Unique Columns: 2
# [INFO] File: steatosis cta
# [INFO]   Data Type: CTA
# [INFO]   Total Columns: 31
# [INFO]   Unique Columns: 3
# [INFO] Error reading /data/kjc1/projects/#999.GeoMxmeta/pooled/syringoma re.xlsx: invalid literal for int() with base 10: 'NaN'
# [INFO] Error reading /data/kjc1/projects/#999.GeoMxmeta/pooled/thymus normal.xlsx: invalid literal for int() with base 10: 'NaN'
# [INFO] Error reading /data/kjc1/projects/#999.GeoMxmeta/pooled/thymus240401.xlsx: invalid literal for int() with base 10: 'NaN'
# [INFO] File: Total(Ubiased clustering_DRESS123)
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 52
# [INFO]   Unique Columns: 24
# [INFO] File: TOF_geomx_analysis
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 31
# [INFO]   Unique Columns: 3
# [INFO] File: Wound_GeoMx
# [INFO]   Data Type: MOUSE
# [INFO]   Total Columns: 110
# [INFO]   Unique Columns: 82
# [INFO] File: Wound_KHW
# [INFO]   Data Type: MOUSE
# [INFO]   Total Columns: 32
# [INFO]   Unique Columns: 4
# [INFO] Saved unique columns analysis to output/unique_columns_analysis.csv
#
# === Unique Columns Summary ===
# data_type  column_name
# CTA        injured                                              1
#            non-injured                                          1
#            recovered                                            1
#            w/o tumor                                            1
# MOUSE      D0_margin                                            1
#            D0_margin1                                           1
#            D0_margin2                                           1
#            D0_margin3                                           1
#            D1_distant                                           1
#            D1_distant1                                          1
#            D1_distant2                                          1
#            D1_distant3                                          1
#            D1_margin                                            1
#            D1_margin1                                           1
#            D1_margin2                                           1
#            D1_margin3                                           1
#            D3_distant                                           1
#            D3_distant1                                          1
#            D3_distant2                                          1
#            D3_distant3                                          1
#            D3_margin                                            1
#            D3_margin1                                           1
#            D3_margin2                                           1
#            D3_margin3                                           1
#            D7_center                                            1
#            D7_center1                                           1
#            D7_center2                                           1
#            D7_center3                                           1
#            D7_distant                                           1
#            D7_distant(follicle_include)                         1
#            D7_distant1(follicle_include)                        1
#            D7_distant2                                          1
#            D7_distant3                                          1
#            D7_hypo                                              1
#            D7_hypo1                                             1
#            D7_hypo2                                             1
#            D7_hypo3                                             1
#            D7_margin                                            1
#            D7_margin1                                           1
#            D7_margin2                                           1
#            D7_margin3                                           1
#            Epithelial cells                                     1
#            Iba+                                                 2
#            Iba+_D0_margin                                       1
#            Iba+_D1_distant                                      1
#            Iba+_D1_margin                                       1
#            Iba+_D3_distant                                      1
#            Iba+_D3_margin                                       1
#            Iba+_D7_center                                       1
#            Iba+_D7_distant                                      1
#            Iba+_D7_distant(follicle_include)                    1
#            Iba+_D7_hypo                                         1
#            Iba+_D7_margin                                       1
#            Iba_D0                                               1
#            Iba_D1                                               1
#            Iba_D3                                               1
#            Iba_D7                                               1
#            Macrophage                                           1
#            PanCK-Iba-                                           2
#            PanCK-Iba-_D0_margin                                 1
#            PanCK-Iba-_D1_distant                                1
#            PanCK-Iba-_D1_margin                                 1
#            PanCK-Iba-_D3_distant                                1
#            PanCK-Iba-_D3_margin                                 1
#            PanCK-Iba-_D7_center                                 1
#            PanCK-Iba-_D7_distant                                1
#            PanCK-Iba-_D7_distant(follicle_include)              1
#            PanCK-Iba-_D7_hypo                                   1
#            PanCK-Iba-_D7_margin                                 1
#            Panck+                                               2
#            Panck+_D0_margin                                     1
#            Panck+_D1_distant                                    1
#            Panck+_D1_margin                                     1
#            Panck+_D3_distant                                    1
#            Panck+_D3_margin                                     1
#            Panck+_D7_center                                     1
#            Panck+_D7_distant                                    1
#            Panck+_D7_distant(follicle_include)                  1
#            Panck+_D7_margin                                     1
#            ROIComments                                          3
#            Segment 1                                            3
#            Segment 2                                            1
#            ck_D0                                                1
#            ck_D1                                                1
#            ck_D3                                                1
#            ck_D7                                                1
#            neg_D0                                               1
#            neg_D1                                               1
#            neg_D3                                               1
#            neg_D7                                               1
# WTA        -                                                    1
#            1-1 Der                                              1
#            1-1 Epi                                              1
#            1-21 Der                                             1
#            1-21 Epi                                             1
#            1-22 Der                                             1
#            1-22 Epi                                             1
#            1-3 Der                                              1
#            1-3 Epi                                              1
#            131_early_para                                       1
#            131_early_stea                                       1
#            131_late                                             1
#            2-1 Der                                              1
#            2-1 Epi                                              1
#            2-2 Der                                              1
#            2-2 Epi                                              1
#            2-3 Der                                              1
#            2-3 Epi                                              1
#            3-1 Der                                              1
#            3-1 Epi                                              1
#            3-2 Der                                              1
#            3-2 Epi                                              1
#            3-3 Der                                              1
#            3-3 Epi                                              1
#            87_early_para                                        1
#            87_early_stea                                        1
#            87_late                                              1
#            A                                                    1
#            AA                                                   2
#            AA #1                                                1
#            AA #2                                                1
#            AA #3                                                1
#            AA #4                                                1
#            AA_isthmus                                           1
#            AC Cystic wall                                       1
#            AC Epithelial cell                                   1
#            AC Immune cell                                       1
#            AC Inflammation                                      1
#            AC Interfollicular epidermis                         1
#            AC Normal hair follicle                              1
#            AD_epithelial cell                                   1
#            AD_immune cell                                       1
#            AD_infiltrating lymphocyte                           1
#            AR_0                                                 1
#            AR_1                                                 1
#            AR_10__                                              1
#            AR_na                                                1
#            A_ post_PanCK(-)                                     1
#            A_post                                               1
#            A_post_PanCK(+)                                      1
#            A_pre                                                1
#            A_pre_PanCK(+)                                       1
#            A_pre_PanCK(-)                                       1
#            Adventitial                                          1
#            B                                                    2
#            BO                                                   1
#            BP                                                   1
#            BP Blistered Epidermis                               1
#            BP Infiltrated                                       1
#            BP Infiltrated_1                                     1
#            BP Infiltrated_2                                     1
#            BP Infiltrated_3                                     1
#            BP Infiltrated_4                                     1
#            BP Intact Epidermis                                  1
#            BRCA1_epi_C                                          1
#            BRCA1_epi_LN                                         1
#            BRCA1_epi_N                                          1
#            BRCA1_stroma_C                                       1
#            BRCA1_stroma_LN                                      1
#            BRCA1_stroma_N                                       1
#            BRCA2_epi_C                                          1
#            BRCA2_epi_LN                                         1
#            BRCA2_epi_N                                          1
#            BRCA2_epi_S                                          1
#            BRCA2_stroma_C                                       1
#            BRCA2_stroma_LN                                      1
#            BRCA2_stroma_N                                       1
#            BRCA2_stroma_S                                       1
#            B_post                                               1
#            B_post_PanCK(+)                                      1
#            B_post_PanCK(-)                                      1
#            B_pre                                                1
#            B_pre_PanCK(+)                                       1
#            B_pre_PanCK(-)                                       1
#            Basal                                                1
#            Basal_0                                              1
#            Basal_panCK-                                         1
#            Breast Tumor                                         1
#            C Nevus_Epi                                          1
#            C Nevus_Ne                                           1
#            C1                                                   2
#            C10                                                  2
#            C11                                                  2
#            C12                                                  2
#            C2                                                   2
#            C3                                                   2
#            C4                                                   2
#            C5                                                   2
#            C6                                                   2
#            C7                                                   2
#            C8                                                   2
#            C9                                                   2
#            CA                                                   1
#            CAF                                                  2
#            CD4                                                  2
#            CD45                                                 3
#            CD68                                                 2
#            CHI                                                  1
#            CHI+CA                                               1
#            CHI+MPFD                                             1
#            CHICAMPFD                                            1
#            CHI_CA                                               1
#            CHI_CA_MPFD                                          1
#            CHI_MPFD                                             1
#            CIS                                                  1
#            CIS_1                                                1
#            CIS_2                                                1
#            CIS_4                                                1
#            CIS_O                                                1
#            CIS_panCK+                                           1
#            CIS_panCK-                                           1
#            CK+                                                  1
#            CK-                                                  1
#            CO                                                   1
#            CP_TC                                                1
#            CP_TME                                               1
#            CP_Tumor                                             1
#            CP_peri T                                            1
#            CT_TC                                                1
#            CT_TME                                               1
#            CT_Tumor                                             1
#            CT_peri T                                            1
#            C_Microglia+                                         1
#            C_Microglia-                                         1
#            C_Tcell+                                             1
#            Center                                               1
#            Center_M                                             1
#            Center_T                                             1
#            Class                                                1
#            Cold_CAF                                             1
#            Cold_LVI                                             1
#            Cont Epi                                             1
#            Cont Imm                                             1
#            Control                                              6
#            Control endothelium                                  1
#            Control plexus                                       1
#            Control tumor                                        1
#            Control urothelium                                   2
#            Control vessel                                       1
#            Control_1                                            1
#            Control_2                                            1
#            Control_3                                            1
#            Control_Middle_Tension                               1
#            Control_panCK+                                       1
#            Control_panCK-                                       1
#            Control_tumor (PanCK +)                              1
#            Control_tumor (PanCK -)                              1
#            Control_vessel                                       1
#            D1                                                   1
#            D10                                                  1
#            D11                                                  1
#            D12                                                  1
#            D2                                                   1
#            D3                                                   1
#            D4                                                   1
#            D5                                                   1
#            D6                                                   1
#            D7                                                   1
#            D8                                                   1
#            D9                                                   1
#            DAPI                                                 1
#            DD                                                   1
#            DDD                                                  1
#            Dermis                                               1
#            Destructive VI                                       1
#            Destructive VI (PanCK +)                             1
#            Destructive VI (PanCK +)_real                        1
#            Destructive VI (PanCK +)_real_up15                   1
#            Destructive VI (PanCK -)                             1
#            Destructive VI (PanCK -)_real                        1
#            Destructive VI (PanCK -)_real_up15                   1
#            Disease_status                                       1
#            Dorsal                                               1
#            Down                                                 1
#            ER_0                                                 1
#            ER_1                                                 1
#            ER_10__                                              1
#            ER_na                                                1
#            Epidermal Cyst Epithelial Cells                      1
#            Epidermal Cyst Immune Cells                          1
#            Epidermis                                            1
#            Exocu_1                                              1
#            Exocu_2                                              1
#            Exocu_na                                             1
#            Extraocular                                          1
#            FB                                                   1
#            Fi                                                   1
#            Fibroblast                                           1
#            Fibrosis                                             3
#            Fibrotic tract                                       1
#            GIPR                                                 1
#            GLP1R, LEPR                                          1
#            GR                                                   1
#            GR_0                                                 1
#            GR_1                                                 1
#            GR_na                                                1
#            GeoMx_Annotation                                     1
#            GeoMx_Annotation_1                                   1
#            Group                                                1
#            Group1                                               1
#            Group2                                               1
#            H Nevus_Epi                                          1
#            H Nevus_Ne                                           1
#            HCC-x1                                               1
#            HCC-x2                                               1
#            HCC-x3                                               1
#            HCC-x4                                               1
#            HCC1                                                 1
#            HCC2                                                 1
#            HCC3                                                 1
#            HCC4                                                 1
#            HCC5                                                 1
#            HCC6                                                 1
#            HCC7                                                 1
#            HCC8                                                 1
#            HS Apocrine gland                                    1
#            HS Cystic wall                                       1
#            HS Epithelial Cells                                  1
#            HS Epithelial cel                                    1
#            HS Epithelial cell                                   1
#            HS Immune Cells                                      1
#            HS Immune cell                                       1
#            HS Inflammation                                      1
#            HS Interfollicular epidermis                         1
#            HS Normal hair follicle                              1
#            HS Peri-Lesional Epithelial Cells                    1
#            HS dermal tunnel epithelium                          1
#            HS epidermis epithelium                              1
#            IL-17 deleter; RRDD fibrosis                         1
#            Immune                                               3
#            Immune_exclusive                                     1
#            Immune_exclusive_CK-                                 1
#            Immune_prone                                         1
#            Immune_prone_CK-                                     1
#            Islet                                                1
#            Jin HS Epithelial Cells                              1
#            Jin HS Immune Cells                                  1
#            K                                                    1
#            KC                                                   1
#            Keloid                                               1
#            Keloid_High_Tension                                  1
#            Keloid_Low_Tension                                   1
#            Keloid_Middle_Tension                                1
#            Km                                                   1
#            LN__metz                                             1
#            LNmet_                                               1
#            LNmet_0                                              1
#            LNmet_1                                              1
#            LNmet_na                                             1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA         44
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1       19
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_10       3
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_100      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_101      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_102      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_103      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_104      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_105      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_106      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_107      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_108      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_109      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_11       3
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_110      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_111      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_112      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_113      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_114      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_115      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_116      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_117      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_118      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_119      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_12       2
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_120      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_121      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_122      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_123      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_124      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_125      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_126      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_127      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_128      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_129      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_13       2
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_130      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_131      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_132      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_133      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_134      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_135      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_136      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_137      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_138      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_139      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_14       2
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_140      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_141      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_142      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_143      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_144      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_145      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_146      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_147      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_148      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_149      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_15       2
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_150      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_151      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_152      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_153      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_154      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_155      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_156      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_157      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_158      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_159      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_16       2
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_160      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_161      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_162      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_163      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_164      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_165      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_166      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_167      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_168      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_169      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_17       2
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_170      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_171      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_172      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_173      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_174      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_175      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_176      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_177      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_178      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_179      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_18       1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_180      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_181      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_182      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_183      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_184      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_185      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_186      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_187      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_188      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_189      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_19       1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_190      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_191      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_192      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_193      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_194      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_195      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_196      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_197      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_198      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_199      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1_1      6
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1_10     1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1_11     1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1_12     1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1_13     1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1_14     1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1_15     1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1_16     1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1_17     1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1_18     1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1_19     1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1_2      4
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1_20     1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1_21     1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1_22     1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1_23     1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1_24     1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1_25     1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1_26     1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1_27     1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1_28     1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1_29     1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1_3      2
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1_30     1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1_4      2
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1_5      2
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1_6      2
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1_7      2
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1_8      2
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1_9      2
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_2       13
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_20       1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_200      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_201      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_202      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_203      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_204      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_205      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_206      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_207      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_208      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_209      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_21       1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_210      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_211      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_212      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_213      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_214      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_215      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_216      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_217      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_218      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_219      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_22       1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_220      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_221      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_222      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_223      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_224      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_225      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_226      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_227      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_228      1
#            LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_229      1
# ...
#            Scan_ID_69                                           1
#            Scan_ID_7                                            6
#            Scan_ID_70                                           1
#            Scan_ID_71                                           1
#            Scan_ID_72                                           1
#            Scan_ID_73                                           1
#            Scan_ID_74                                           1
#            Scan_ID_75                                           1
#            Scan_ID_76                                           1
#            Scan_ID_77                                           1
#            Scan_ID_78                                           1
#            Scan_ID_79                                           1
#            Scan_ID_8                                            5
#            Scan_ID_80                                           1
#            Scan_ID_81                                           1
#            Scan_ID_82                                           1
#            Scan_ID_83                                           1
#            Scan_ID_84                                           1
#            Scan_ID_85                                           1
#            Scan_ID_86                                           1
#            Scan_ID_87                                           1
#            Scan_ID_88                                           1
#            Scan_ID_89                                           1
#            Scan_ID_9                                            5
#            Scan_ID_90                                           1
#            Scan_ID_91                                           1
#            Scan_ID_92                                           1
#            Scan_ID_93                                           1
#            Scan_ID_94                                           1
#            Scan_ID_95                                           1
#            Scan_ID_96                                           1
#            Scan_ID_97                                           1
#            Scan_ID_98                                           1
#            Scan_ID_99                                           1
#            Segment 1                                           13
#            Segment 2                                           10
#            Segment Tags                                         4
#            Segment Tags_1                                       1
#            Sev Epi                                              1
#            Sev Imm                                              1
#            Shin HS Epithelial Cells                             1
#            Shin HS Immune Cells                                 1
#            Shin HS Peri-Lesional Epithelial Cells               1
#            Single cell invasion                                 1
#            Steatosis                                            3
#            T                                                    1
#            T1                                                   4
#            T1 + T2                                              1
#            T1.5                                                 1
#            T1.5(2)                                              1
#            T1_1                                                 1
#            T1_2                                                 1
#            T1_3                                                 1
#            T1_4                                                 1
#            T1_Cold_Tumor cell                                   1
#            T1_Hot_Tumor cell                                    1
#            T1_O                                                 1
#            T1_panCK+                                            1
#            T1_panCK-                                            1
#            T2                                                   4
#            T2+3+4                                               1
#            T2_1                                                 1
#            T2_2                                                 1
#            T2_3                                                 1
#            T2_4                                                 1
#            T2_Cold_Tumor cell                                   1
#            T2_Hot_Tumor cell                                    1
#            T2_O                                                 1
#            T2_panCK+                                            1
#            T2_panCK-                                            1
#            T3                                                   4
#            T3_1                                                 1
#            T3_2                                                 1
#            T3_3                                                 1
#            T3_4                                                 1
#            T3_Cold_CAF                                          1
#            T3_Cold_CAF_Single cell invasion                     1
#            T3_Cold_LVI                                          1
#            T3_Cold_Necrosis                                     1
#            T3_Cold_Single cell invasion                         1
#            T3_Cold_Tumor cell                                   1
#            T3_panCK+                                            1
#            T3_panCK-                                            1
#            T4                                                   3
#            T4_Hot_CAF                                           1
#            T4_Hot_LVI                                           1
#            T4_Hot_Single cell invasion                          1
#            T4_Hot_Tumor cell                                    1
#            TA                                                   1
#            TCMR                                                 1
#            TCMR_Glom                                            1
#            TCMR_interstitium                                    1
#            TI                                                   1
#            TI1                                                  1
#            TI2                                                  1
#            TI3                                                  1
#            TIF                                                  1
#            TIF1                                                 1
#            TIF2                                                 1
#            TILhigh                                              1
#            TILlow                                               1
#            TIS                                                  1
#            TIS1                                                 1
#            TIS2                                                 1
#            TIS3                                                 1
#            TMA_No                                               1
#            T_1                                                  1
#            T_2                                                  1
#            T_Microglia+                                         1
#            T_Microglia-                                         1
#            T_Tcell+                                             1
#            T_na                                                 1
#            T_stage                                              1
#            Tcell+                                               1
#            Th2 Psoriasis_epithelial cell                        1
#            Th2 Psoriasis_epithelial cell_HY                     1
#            Th2 Psoriasis_epithelial cell_SP                     1
#            Th2 Psoriasis_infiltrating lymphocyte                1
#            Th2 Psoriasis_infiltrating lymphocyte_HY             1
#            Th2 Psoriasis_infiltrating lymphocyte_SP             1
#            Thymus B cell 001                                    1
#            Thymus_cortex_B cells                                1
#            Thymus_medulla_B cells                               1
#            Tissue                                               1
#            Tissue_1                                             1
#            Tissue_2                                             1
#            Troponin                                             1
#            Tumor                                                3
#            Tumor Immune(1)                                      1
#            Tumor Immune(2)                                      1
#            Tumor cell                                           2
#            Tumor only                                           4
#            Up                                                   1
#            V                                                    1
#            VI                                                   1
#            VI (PanCK +)                                         1
#            VI (PanCK -)                                         1
#            VV                                                   1
#            Ventral                                              1
#            Zerotime_glom                                        2
#            Zerotime_interstitium                                2
#            [0] CD4 T cell                                       1
#            [0] Keratinocyte                                     1
#            [0] Macrophage                                       1
#            [4] CD4 T cell                                       1
#            [4] Keratinocyte                                     1
#            [4] Macrophage                                       1
#            [Pre] Keratinocyte                                   1
#            [post] CD4+ T cell                                   1
#            [post] Keratinocyte                                  1
#            [post] Macrophage                                    1
#            [pre] CD4+ T cell                                    1
#            [pre] Macrophage                                     1
#            acini                                                1
#            ann_pathcr                                           1
#            biology                                              1
#            control                                              1
#            control_Glom                                         1
#            control_interstitium                                 1
#            cortical b cells                                     1
#            ctrl                                                 1
#            decidua                                              2
#            deciduacell                                          1
#            disease                                              1
#            early_para                                           1
#            early_stea                                           1
#            immu                                                 1
#            implantation site                                    1
#            late                                                 1
#            lobule_1                                             1
#            lobule_2                                             1
#            medullary b cells                                    1
#            mixed type 1_epithelial cell                         1
#            mixed type 1_immune cell                             1
#            mixed type 2_epithelial cell                         1
#            mixed type 2_immune cell                             1
#            moderate Der                                         1
#            moderate epi                                         1
#            myocardiocyte                                        1
#            p53 non-specific                                     1
#            p53+                                                 1
#            p53-                                                 1
#            pembroli Der                                         1
#            pembroli epi                                         1
#            post                                                 1
#            post-borderline ATMR                                 1
#            post-borderline ATMR_glom                            1
#            post-grade II ATMR                                   1
#            post-grade II ATMR_glom                              1
#            pre                                                  1
#            pre-borderline ATMR                                  1
#            pre-borderline ATMR_glom                             1
#            pre-grade II ATMR                                    1
#            pre-grade II ATMR_glom                               1
#            shIL_37                                              1
#            shcontrol                                            1
#            trophoblast                                          2
#            villi                                                1
# Traceback (most recent call last):
#   File "/data/kjc1/mylit/ipynb/geomx_processor.py", line 491, in <module>
#     main()
#   File "/data/kjc1/mylit/ipynb/geomx_processor.py", line 476, in main
#     processor.generate_mapping_template(args.output)
#   File "/data/kjc1/mylit/ipynb/geomx_processor.py", line 228, in generate_mapping_template
#     if pd.notna(values_str):
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 get_ipython().run_cell_magic('bash', '', '# 2. 고유 column 분석\nxlsx_folder="/data/kjc1/projects/#999.GeoMxmeta/pooled/"\necho $xlsx_folder\npython geomx_processor.py analyze $xlsx_folder -o ./output\n\n# %%bash를 치면 그 아랫줄은 다 bash로 실행된다.\n# %system ls를 치면 한줄씩 실행된다.\n# subprocess.run을 사용할 수도 있다.\n')
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2478, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2476 with self.builtin_trap:
#    2477     args = (magic_arg_s, cell)
# -> 2478     result = fn(*args, **kwargs)
#    2480 # The code below prevents the output from being displayed
#    2481 # when using magics with decodator @output_can_be_silenced
#    2482 # when the last Python token in the expression is a ';'.
#    2483 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/magics/script.py:153, in ScriptMagics._make_script_magic.<locals>.named_script_magic(line, cell)
#     151 else:
#     152     line = script
# --> 153 return self.shebang(line, cell)
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/magics/script.py:305, in ScriptMagics.shebang(self, line, cell)
#     300 if args.raise_error and p.returncode != 0:
#     301     # If we get here and p.returncode is still None, we must have
#     302     # killed it but not yet seen its return code. We don't wait for it,
#     303     # in case it's stuck in uninterruptible sleep. -9 = SIGKILL
#     304     rc = p.returncode or -9
# --> 305     raise CalledProcessError(rc, cell)
#
# CalledProcessError: Command 'b'# 2. \xea\xb3\xa0\xec\x9c\xa0 column \xeb\xb6\x84\xec\x84\x9d\nxlsx_folder="/data/kjc1/projects/#999.GeoMxmeta/pooled/"\necho $xlsx_folder\npython geomx_processor.py analyze $xlsx_folder -o ./output\n\n# %%bash\xeb\xa5\xbc \xec\xb9\x98\xeb\xa9\xb4 \xea\xb7\xb8 \xec\x95\x84\xeb\x9e\xab\xec\xa4\x84\xec\x9d\x80 \xeb\x8b\xa4 bash\xeb\xa1\x9c \xec\x8b\xa4\xed\x96\x89\xeb\x90\x9c\xeb\x8b\xa4.\n# %system ls\xeb\xa5\xbc \xec\xb9\x98\xeb\xa9\xb4 \xed\x95\x9c\xec\xa4\x84\xec\x94\xa9 \xec\x8b\xa4\xed\x96\x89\xeb\x90\x9c\xeb\x8b\xa4.\n# subprocess.run\xec\x9d\x84 \xec\x82\xac\xec\x9a\xa9\xed\x95\xa0 \xec\x88\x98\xeb\x8f\x84 \xec\x9e\x88\xeb\x8b\xa4.\n'' returned non-zero exit status 1.

# %%
# 3. 매핑 템플릿 편집 (vim, nano 등)
# !vim ./output/column_mapping_template.csv

# %%
# %%bash
# # 4. Metadata 통합
# xlsx_folder="/data/kjc1/projects/#999.GeoMxmeta/pooled/"
# python geomx_processor.py merge $xlsx_folder ./output/column_mapping_template.csv -o ./output
# Out:
# [INFO] Found 114 xlsx files
# [INFO] Error reading /data/kjc1/projects/#999.GeoMxmeta/pooled/DKD_20240125.xlsx: invalid literal for int() with base 10: 'NaN'
# [INFO] Warning: SegmentProperties sheet not found in /data/kjc1/projects/#999.GeoMxmeta/pooled/t4p.xlsx
# [INFO] File: #124_mIBD_biologics_95AOI
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 30
# [INFO]   Unique Columns: 2
# [INFO] File: e
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 29
# [INFO]   Unique Columns: 1
# [INFO] File: PC_multi_250219
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 33
# [INFO]   Unique Columns: 5
# [INFO] File: #124_mIBD_bologics_44AOI
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 30
# [INFO]   Unique Columns: 2
# [INFO] File: Kidney TPL_GeoMx_R1
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 40
# [INFO]   Unique Columns: 13
# [INFO] File: #377 Ari_ILC_mo
# [INFO]   Data Type: MOUSE
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 0
# [INFO] Error reading /data/kjc1/projects/#999.GeoMxmeta/pooled/Keloid_LYI_4mm_20240528.xlsx: invalid literal for int() with base 10: 'NaN'
# [INFO] File: #377 ILC_Ari_Revision
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 35
# [INFO]   Unique Columns: 7
# [INFO] Warning: SegmentProperties sheet not found in /data/kjc1/projects/#999.GeoMxmeta/pooled/(empty)BK melanoma.xlsx
# [INFO] Error reading /data/kjc1/projects/#999.GeoMxmeta/pooled/CRC(2).xlsx: invalid literal for int() with base 10: 'NaN'
# [INFO] File: NHS
# [INFO]   Data Type: MOUSE
# [INFO]   Total Columns: 29
# [INFO]   Unique Columns: 1
# [INFO] Error reading /data/kjc1/projects/#999.GeoMxmeta/pooled/(not aligned)20221207 bk,yk melanoma.xlsx: invalid literal for int() with base 10: 'NaN'
# [INFO] File: IgAN_KMJ_BYJ_final
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 34
# [INFO]   Unique Columns: 7
# [INFO] File: 22.12.08 GeoMx Analysis(2)
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 33
# [INFO]   Unique Columns: 6
# [INFO] File: Kidney TPL_GeoMx_R2
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 43
# [INFO]   Unique Columns: 16
# [INFO] File: 23.01.06(2) HCC
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 39
# [INFO]   Unique Columns: 12
# [INFO] Error reading /data/kjc1/projects/#999.GeoMxmeta/pooled/Final Thymus normal.xlsx: invalid literal for int() with base 10: 'NaN'
# [INFO] File: 23.01.06_HY GeoMx analysis
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 54
# [INFO]   Unique Columns: 27
# [INFO] File: MN_A1.2.3.4_B1.2
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 1
# [INFO] File: 23.06.27 HCC2 vs HCC.x
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 1
# [INFO] File: Koh_Breast cancer
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 43
# [INFO]   Unique Columns: 16
# [INFO] File: 24.06.04 HCC final_GW2
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 29
# [INFO]   Unique Columns: 1
# [INFO] File: KSJ2
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 30
# [INFO]   Unique Columns: 3
# [INFO] File: TA3815
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 1
# [INFO] File: 307 Breast cancer
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 42
# [INFO]   Unique Columns: 14
# [INFO] Warning: SegmentProperties sheet not found in /data/kjc1/projects/#999.GeoMxmeta/pooled/0408-2.xlsx
# [INFO] File: KT2_NEW_20230419
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 35
# [INFO]   Unique Columns: 8
# [INFO] File: 220905_AA Analysis_SHY
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 34
# [INFO]   Unique Columns: 7
# [INFO] File: KSJ
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 64
# [INFO]   Unique Columns: 37
# [INFO] Error reading /data/kjc1/projects/#999.GeoMxmeta/pooled/TA3814.xlsx: invalid literal for int() with base 10: 'NaN'
# [INFO] File: 221226_AA GeoMx_SHY
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 31
# [INFO]   Unique Columns: 4
# [INFO] File: GeoMx_Thuy,HY
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 45
# [INFO]   Unique Columns: 18
# [INFO] File: TA3854
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 30
# [INFO]   Unique Columns: 2
# [INFO] File: 240708_TMA_Halo_nevus_FINAL
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 36
# [INFO]   Unique Columns: 8
# [INFO] Error reading /data/kjc1/projects/#999.GeoMxmeta/pooled/IFTA_250121_NEW_except1patient.xlsx: invalid literal for int() with base 10: 'NaN'
# [INFO] Error reading /data/kjc1/projects/#999.GeoMxmeta/pooled/250114_TCR add on_final.xlsx: invalid literal for int() with base 10: 'NaN'
# [INFO] Warning: SegmentProperties sheet not found in /data/kjc1/projects/#999.GeoMxmeta/pooled/20210315 analysis.xlsx
# [INFO] File: Lupus Nephritis2_202302224
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 1
# [INFO] File: 20220729 Th2 Psoriasis
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 44
# [INFO]   Unique Columns: 17
# [INFO] Error reading /data/kjc1/projects/#999.GeoMxmeta/pooled/IgAN_KMJ_BYJ_20221004.xlsx: invalid literal for int() with base 10: 'NaN'
# [INFO] File: 20220807 JSY HS analysis
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 73
# [INFO]   Unique Columns: 46
# [INFO] Error reading /data/kjc1/projects/#999.GeoMxmeta/pooled/IFTA_20241028.xlsx: invalid literal for int() with base 10: 'NaN'
# [INFO] File: TA3855
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 30
# [INFO]   Unique Columns: 2
# [INFO] File: 20221207 melanoma_bk,yk final
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 40
# [INFO]   Unique Columns: 13
# [INFO] File: JHK_Sebaceous carinoma
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 77
# [INFO]   Unique Columns: 50
# [INFO] File: 20221209 melanoma_macrophage
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 34
# [INFO]   Unique Columns: 7
# [INFO] File: KMJ_Crescent
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 1
# [INFO] File: tnbc_ln
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 55
# [INFO]   Unique Columns: 28
# [INFO] File: 20221228_psoriasis_jsp, bk
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 41
# [INFO]   Unique Columns: 14
# [INFO] Error reading /data/kjc1/projects/#999.GeoMxmeta/pooled/Lupus Nephritis.xlsx: invalid literal for int() with base 10: 'NaN'
# [INFO] File: 20230103 macrophage
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 42
# [INFO]   Unique Columns: 15
# [INFO] File: JSY WTA
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 30
# [INFO]   Unique Columns: 3
# [INFO] File: placenta_KHW
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 36
# [INFO]   Unique Columns: 8
# [INFO] File: 20230512 Brain preliminary 2
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 33
# [INFO]   Unique Columns: 6
# [INFO] Error reading /data/kjc1/projects/#999.GeoMxmeta/pooled/CRC.xlsx: invalid literal for int() with base 10: 'NaN'
# [INFO] File: MuOPKidney
# [INFO]   Data Type: MOUSE
# [INFO]   Total Columns: 33
# [INFO]   Unique Columns: 5
# [INFO] File: 20230515 brain original rna probe
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 1
# [INFO] File: Pancreatic Cancer 2
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 74
# [INFO]   Unique Columns: 46
# [INFO] File: 20230609_GI_2
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 1
# [INFO] File: Marmoset_EAE_ODS
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 43
# [INFO]   Unique Columns: 15
# [INFO] Error reading /data/kjc1/projects/#999.GeoMxmeta/pooled/20230615_LE_Rosa_1st.xlsx: invalid literal for int() with base 10: 'NaN'
# [INFO] Error reading /data/kjc1/projects/#999.GeoMxmeta/pooled/MN_D1.E3.X1.C4.C3.C2.D4.xlsx: invalid literal for int() with base 10: 'NaN'
# [INFO] File: 20230703_GI_control
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 1
# [INFO] Error reading /data/kjc1/projects/#999.GeoMxmeta/pooled/MN_D1.E3.X1.C4.C3.C2.D4_.xlsx: invalid literal for int() with base 10: 'NaN'
# [INFO] File: 20240214_Brain_PD
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 0
# [INFO] File: MN_D1.E3.X1.C4.C3.C2.D4__
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 1
# [INFO] File: 20240723 PV_ChoiSeoyoung_GeoMx
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 0
# [INFO] File: Breast_Cancer_KHW
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 30
# [INFO]   Unique Columns: 2
# [INFO] File: Dermatomyositis
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 37
# [INFO]   Unique Columns: 9
# [INFO] File: Placenta_GeoMx
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 49
# [INFO]   Unique Columns: 21
# [INFO] File: BC_stage_240607
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 167
# [INFO]   Unique Columns: 139
# [INFO] Warning: SegmentProperties sheet not found in /data/kjc1/projects/#999.GeoMxmeta/pooled/SMC0408.xlsx
# [INFO] File: 20240910 Steatosis WTA_BYJ
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 37
# [INFO]   Unique Columns: 9
# [INFO] File: MN_X3.B4.C1.X2
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 1
# [INFO] File: bk melanoma
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 88
# [INFO]   Unique Columns: 61
# [INFO] File: Keloid GeoMx
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 42
# [INFO]   Unique Columns: 14
# [INFO] File: yu
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 32
# [INFO]   Unique Columns: 5
# [INFO] File: BK_colon cancer
# [INFO]   Data Type: CTA
# [INFO]   Total Columns: 29
# [INFO]   Unique Columns: 1
# [INFO] File: MT analysis_20220920
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 30
# [INFO]   Unique Columns: 3
# [INFO] File: Bladder_Cancer_Final
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 69
# [INFO]   Unique Columns: 42
# [INFO] File: Bladder_Cancer_20230913
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 45
# [INFO]   Unique Columns: 18
# [INFO] File: BYC_Thymus_B cell_2021
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 34
# [INFO]   Unique Columns: 6
# [INFO] File: Keloid_LYI_2mm_20240528
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 37
# [INFO]   Unique Columns: 9
# [INFO] File: BSB_Dermatomyositis
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 37
# [INFO]   Unique Columns: 9
# [INFO] File: NC_20231011
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 1
# [INFO] File: bullous real data
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 45
# [INFO]   Unique Columns: 18
# [INFO] File: EoD_analysis_yjbaik
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 48
# [INFO]   Unique Columns: 21
# [INFO] File: HCC_7_10_Final
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 29
# [INFO]   Unique Columns: 1
# [INFO] Error reading /data/kjc1/projects/#999.GeoMxmeta/pooled/H Chung_Thymus #1_240921.xlsx: invalid literal for int() with base 10: 'NaN'
# [INFO] Error reading /data/kjc1/projects/#999.GeoMxmeta/pooled/HCC_VETC_HSH.xlsx: invalid literal for int() with base 10: 'NaN'
# [INFO] File: IgAN_TPL_20240329
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 0
# [INFO] Error reading /data/kjc1/projects/#999.GeoMxmeta/pooled/HCC_NTvsTC_48_KDJ_real.xlsx: invalid literal for int() with base 10: 'NaN'
# [INFO] Error reading /data/kjc1/projects/#999.GeoMxmeta/pooled/HCC_NT_vs_TC_48_KMJ.xlsx: invalid literal for int() with base 10: 'NaN'
# [INFO] File: HS_LYI_20240411
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 30
# [INFO]   Unique Columns: 2
# [INFO] File: mouse_nasal_polyp...
# [INFO]   Data Type: MOUSE
# [INFO]   Total Columns: 29
# [INFO]   Unique Columns: 1
# [INFO] File: HCC_TMA_KMS
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 30
# [INFO]   Unique Columns: 2
# [INFO] File: HS_LYI_2023922
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 48
# [INFO]   Unique Columns: 21
# [INFO] File: RCC_56+28AOI
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 35
# [INFO]   Unique Columns: 7
# [INFO] File: Pancreatic Cancer_HSH_231218
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 39
# [INFO]   Unique Columns: 11
# [INFO] File: Preliminary MSA Brain 2023.03.22
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 1787
# [INFO]   Unique Columns: 1760
# [INFO] File: Preliminary230404_GI
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 79
# [INFO]   Unique Columns: 52
# [INFO] File: SCC GeoMx
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 39
# [INFO]   Unique Columns: 11
# [INFO] Error reading /data/kjc1/projects/#999.GeoMxmeta/pooled/SJ_HY geomx Thymus.xlsx: invalid literal for int() with base 10: 'NaN'
# [INFO] File: SDR_Hu_HT
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 30
# [INFO]   Unique Columns: 2
# [INFO] File: steatosis cta
# [INFO]   Data Type: CTA
# [INFO]   Total Columns: 31
# [INFO]   Unique Columns: 3
# [INFO] Error reading /data/kjc1/projects/#999.GeoMxmeta/pooled/syringoma re.xlsx: invalid literal for int() with base 10: 'NaN'
# [INFO] Error reading /data/kjc1/projects/#999.GeoMxmeta/pooled/thymus normal.xlsx: invalid literal for int() with base 10: 'NaN'
# [INFO] Error reading /data/kjc1/projects/#999.GeoMxmeta/pooled/thymus240401.xlsx: invalid literal for int() with base 10: 'NaN'
# [INFO] File: Total(Ubiased clustering_DRESS123)
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 52
# [INFO]   Unique Columns: 24
# [INFO] File: TOF_geomx_analysis
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 31
# [INFO]   Unique Columns: 3
# [INFO] File: Wound_GeoMx
# [INFO]   Data Type: MOUSE
# [INFO]   Total Columns: 110
# [INFO]   Unique Columns: 82
# [INFO] File: Wound_KHW
# [INFO]   Data Type: MOUSE
# [INFO]   Total Columns: 32
# [INFO]   Unique Columns: 4
# Traceback (most recent call last):
#   File "/data/kjc1/mylit/ipynb/geomx_processor.py", line 491, in <module>
#     main()
#   File "/data/kjc1/mylit/ipynb/geomx_processor.py", line 481, in main
#     processor.apply_mappings_and_merge(args.mapping_file, args.output)
#   File "/data/kjc1/mylit/ipynb/geomx_processor.py", line 301, in apply_mappings_and_merge
#     merged_metadata = pd.concat(merged_dfs, ignore_index=True, sort=False)
#   File "/home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/pandas/core/reshape/concat.py", line 395, in concat
#     return op.get_result()
#   File "/home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/pandas/core/reshape/concat.py", line 680, in get_result
#     indexers[ax] = obj_labels.get_indexer(new_labels)
#   File "/home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/pandas/core/indexes/base.py", line 3885, in get_indexer
#     raise InvalidIndexError(self._requires_unique_msg)
# pandas.errors.InvalidIndexError: Reindexing only valid with uniquely valued Index objects
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 get_ipython().run_cell_magic('bash', '', '# 4. Metadata 통합\nxlsx_folder="/data/kjc1/projects/#999.GeoMxmeta/pooled/"\npython geomx_processor.py merge $xlsx_folder ./output/column_mapping_template.csv -o ./output\n')
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2478, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2476 with self.builtin_trap:
#    2477     args = (magic_arg_s, cell)
# -> 2478     result = fn(*args, **kwargs)
#    2480 # The code below prevents the output from being displayed
#    2481 # when using magics with decodator @output_can_be_silenced
#    2482 # when the last Python token in the expression is a ';'.
#    2483 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/magics/script.py:153, in ScriptMagics._make_script_magic.<locals>.named_script_magic(line, cell)
#     151 else:
#     152     line = script
# --> 153 return self.shebang(line, cell)
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/magics/script.py:305, in ScriptMagics.shebang(self, line, cell)
#     300 if args.raise_error and p.returncode != 0:
#     301     # If we get here and p.returncode is still None, we must have
#     302     # killed it but not yet seen its return code. We don't wait for it,
#     303     # in case it's stuck in uninterruptible sleep. -9 = SIGKILL
#     304     rc = p.returncode or -9
# --> 305     raise CalledProcessError(rc, cell)
#
# CalledProcessError: Command 'b'# 4. Metadata \xed\x86\xb5\xed\x95\xa9\nxlsx_folder="/data/kjc1/projects/#999.GeoMxmeta/pooled/"\npython geomx_processor.py merge $xlsx_folder ./output/column_mapping_template.csv -o ./output\n'' returned non-zero exit status 1.

# %%
# 5. 기존 count matrix와 매칭 (선택사항)
# !python geomx_processor.py match your_count_matrix.csv ./output/merged_metadata.csv -o ./final

# %% [markdown]
# ### ver2. 함수 실행

# %%
# %%bash
# # 2. 고유 column 분석
# xlsx_folder="/data/kjc1/projects/#999.GeoMxmeta/pooled/"
# echo $xlsx_folder
# python geomx_processor_v2.py analyze $xlsx_folder -o ./output
# Out:
# /data/kjc1/projects/#999.GeoMxmeta/pooled/
# [INFO] Found 114 xlsx files
# [INFO]
# Processing: DKD_20240125.xlsx
# [WARNING] Warning: Could not read SegmentProperties from /data/kjc1/projects/#999.GeoMxmeta/pooled/DKD_20240125.xlsx
# [INFO]
# Processing: t4p.xlsx
# [WARNING] Warning: Could not read SegmentProperties from /data/kjc1/projects/#999.GeoMxmeta/pooled/t4p.xlsx
# [INFO]
# Processing: #124_mIBD_biologics_95AOI.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/#124_mIBD_biologics_95AOI.xlsx using openpyxl
# [INFO] File: #124_mIBD_biologics_95AOI
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 30
# [INFO]   Unique Columns: 2
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: e.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/e.xlsx using openpyxl
# [INFO] File: e
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 29
# [INFO]   Unique Columns: 1
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: PC_multi_250219.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/PC_multi_250219.xlsx using openpyxl
# [INFO] File: PC_multi_250219
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 33
# [INFO]   Unique Columns: 4
# [INFO]   Ignored Columns: 1
# [INFO]   Ignored: ['ROIComments']
# [INFO]
# Processing: #124_mIBD_bologics_44AOI.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/#124_mIBD_bologics_44AOI.xlsx using openpyxl
# [INFO] File: #124_mIBD_bologics_44AOI
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 30
# [INFO]   Unique Columns: 2
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: Kidney TPL_GeoMx_R1.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/Kidney TPL_GeoMx_R1.xlsx using openpyxl
# [INFO] File: Kidney TPL_GeoMx_R1
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 40
# [INFO]   Unique Columns: 6
# [INFO]   Ignored Columns: 7
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA', 'Scan_ID_1', 'ROI_ID_1', 'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1', 'Scan_ID_2']...
# [INFO]
# Processing: #377 Ari_ILC_mo.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/#377 Ari_ILC_mo.xlsx using openpyxl
# [INFO] File: #377 Ari_ILC_mo
# [INFO]   Data Type: MOUSE
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 0
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: Keloid_LYI_4mm_20240528.xlsx
# [WARNING] Warning: Could not read SegmentProperties from /data/kjc1/projects/#999.GeoMxmeta/pooled/Keloid_LYI_4mm_20240528.xlsx
# [INFO]
# Processing: #377 ILC_Ari_Revision.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/#377 ILC_Ari_Revision.xlsx using openpyxl
# [INFO] File: #377 ILC_Ari_Revision
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 35
# [INFO]   Unique Columns: 7
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: (empty)BK melanoma.xlsx
# [WARNING] Warning: Could not read SegmentProperties from /data/kjc1/projects/#999.GeoMxmeta/pooled/(empty)BK melanoma.xlsx
# [INFO]
# Processing: CRC(2).xlsx
# [WARNING] Warning: Could not read SegmentProperties from /data/kjc1/projects/#999.GeoMxmeta/pooled/CRC(2).xlsx
# [INFO]
# Processing: NHS.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/NHS.xlsx using openpyxl
# [INFO] File: NHS
# [INFO]   Data Type: MOUSE
# [INFO]   Total Columns: 29
# [INFO]   Unique Columns: 0
# [INFO]   Ignored Columns: 1
# [INFO]   Ignored: ['Segment 1']
# [INFO]
# Processing: (not aligned)20221207 bk,yk melanoma.xlsx
# [ERROR] Direct reading failed for /data/kjc1/projects/#999.GeoMxmeta/pooled/(not aligned)20221207 bk,yk melanoma.xlsx: invalid literal for int() with base 10: 'NaN'
# [WARNING] Warning: Could not read SegmentProperties from /data/kjc1/projects/#999.GeoMxmeta/pooled/(not aligned)20221207 bk,yk melanoma.xlsx
# [INFO]
# Processing: IgAN_KMJ_BYJ_final.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/IgAN_KMJ_BYJ_final.xlsx using openpyxl
# [INFO] File: IgAN_KMJ_BYJ_final
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 34
# [INFO]   Unique Columns: 3
# [INFO]   Ignored Columns: 4
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA', 'Scan_ID_1', 'ROI_ID_1', 'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1']
# [INFO]
# Processing: 22.12.08 GeoMx Analysis(2).xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/22.12.08 GeoMx Analysis(2).xlsx using openpyxl
# [INFO] File: 22.12.08 GeoMx Analysis(2)
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 33
# [INFO]   Unique Columns: 5
# [INFO]   Ignored Columns: 1
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA']
# [INFO]
# Processing: Kidney TPL_GeoMx_R2.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/Kidney TPL_GeoMx_R2.xlsx using openpyxl
# [INFO] File: Kidney TPL_GeoMx_R2
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 43
# [INFO]   Unique Columns: 12
# [INFO]   Ignored Columns: 4
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA', 'Scan_ID_1', 'ROI_ID_1', 'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1']
# [INFO]
# Processing: 23.01.06(2) HCC.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/23.01.06(2) HCC.xlsx using openpyxl
# [INFO] File: 23.01.06(2) HCC
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 39
# [INFO]   Unique Columns: 5
# [INFO]   Ignored Columns: 7
# [INFO]   Ignored: ['Scan_ID_1', 'ROI_ID_1', 'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1', 'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA', 'Scan_ID_2']...
# [INFO]
# Processing: Final Thymus normal.xlsx
# [WARNING] Warning: Could not read SegmentProperties from /data/kjc1/projects/#999.GeoMxmeta/pooled/Final Thymus normal.xlsx
# [INFO]
# Processing: 23.01.06_HY GeoMx analysis.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/23.01.06_HY GeoMx analysis.xlsx using openpyxl
# [INFO] File: 23.01.06_HY GeoMx analysis
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 54
# [INFO]   Unique Columns: 20
# [INFO]   Ignored Columns: 7
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA', 'Scan_ID_1', 'ROI_ID_1', 'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1', 'Scan_ID_2']...
# [INFO]
# Processing: MN_A1.2.3.4_B1.2.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/MN_A1.2.3.4_B1.2.xlsx using openpyxl
# [INFO] File: MN_A1.2.3.4_B1.2
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 0
# [INFO]   Ignored Columns: 1
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA']
# [INFO]
# Processing: 23.06.27 HCC2 vs HCC.x.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/23.06.27 HCC2 vs HCC.x.xlsx using openpyxl
# [INFO] File: 23.06.27 HCC2 vs HCC.x
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 0
# [INFO]   Ignored Columns: 1
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA']
# [INFO]
# Processing: Koh_Breast cancer.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/Koh_Breast cancer.xlsx using openpyxl
# [INFO] File: Koh_Breast cancer
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 43
# [INFO]   Unique Columns: 14
# [INFO]   Ignored Columns: 2
# [INFO]   Ignored: ['ROI_ID_1', 'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA']
# [INFO]
# Processing: 24.06.04 HCC final_GW2.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/24.06.04 HCC final_GW2.xlsx using openpyxl
# [INFO] File: 24.06.04 HCC final_GW2
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 29
# [INFO]   Unique Columns: 1
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: KSJ2.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/KSJ2.xlsx using openpyxl
# [INFO] File: KSJ2
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 30
# [INFO]   Unique Columns: 2
# [INFO]   Ignored Columns: 1
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA']
# [INFO]
# Processing: TA3815.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/TA3815.xlsx using openpyxl
# [INFO] File: TA3815
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 0
# [INFO]   Ignored Columns: 1
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA']
# [INFO]
# Processing: 307 Breast cancer.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/307 Breast cancer.xlsx using openpyxl
# [INFO] File: 307 Breast cancer
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 42
# [INFO]   Unique Columns: 14
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: 0408-2.xlsx
# [WARNING] Warning: Could not read SegmentProperties from /data/kjc1/projects/#999.GeoMxmeta/pooled/0408-2.xlsx
# [INFO]
# Processing: KT2_NEW_20230419.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/KT2_NEW_20230419.xlsx using openpyxl
# [INFO] File: KT2_NEW_20230419
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 35
# [INFO]   Unique Columns: 4
# [INFO]   Ignored Columns: 4
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA', 'Scan_ID_1', 'ROI_ID_1', 'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1']
# [INFO]
# Processing: 220905_AA Analysis_SHY.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/220905_AA Analysis_SHY.xlsx using openpyxl
# [INFO] File: 220905_AA Analysis_SHY
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 34
# [INFO]   Unique Columns: 6
# [INFO]   Ignored Columns: 1
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA']
# [INFO]
# Processing: KSJ.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/KSJ.xlsx using openpyxl
# [INFO] File: KSJ
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 64
# [INFO]   Unique Columns: 30
# [INFO]   Ignored Columns: 7
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA', 'Scan_ID_1', 'ROI_ID_1', 'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1', 'Scan_ID_2']...
# [INFO]
# Processing: TA3814.xlsx
# [WARNING] Warning: Could not read SegmentProperties from /data/kjc1/projects/#999.GeoMxmeta/pooled/TA3814.xlsx
# [INFO]
# Processing: 221226_AA GeoMx_SHY.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/221226_AA GeoMx_SHY.xlsx using openpyxl
# [INFO] File: 221226_AA GeoMx_SHY
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 31
# [INFO]   Unique Columns: 3
# [INFO]   Ignored Columns: 1
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA']
# [INFO]
# Processing: GeoMx_Thuy,HY.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/GeoMx_Thuy,HY.xlsx using openpyxl
# [INFO] File: GeoMx_Thuy,HY
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 45
# [INFO]   Unique Columns: 17
# [INFO]   Ignored Columns: 1
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA']
# [INFO]
# Processing: TA3854.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/TA3854.xlsx using openpyxl
# [INFO] File: TA3854
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 30
# [INFO]   Unique Columns: 2
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: 240708_TMA_Halo_nevus_FINAL.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/240708_TMA_Halo_nevus_FINAL.xlsx using openpyxl
# [INFO] File: 240708_TMA_Halo_nevus_FINAL
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 36
# [INFO]   Unique Columns: 7
# [INFO]   Ignored Columns: 1
# [INFO]   Ignored: ['Segment Tags']
# [INFO]
# Processing: IFTA_250121_NEW_except1patient.xlsx
# [WARNING] Warning: Could not read SegmentProperties from /data/kjc1/projects/#999.GeoMxmeta/pooled/IFTA_250121_NEW_except1patient.xlsx
# [INFO]
# Processing: 250114_TCR add on_final.xlsx
# [WARNING] Warning: Could not read SegmentProperties from /data/kjc1/projects/#999.GeoMxmeta/pooled/250114_TCR add on_final.xlsx
# [INFO]
# Processing: 20210315 analysis.xlsx
# [WARNING] Warning: Could not read SegmentProperties from /data/kjc1/projects/#999.GeoMxmeta/pooled/20210315 analysis.xlsx
# [INFO]
# Processing: Lupus Nephritis2_202302224.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/Lupus Nephritis2_202302224.xlsx using openpyxl
# [INFO] File: Lupus Nephritis2_202302224
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 1
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: 20220729 Th2 Psoriasis.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/20220729 Th2 Psoriasis.xlsx using openpyxl
# [INFO] File: 20220729 Th2 Psoriasis
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 44
# [INFO]   Unique Columns: 17
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: IgAN_KMJ_BYJ_20221004.xlsx
# [ERROR] Direct reading failed for /data/kjc1/projects/#999.GeoMxmeta/pooled/IgAN_KMJ_BYJ_20221004.xlsx: invalid literal for int() with base 10: 'NaN'
# [WARNING] Warning: Could not read SegmentProperties from /data/kjc1/projects/#999.GeoMxmeta/pooled/IgAN_KMJ_BYJ_20221004.xlsx
# [INFO]
# Processing: 20220807 JSY HS analysis.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/20220807 JSY HS analysis.xlsx using openpyxl
# [INFO] File: 20220807 JSY HS analysis
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 73
# [INFO]   Unique Columns: 12
# [INFO]   Ignored Columns: 34
# [INFO]   Ignored: ['Scan_ID_6', 'Scan_ID_7', 'Scan_ID_8', 'Scan_ID_9', 'Scan_ID_10']...
# [INFO]
# Processing: IFTA_20241028.xlsx
# [WARNING] Warning: Could not read SegmentProperties from /data/kjc1/projects/#999.GeoMxmeta/pooled/IFTA_20241028.xlsx
# [INFO]
# Processing: TA3855.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/TA3855.xlsx using openpyxl
# [INFO] File: TA3855
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 30
# [INFO]   Unique Columns: 2
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: 20221207 melanoma_bk,yk final.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/20221207 melanoma_bk,yk final.xlsx using openpyxl
# [INFO] File: 20221207 melanoma_bk,yk final
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 40
# [INFO]   Unique Columns: 9
# [INFO]   Ignored Columns: 4
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA', 'Scan_ID_1', 'ROI_ID_1', 'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1']
# [INFO]
# Processing: JHK_Sebaceous carinoma.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/JHK_Sebaceous carinoma.xlsx using openpyxl
# [INFO] File: JHK_Sebaceous carinoma
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 77
# [INFO]   Unique Columns: 48
# [INFO]   Ignored Columns: 2
# [INFO]   Ignored: ['Group', 'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA']
# [INFO]
# Processing: 20221209 melanoma_macrophage.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/20221209 melanoma_macrophage.xlsx using openpyxl
# [INFO] File: 20221209 melanoma_macrophage
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 34
# [INFO]   Unique Columns: 6
# [INFO]   Ignored Columns: 1
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA']
# [INFO]
# Processing: KMJ_Crescent.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/KMJ_Crescent.xlsx using openpyxl
# [INFO] File: KMJ_Crescent
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 0
# [INFO]   Ignored Columns: 1
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA']
# [INFO]
# Processing: tnbc_ln.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/tnbc_ln.xlsx using openpyxl
# [INFO] File: tnbc_ln
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 55
# [INFO]   Unique Columns: 12
# [INFO]   Ignored Columns: 16
# [INFO]   Ignored: ['ROI_ID_3', 'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_3', 'Scan_ID_3', 'Scan_ID_4', 'ROI_ID_4']...
# [INFO]
# Processing: 20221228_psoriasis_jsp, bk.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/20221228_psoriasis_jsp, bk.xlsx using openpyxl
# [INFO] File: 20221228_psoriasis_jsp, bk
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 41
# [INFO]   Unique Columns: 7
# [INFO]   Ignored Columns: 7
# [INFO]   Ignored: ['Scan_ID_2', 'ROI_ID_2', 'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_2', 'Scan_ID_1', 'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA']...
# [INFO]
# Processing: Lupus Nephritis.xlsx
# [WARNING] Warning: Could not read SegmentProperties from /data/kjc1/projects/#999.GeoMxmeta/pooled/Lupus Nephritis.xlsx
# [INFO]
# Processing: 20230103 macrophage .xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/20230103 macrophage .xlsx using openpyxl
# [INFO] File: 20230103 macrophage
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 42
# [INFO]   Unique Columns: 11
# [INFO]   Ignored Columns: 4
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA', 'Scan_ID_1', 'ROI_ID_1', 'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1']
# [INFO]
# Processing: JSY WTA.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/JSY WTA.xlsx using openpyxl
# [INFO] File: JSY WTA
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 30
# [INFO]   Unique Columns: 2
# [INFO]   Ignored Columns: 1
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA']
# [INFO]
# Processing: placenta_KHW.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/placenta_KHW.xlsx using openpyxl
# [INFO] File: placenta_KHW
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 36
# [INFO]   Unique Columns: 6
# [INFO]   Ignored Columns: 2
# [INFO]   Ignored: ['ROI_ID_1', 'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1_1']
# [INFO]
# Processing: 20230512 Brain preliminary 2.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/20230512 Brain preliminary 2.xlsx using openpyxl
# [INFO] File: 20230512 Brain preliminary 2
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 33
# [INFO]   Unique Columns: 3
# [INFO]   Ignored Columns: 3
# [INFO]   Ignored: ['Scan_ID_1', 'ROI_ID_1', 'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1']
# [INFO]
# Processing: CRC.xlsx
# [WARNING] Warning: Could not read SegmentProperties from /data/kjc1/projects/#999.GeoMxmeta/pooled/CRC.xlsx
# [INFO]
# Processing: MuOPKidney.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/MuOPKidney.xlsx using openpyxl
# [INFO] File: MuOPKidney
# [INFO]   Data Type: MOUSE
# [INFO]   Total Columns: 33
# [INFO]   Unique Columns: 5
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: 20230515 brain original rna probe.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/20230515 brain original rna probe.xlsx using openpyxl
# [INFO] File: 20230515 brain original rna probe
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 1
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: Pancreatic Cancer 2.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/Pancreatic Cancer 2.xlsx using openpyxl
# [INFO] File: Pancreatic Cancer 2
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 74
# [INFO]   Unique Columns: 19
# [INFO]   Ignored Columns: 27
# [INFO]   Ignored: ['ROI_ID_5', 'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1_5', 'Scan_ID_6', 'ROI_ID_6', 'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1_6']...
# [INFO]
# Processing: 20230609_GI_2.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/20230609_GI_2.xlsx using openpyxl
# [INFO] File: 20230609_GI_2
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 0
# [INFO]   Ignored Columns: 1
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA']
# [INFO]
# Processing: Marmoset_EAE_ODS.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/Marmoset_EAE_ODS.xlsx using openpyxl
# [INFO] File: Marmoset_EAE_ODS
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 43
# [INFO]   Unique Columns: 11
# [INFO]   Ignored Columns: 4
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1_2', 'ROI_ID_1', 'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1_1', 'ROI_ID_2']
# [INFO]
# Processing: 20230615_LE_Rosa_1st.xlsx
# [WARNING] Warning: Could not read SegmentProperties from /data/kjc1/projects/#999.GeoMxmeta/pooled/20230615_LE_Rosa_1st.xlsx
# [INFO]
# Processing: MN_D1.E3.X1.C4.C3.C2.D4.xlsx
# [WARNING] Warning: Could not read SegmentProperties from /data/kjc1/projects/#999.GeoMxmeta/pooled/MN_D1.E3.X1.C4.C3.C2.D4.xlsx
# [INFO]
# Processing: 20230703_GI_control.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/20230703_GI_control.xlsx using openpyxl
# [INFO] File: 20230703_GI_control
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 0
# [INFO]   Ignored Columns: 1
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA']
# [INFO]
# Processing: MN_D1.E3.X1.C4.C3.C2.D4_.xlsx
# [WARNING] Warning: Could not read SegmentProperties from /data/kjc1/projects/#999.GeoMxmeta/pooled/MN_D1.E3.X1.C4.C3.C2.D4_.xlsx
# [INFO]
# Processing: 20240214_Brain_PD.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/20240214_Brain_PD.xlsx using openpyxl
# [INFO] File: 20240214_Brain_PD
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 0
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: MN_D1.E3.X1.C4.C3.C2.D4__.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/MN_D1.E3.X1.C4.C3.C2.D4__.xlsx using openpyxl
# [INFO] File: MN_D1.E3.X1.C4.C3.C2.D4__
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 0
# [INFO]   Ignored Columns: 1
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA']
# [INFO]
# Processing: 20240723 PV_ChoiSeoyoung_GeoMx.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/20240723 PV_ChoiSeoyoung_GeoMx.xlsx using openpyxl
# [INFO] File: 20240723 PV_ChoiSeoyoung_GeoMx
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 0
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: Breast_Cancer_KHW.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/Breast_Cancer_KHW.xlsx using openpyxl
# [INFO] File: Breast_Cancer_KHW
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 30
# [INFO]   Unique Columns: 2
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: Dermatomyositis.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/Dermatomyositis.xlsx using openpyxl
# [INFO] File: Dermatomyositis
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 37
# [INFO]   Unique Columns: 9
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: Placenta_GeoMx.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/Placenta_GeoMx.xlsx using openpyxl
# [INFO] File: Placenta_GeoMx
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 49
# [INFO]   Unique Columns: 21
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: BC_stage_240607.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/BC_stage_240607.xlsx using openpyxl
# [INFO] File: BC_stage_240607
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 167
# [INFO]   Unique Columns: 49
# [INFO]   Ignored Columns: 90
# [INFO]   Ignored: ['Scan_ID_1', 'ROI_ID_1', 'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1_1', 'Scan_ID_2', 'ROI_ID_2']...
# [INFO]
# Processing: SMC0408.xlsx
# [WARNING] Warning: Could not read SegmentProperties from /data/kjc1/projects/#999.GeoMxmeta/pooled/SMC0408.xlsx
# [INFO]
# Processing: 20240910 Steatosis WTA_BYJ.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/20240910 Steatosis WTA_BYJ.xlsx using openpyxl
# [INFO] File: 20240910 Steatosis WTA_BYJ
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 37
# [INFO]   Unique Columns: 9
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: MN_X3.B4.C1.X2.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/MN_X3.B4.C1.X2.xlsx using openpyxl
# [INFO] File: MN_X3.B4.C1.X2
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 0
# [INFO]   Ignored Columns: 1
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA']
# [INFO]
# Processing: bk melanoma.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/bk melanoma.xlsx using openpyxl
# [INFO] File: bk melanoma
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 88
# [INFO]   Unique Columns: 9
# [INFO]   Ignored Columns: 52
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA', 'Scan_ID_1', 'ROI_ID_1', 'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1', 'Scan_ID_2']...
# [INFO]
# Processing: Keloid GeoMx.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/Keloid GeoMx.xlsx using openpyxl
# [INFO] File: Keloid GeoMx
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 42
# [INFO]   Unique Columns: 14
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: yu.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/yu.xlsx using openpyxl
# [INFO] File: yu
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 32
# [INFO]   Unique Columns: 4
# [INFO]   Ignored Columns: 1
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA']
# [INFO]
# Processing: BK_colon cancer.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/BK_colon cancer.xlsx using openpyxl
# [INFO] File: BK_colon cancer
# [INFO]   Data Type: CTA
# [INFO]   Total Columns: 29
# [INFO]   Unique Columns: 0
# [INFO]   Ignored Columns: 1
# [INFO]   Ignored: ['w/o tumor']
# [INFO]
# Processing: MT analysis_20220920.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/MT analysis_20220920.xlsx using openpyxl
# [INFO] File: MT analysis_20220920
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 30
# [INFO]   Unique Columns: 2
# [INFO]   Ignored Columns: 1
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA']
# [INFO]
# Processing: Bladder_Cancer_Final.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/Bladder_Cancer_Final.xlsx using openpyxl
# [INFO] File: Bladder_Cancer_Final
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 69
# [INFO]   Unique Columns: 26
# [INFO]   Ignored Columns: 16
# [INFO]   Ignored: ['Scan_ID_4', 'ROI_ID_4', 'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_4', 'Scan_ID_5', 'ROI_ID_5']...
# [INFO]
# Processing: Bladder_Cancer_20230913.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/Bladder_Cancer_20230913.xlsx using openpyxl
# [INFO] File: Bladder_Cancer_20230913
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 45
# [INFO]   Unique Columns: 11
# [INFO]   Ignored Columns: 7
# [INFO]   Ignored: ['Scan_ID_1', 'ROI_ID_1', 'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1', 'Scan_ID_2', 'ROI_ID_2']...
# [INFO]
# Processing: BYC_Thymus_B cell_2021.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/BYC_Thymus_B cell_2021.xlsx using openpyxl
# [INFO] File: BYC_Thymus_B cell_2021
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 34
# [INFO]   Unique Columns: 5
# [INFO]   Ignored Columns: 1
# [INFO]   Ignored: ['Segment Tags']
# [INFO]
# Processing: Keloid_LYI_2mm_20240528.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/Keloid_LYI_2mm_20240528.xlsx using openpyxl
# [INFO] File: Keloid_LYI_2mm_20240528
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 37
# [INFO]   Unique Columns: 9
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: BSB_Dermatomyositis.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/BSB_Dermatomyositis.xlsx using openpyxl
# [INFO] File: BSB_Dermatomyositis
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 37
# [INFO]   Unique Columns: 6
# [INFO]   Ignored Columns: 3
# [INFO]   Ignored: ['Scan_ID_1', 'ROI_ID_1', 'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1_1']
# [INFO]
# Processing: NC_20231011.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/NC_20231011.xlsx using openpyxl
# [INFO] File: NC_20231011
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 0
# [INFO]   Ignored Columns: 1
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA']
# [INFO]
# Processing: bullous real data.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/bullous real data.xlsx using openpyxl
# [INFO] File: bullous real data
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 45
# [INFO]   Unique Columns: 16
# [INFO]   Ignored Columns: 2
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA', 'ROI_ID_1']
# [INFO]
# Processing: EoD_analysis_yjbaik.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/EoD_analysis_yjbaik.xlsx using openpyxl
# [INFO] File: EoD_analysis_yjbaik
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 48
# [INFO]   Unique Columns: 20
# [INFO]   Ignored Columns: 1
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA']
# [INFO]
# Processing: HCC_7_10_Final.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/HCC_7_10_Final.xlsx using openpyxl
# [INFO] File: HCC_7_10_Final
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 29
# [INFO]   Unique Columns: 1
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: H Chung_Thymus #1_240921.xlsx
# [WARNING] Warning: Could not read SegmentProperties from /data/kjc1/projects/#999.GeoMxmeta/pooled/H Chung_Thymus #1_240921.xlsx
# [INFO]
# Processing: HCC_VETC_HSH.xlsx
# [WARNING] Warning: Could not read SegmentProperties from /data/kjc1/projects/#999.GeoMxmeta/pooled/HCC_VETC_HSH.xlsx
# [INFO]
# Processing: IgAN_TPL_20240329.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/IgAN_TPL_20240329.xlsx using openpyxl
# [INFO] File: IgAN_TPL_20240329
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 0
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: HCC_NTvsTC_48_KDJ_real.xlsx
# [WARNING] Warning: Could not read SegmentProperties from /data/kjc1/projects/#999.GeoMxmeta/pooled/HCC_NTvsTC_48_KDJ_real.xlsx
# [INFO]
# Processing: HCC_NT_vs_TC_48_KMJ.xlsx
# [WARNING] Warning: Could not read SegmentProperties from /data/kjc1/projects/#999.GeoMxmeta/pooled/HCC_NT_vs_TC_48_KMJ.xlsx
# [INFO]
# Processing: HS_LYI_20240411.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/HS_LYI_20240411.xlsx using openpyxl
# [INFO] File: HS_LYI_20240411
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 30
# [INFO]   Unique Columns: 2
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: mouse_nasal_polyp....xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/mouse_nasal_polyp....xlsx using openpyxl
# [INFO] File: mouse_nasal_polyp...
# [INFO]   Data Type: MOUSE
# [INFO]   Total Columns: 29
# [INFO]   Unique Columns: 0
# [INFO]   Ignored Columns: 1
# [INFO]   Ignored: ['Segment 1']
# [INFO]
# Processing: HCC_TMA_KMS.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/HCC_TMA_KMS.xlsx using openpyxl
# [INFO] File: HCC_TMA_KMS
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 30
# [INFO]   Unique Columns: 2
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: HS_LYI_2023922.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/HS_LYI_2023922.xlsx using openpyxl
# [INFO] File: HS_LYI_2023922
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 48
# [INFO]   Unique Columns: 14
# [INFO]   Ignored Columns: 7
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA', 'Scan_ID_1', 'ROI_ID_1', 'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1', 'Scan_ID_2']...
# [INFO]
# Processing: RCC_56+28AOI.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/RCC_56+28AOI.xlsx using openpyxl
# [INFO] File: RCC_56+28AOI
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 35
# [INFO]   Unique Columns: 7
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: Pancreatic Cancer_HSH_231218.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/Pancreatic Cancer_HSH_231218.xlsx using openpyxl
# [INFO] File: Pancreatic Cancer_HSH_231218
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 39
# [INFO]   Unique Columns: 6
# [INFO]   Ignored Columns: 5
# [INFO]   Ignored: ['Scan_ID_1', 'ROI_ID_1', 'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1_1', 'Scan_ID_2', 'ROI_ID_2']
# [INFO]
# Processing: Preliminary MSA Brain 2023.03.22.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/Preliminary MSA Brain 2023.03.22.xlsx using openpyxl
# [INFO] File: Preliminary MSA Brain 2023.03.22
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 1787
# [INFO]   Unique Columns: 34
# [INFO]   Ignored Columns: 1726
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA', 'Scan_ID_1', 'ROI_ID_1', 'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1', 'Scan_ID_2']...
# [INFO]
# Processing: Preliminary230404_GI.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/Preliminary230404_GI.xlsx using openpyxl
# [INFO] File: Preliminary230404_GI
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 79
# [INFO]   Unique Columns: 30
# [INFO]   Ignored Columns: 22
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA', 'Scan_ID_1', 'ROI_ID_1', 'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1', 'Scan_ID_2']...
# [INFO]
# Processing: SCC GeoMx.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/SCC GeoMx.xlsx using openpyxl
# [INFO] File: SCC GeoMx
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 39
# [INFO]   Unique Columns: 11
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: SJ_HY geomx Thymus.xlsx
# [WARNING] Warning: Could not read SegmentProperties from /data/kjc1/projects/#999.GeoMxmeta/pooled/SJ_HY geomx Thymus.xlsx
# [INFO]
# Processing: SDR_Hu_HT.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/SDR_Hu_HT.xlsx using openpyxl
# [INFO] File: SDR_Hu_HT
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 30
# [INFO]   Unique Columns: 2
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: steatosis cta.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/steatosis cta.xlsx using openpyxl
# [INFO] File: steatosis cta
# [INFO]   Data Type: CTA
# [INFO]   Total Columns: 31
# [INFO]   Unique Columns: 3
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: syringoma re.xlsx
# [WARNING] Warning: Could not read SegmentProperties from /data/kjc1/projects/#999.GeoMxmeta/pooled/syringoma re.xlsx
# [INFO]
# Processing: thymus normal.xlsx
# [WARNING] Warning: Could not read SegmentProperties from /data/kjc1/projects/#999.GeoMxmeta/pooled/thymus normal.xlsx
# [INFO]
# Processing: thymus240401.xlsx
# [WARNING] Warning: Could not read SegmentProperties from /data/kjc1/projects/#999.GeoMxmeta/pooled/thymus240401.xlsx
# [INFO]
# Processing: Total(Ubiased clustering_DRESS123).xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/Total(Ubiased clustering_DRESS123).xlsx using openpyxl
# [INFO] File: Total(Ubiased clustering_DRESS123)
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 52
# [INFO]   Unique Columns: 24
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: TOF_geomx_analysis.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/TOF_geomx_analysis.xlsx using openpyxl
# [INFO] File: TOF_geomx_analysis
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 31
# [INFO]   Unique Columns: 3
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: Wound_GeoMx.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/Wound_GeoMx.xlsx using openpyxl
# [INFO] File: Wound_GeoMx
# [INFO]   Data Type: MOUSE
# [INFO]   Total Columns: 110
# [INFO]   Unique Columns: 82
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: Wound_KHW.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/Wound_KHW.xlsx using openpyxl
# [INFO] File: Wound_KHW
# [INFO]   Data Type: MOUSE
# [INFO]   Total Columns: 32
# [INFO]   Unique Columns: 4
# [INFO]   Ignored Columns: 0
# [WARNING]
# 28 files had issues:
# [WARNING]   - DKD_20240125.xlsx
# [WARNING]   - t4p.xlsx
# [WARNING]   - Keloid_LYI_4mm_20240528.xlsx
# [WARNING]   - (empty)BK melanoma.xlsx
# [WARNING]   - CRC(2).xlsx
# [WARNING]   - (not aligned)20221207 bk,yk melanoma.xlsx
# [WARNING]   - Final Thymus normal.xlsx
# [WARNING]   - 0408-2.xlsx
# [WARNING]   - TA3814.xlsx
# [WARNING]   - IFTA_250121_NEW_except1patient.xlsx
# [WARNING]   - 250114_TCR add on_final.xlsx
# [WARNING]   - 20210315 analysis.xlsx
# [WARNING]   - IgAN_KMJ_BYJ_20221004.xlsx
# [WARNING]   - IFTA_20241028.xlsx
# [WARNING]   - Lupus Nephritis.xlsx
# [WARNING]   - CRC.xlsx
# [WARNING]   - 20230615_LE_Rosa_1st.xlsx
# [WARNING]   - MN_D1.E3.X1.C4.C3.C2.D4.xlsx
# [WARNING]   - MN_D1.E3.X1.C4.C3.C2.D4_.xlsx
# [WARNING]   - SMC0408.xlsx
# [WARNING]   - H Chung_Thymus #1_240921.xlsx
# [WARNING]   - HCC_VETC_HSH.xlsx
# [WARNING]   - HCC_NTvsTC_48_KDJ_real.xlsx
# [WARNING]   - HCC_NT_vs_TC_48_KMJ.xlsx
# [WARNING]   - SJ_HY geomx Thymus.xlsx
# [WARNING]   - syringoma re.xlsx
# [WARNING]   - thymus normal.xlsx
# [WARNING]   - thymus240401.xlsx
# [INFO]
# Saved unique columns analysis to output/unique_columns_analysis.csv
#
# === Unique Columns Summary ===
# data_type  column_name
# CTA        injured                                             1
#            non-injured                                         1
#            recovered                                           1
# MOUSE      D0_margin                                           1
#            D0_margin1                                          1
#            D0_margin2                                          1
#            D0_margin3                                          1
#            D1_distant                                          1
#            D1_distant1                                         1
#            D1_distant2                                         1
#            D1_distant3                                         1
#            D1_margin                                           1
#            D1_margin1                                          1
#            D1_margin2                                          1
#            D1_margin3                                          1
#            D3_distant                                          1
#            D3_distant1                                         1
#            D3_distant2                                         1
#            D3_distant3                                         1
#            D3_margin                                           1
#            D3_margin1                                          1
#            D3_margin2                                          1
#            D3_margin3                                          1
#            D7_center                                           1
#            D7_center1                                          1
#            D7_center2                                          1
#            D7_center3                                          1
#            D7_distant                                          1
#            D7_distant(follicle_include)                        1
#            D7_distant1(follicle_include)                       1
#            D7_distant2                                         1
#            D7_distant3                                         1
#            D7_hypo                                             1
#            D7_hypo1                                            1
#            D7_hypo2                                            1
#            D7_hypo3                                            1
#            D7_margin                                           1
#            D7_margin1                                          1
#            D7_margin2                                          1
#            D7_margin3                                          1
#            Epithelial cells                                    1
#            Iba+                                                2
#            Iba+_D0_margin                                      1
#            Iba+_D1_distant                                     1
#            Iba+_D1_margin                                      1
#            Iba+_D3_distant                                     1
#            Iba+_D3_margin                                      1
#            Iba+_D7_center                                      1
#            Iba+_D7_distant                                     1
#            Iba+_D7_distant(follicle_include)                   1
#            Iba+_D7_hypo                                        1
#            Iba+_D7_margin                                      1
#            Iba_D0                                              1
#            Iba_D1                                              1
#            Iba_D3                                              1
#            Iba_D7                                              1
#            Macrophage                                          1
#            PanCK-Iba-                                          2
#            PanCK-Iba-_D0_margin                                1
#            PanCK-Iba-_D1_distant                               1
#            PanCK-Iba-_D1_margin                                1
#            PanCK-Iba-_D3_distant                               1
#            PanCK-Iba-_D3_margin                                1
#            PanCK-Iba-_D7_center                                1
#            PanCK-Iba-_D7_distant                               1
#            PanCK-Iba-_D7_distant(follicle_include)             1
#            PanCK-Iba-_D7_hypo                                  1
#            PanCK-Iba-_D7_margin                                1
#            Panck+                                              2
#            Panck+_D0_margin                                    1
#            Panck+_D1_distant                                   1
#            Panck+_D1_margin                                    1
#            Panck+_D3_distant                                   1
#            Panck+_D3_margin                                    1
#            Panck+_D7_center                                    1
#            Panck+_D7_distant                                   1
#            Panck+_D7_distant(follicle_include)                 1
#            Panck+_D7_margin                                    1
#            ROIComments                                         3
#            Segment 1                                           1
#            Segment 2                                           1
#            ck_D0                                               1
#            ck_D1                                               1
#            ck_D3                                               1
#            ck_D7                                               1
#            neg_D0                                              1
#            neg_D1                                              1
#            neg_D3                                              1
#            neg_D7                                              1
# WTA        -                                                   1
#            1-1 Der                                             1
#            1-1 Epi                                             1
#            1-21 Der                                            1
#            1-21 Epi                                            1
#            1-22 Der                                            1
#            1-22 Epi                                            1
#            1-3 Der                                             1
#            1-3 Epi                                             1
#            131_early_para                                      1
#            131_early_stea                                      1
#            131_late                                            1
#            2-1 Der                                             1
#            2-1 Epi                                             1
#            2-2 Der                                             1
#            2-2 Epi                                             1
#            2-3 Der                                             1
#            2-3 Epi                                             1
#            3-1 Der                                             1
#            3-1 Epi                                             1
#            3-2 Der                                             1
#            3-2 Epi                                             1
#            3-3 Der                                             1
#            3-3 Epi                                             1
#            87_early_para                                       1
#            87_early_stea                                       1
#            87_late                                             1
#            A                                                   1
#            AA                                                  2
#            AA #1                                               1
#            AA #2                                               1
#            AA #3                                               1
#            AA #4                                               1
#            AA_isthmus                                          1
#            AC Cystic wall                                      1
#            AC Epithelial cell                                  1
#            AC Immune cell                                      1
#            AC Inflammation                                     1
#            AC Interfollicular epidermis                        1
#            AC Normal hair follicle                             1
#            AD_epithelial cell                                  1
#            AD_immune cell                                      1
#            AD_infiltrating lymphocyte                          1
#            AR_0                                                1
#            AR_1                                                1
#            AR_10__                                             1
#            AR_na                                               1
#            A_ post_PanCK(-)                                    1
#            A_post                                              1
#            A_post_PanCK(+)                                     1
#            A_pre                                               1
#            A_pre_PanCK(+)                                      1
#            A_pre_PanCK(-)                                      1
#            Adventitial                                         1
#            B                                                   2
#            BO                                                  1
#            BP                                                  1
#            BP Blistered Epidermis                              1
#            BP Infiltrated                                      1
#            BP Infiltrated_1                                    1
#            BP Infiltrated_2                                    1
#            BP Infiltrated_3                                    1
#            BP Infiltrated_4                                    1
#            BP Intact Epidermis                                 1
#            BRCA1_epi_C                                         1
#            BRCA1_epi_LN                                        1
#            BRCA1_epi_N                                         1
#            BRCA1_stroma_C                                      1
#            BRCA1_stroma_LN                                     1
#            BRCA1_stroma_N                                      1
#            BRCA2_epi_C                                         1
#            BRCA2_epi_LN                                        1
#            BRCA2_epi_N                                         1
#            BRCA2_epi_S                                         1
#            BRCA2_stroma_C                                      1
#            BRCA2_stroma_LN                                     1
#            BRCA2_stroma_N                                      1
#            BRCA2_stroma_S                                      1
#            B_post                                              1
#            B_post_PanCK(+)                                     1
#            B_post_PanCK(-)                                     1
#            B_pre                                               1
#            B_pre_PanCK(+)                                      1
#            B_pre_PanCK(-)                                      1
#            Basal                                               1
#            Basal_0                                             1
#            Basal_panCK-                                        1
#            Breast Tumor                                        1
#            C Nevus_Epi                                         1
#            C Nevus_Ne                                          1
#            C1                                                  2
#            C10                                                 2
#            C11                                                 2
#            C12                                                 2
#            C2                                                  2
#            C3                                                  2
#            C4                                                  2
# ...
#            NECTIN4 Low_CK-                                     1
#            Necrosis                                            2
#            Nno                                                 1
#            No                                                  1
#            Normal                                              2
#            Normal_tissue                                       1
#            Outer_M                                             1
#            Outer_T                                             1
#            P Macrophage                                        1
#            P T cell                                            1
#            P melanoma                                          1
#            P1 Macrophage                                       1
#            P1 Melanoma                                         1
#            P1 T cell                                           3
#            P1 macrophage                                       2
#            P1 melanoma                                         2
#            P2 Macrophage                                       1
#            P2 Melanoma                                         1
#            P2 T cell                                           3
#            P2 macrophage                                       2
#            P2 melanoma                                         2
#            P53_0                                               1
#            P53_1                                               1
#            P53_IHC_                                            1
#            P53_X                                               1
#            P53_na                                              1
#            PANIN-like VI                                       1
#            PANIN-like VI (PanCK +)                             1
#            PANIN-like VI (PanCK -)                             1
#            PDL1                                                1
#            PDL1_0                                              1
#            PDL1_1                                              1
#            PDL1_X                                              1
#            PDL1_na                                             1
#            POD9_CD3                                            2
#            POD9_glom                                           2
#            PP                                                  1
#            PP Blistered Epidermis                              1
#            PP Infiltrated                                      1
#            PP Intact Epidermis                                 1
#            PPH                                                 1
#            PR_0                                                1
#            PR_1                                                1
#            PR_10__                                             1
#            PR_na                                               1
#            PV                                                  1
#            PV Blistered Epidermis                              1
#            PV Infiltrated                                      1
#            PV Intact Epidermis                                 1
#            PanCK(+)                                            1
#            PanCK(-)                                            1
#            PanCK+                                              2
#            PanCK-                                              2
#            PanCk                                               2
#            Panck+                                              3
#            Panck-                                              3
#            Parenchymal                                         1
#            Pathologic_CR                                       1
#            Pathologic_CR_1                                     1
#            Peri_melanoma-1                                     1
#            Peri_melanoma-2                                     1
#            Psoriasis_epithelial cell                           1
#            Psoriasis_immune cell                               1
#            Psoriasis_infiltrating lymphocyte                   1
#            RCB_Group                                           1
#            RCB_Group_1                                         1
#            ROIComments                                         4
#            RR control                                          1
#            RR fibrosis                                         1
#            RRDD fibrosis                                       1
#            Regions                                             1
#            Right                                               1
#            SA                                                  1
#            SD                                                  3
#            SMA                                                 1
#            SMA+                                                1
#            SMA-                                                1
#            SU                                                  1
#            Scan Name                                           2
#            Scan Name_1                                         1
#            Segment 1                                          13
#            Segment 2                                          10
#            Segment Tags                                        2
#            Segment Tags_1                                      1
#            Sev Epi                                             1
#            Sev Imm                                             1
#            Shin HS Epithelial Cells                            1
#            Shin HS Immune Cells                                1
#            Shin HS Peri-Lesional Epithelial Cells              1
#            Single cell invasion                                1
#            Steatosis                                           3
#            T                                                   1
#            T1                                                  4
#            T1 + T2                                             1
#            T1.5                                                1
#            T1.5(2)                                             1
#            T1_1                                                1
#            T1_2                                                1
#            T1_3                                                1
#            T1_4                                                1
#            T1_Cold_Tumor cell                                  1
#            T1_Hot_Tumor cell                                   1
#            T1_O                                                1
#            T1_panCK+                                           1
#            T1_panCK-                                           1
#            T2                                                  4
#            T2+3+4                                              1
#            T2_1                                                1
#            T2_2                                                1
#            T2_3                                                1
#            T2_4                                                1
#            T2_Cold_Tumor cell                                  1
#            T2_Hot_Tumor cell                                   1
#            T2_O                                                1
#            T2_panCK+                                           1
#            T2_panCK-                                           1
#            T3                                                  4
#            T3_1                                                1
#            T3_2                                                1
#            T3_3                                                1
#            T3_4                                                1
#            T3_Cold_CAF                                         1
#            T3_Cold_CAF_Single cell invasion                    1
#            T3_Cold_LVI                                         1
#            T3_Cold_Necrosis                                    1
#            T3_Cold_Single cell invasion                        1
#            T3_Cold_Tumor cell                                  1
#            T3_panCK+                                           1
#            T3_panCK-                                           1
#            T4                                                  3
#            T4_Hot_CAF                                          1
#            T4_Hot_LVI                                          1
#            T4_Hot_Single cell invasion                         1
#            T4_Hot_Tumor cell                                   1
#            TA                                                  1
#            TCMR                                                1
#            TCMR_Glom                                           1
#            TCMR_interstitium                                   1
#            TI                                                  1
#            TI1                                                 1
#            TI2                                                 1
#            TI3                                                 1
#            TIF                                                 1
#            TIF1                                                1
#            TIF2                                                1
#            TILhigh                                             1
#            TILlow                                              1
#            TIS                                                 1
#            TIS1                                                1
#            TIS2                                                1
#            TIS3                                                1
#            TMA_No                                              1
#            T_1                                                 1
#            T_2                                                 1
#            T_Microglia+                                        1
#            T_Microglia-                                        1
#            T_Tcell+                                            1
#            T_na                                                1
#            T_stage                                             1
#            Tcell+                                              1
#            Th2 Psoriasis_epithelial cell                       1
#            Th2 Psoriasis_epithelial cell_HY                    1
#            Th2 Psoriasis_epithelial cell_SP                    1
#            Th2 Psoriasis_infiltrating lymphocyte               1
#            Th2 Psoriasis_infiltrating lymphocyte_HY            1
#            Th2 Psoriasis_infiltrating lymphocyte_SP            1
#            Thymus B cell 001                                   1
#            Thymus_cortex_B cells                               1
#            Thymus_medulla_B cells                              1
#            Tissue                                              1
#            Tissue_1                                            1
#            Tissue_2                                            1
#            Troponin                                            1
#            Tumor                                               3
#            Tumor Immune(1)                                     1
#            Tumor Immune(2)                                     1
#            Tumor cell                                          2
#            Tumor only                                          4
#            Up                                                  1
#            V                                                   1
#            VI                                                  1
#            VI (PanCK +)                                        1
#            VI (PanCK -)                                        1
#            VV                                                  1
#            Ventral                                             1
#            Zerotime_glom                                       2
#            Zerotime_interstitium                               2
#            [0] CD4 T cell                                      1
#            [0] Keratinocyte                                    1
#            [0] Macrophage                                      1
#            [4] CD4 T cell                                      1
#            [4] Keratinocyte                                    1
#            [4] Macrophage                                      1
#            [Pre] Keratinocyte                                  1
#            [post] CD4+ T cell                                  1
#            [post] Keratinocyte                                 1
#            [post] Macrophage                                   1
#            [pre] CD4+ T cell                                   1
#            [pre] Macrophage                                    1
#            acini                                               1
#            ann_pathcr                                          1
#            biology                                             1
#            control                                             1
#            control_Glom                                        1
#            control_interstitium                                1
#            cortical b cells                                    1
#            ctrl                                                1
#            decidua                                             2
#            deciduacell                                         1
#            disease                                             1
#            early_para                                          1
#            early_stea                                          1
#            immu                                                1
#            implantation site                                   1
#            late                                                1
#            lobule_1                                            1
#            lobule_2                                            1
#            medullary b cells                                   1
#            mixed type 1_epithelial cell                        1
#            mixed type 1_immune cell                            1
#            mixed type 2_epithelial cell                        1
#            mixed type 2_immune cell                            1
#            moderate Der                                        1
#            moderate epi                                        1
#            myocardiocyte                                       1
#            p53 non-specific                                    1
#            p53+                                                1
#            p53-                                                1
#            pembroli Der                                        1
#            pembroli epi                                        1
#            post                                                1
#            post-borderline ATMR                                1
#            post-borderline ATMR_glom                           1
#            post-grade II ATMR                                  1
#            post-grade II ATMR_glom                             1
#            pre                                                 1
#            pre-borderline ATMR                                 1
#            pre-borderline ATMR_glom                            1
#            pre-grade II ATMR                                   1
#            pre-grade II ATMR_glom                              1
#            shIL_37                                             1
#            shcontrol                                           1
#            trophoblast                                         2
#            villi                                               1
# [INFO] Saved problematic files list to output/problematic_files.txt
# [INFO] Saved mapping template to output/column_mapping_template.csv

# %%
# %%bash
# # 2. 결과 확인
# cat ./output/unique_columns_analysis.csv | head
# cat ./output/column_mapping_template.csv | head
#
# # 3. 문제 파일 확인 (있는 경우)
# cat ./output/problematic_files.txt
# Out:
# dataset,data_type,column_name,dtype,unique_values,unique_count,null_count,total_count
# #124_mIBD_biologics_95AOI,WTA,Segment 1,Boolean,"True, False",2,0,95
# #124_mIBD_biologics_95AOI,WTA,Segment 2,Boolean,"False, True",2,0,95
# e,WTA,Segment 1,Boolean,"False, True",2,0,48
# PC_multi_250219,WTA,Islet,Boolean,"True, False",2,0,20
# PC_multi_250219,WTA,Normal,Boolean,"True, False",2,0,20
# PC_multi_250219,WTA,DAPI,Boolean,"False, True",2,0,20
# PC_multi_250219,WTA,acini,Boolean,"False, True",2,0,20
# #124_mIBD_bologics_44AOI,WTA,Segment 1,Boolean,"True, False",2,0,44
# #124_mIBD_bologics_44AOI,WTA,Segment 2,Boolean,"False, True",2,0,44
# original_column,unified_name,data_types,datasets,sample_values,value_mapping,notes
# Segment 1,Segment 1,"WTA, MOUSE","#124_mIBD_biologics_95AOI, e, #124_mIBD_bologics_44AOI, KSJ2, KSJ, TA3855, 20221228_psoriasis_jsp, bk, 20230103 macrophage , MuOPKidney, yu, Keloid_LYI_2mm_20240528, EoD_analysis_yjbaik, HS_LYI_20240411, HCC_TMA_KMS","[True, False], [False, True]",,
# Segment 2,Segment 2,"WTA, MOUSE","#124_mIBD_biologics_95AOI, #124_mIBD_bologics_44AOI, KSJ2, KSJ, TA3855, 20230103 macrophage , MuOPKidney, yu, EoD_analysis_yjbaik, HS_LYI_20240411, HCC_TMA_KMS","[False, True]",,
# Islet,Islet,WTA,PC_multi_250219,"[True, False]",,
# Normal,Normal,WTA,"PC_multi_250219, KSJ","[True, False], [False, True]",,
# DAPI,DAPI,WTA,PC_multi_250219,"[False, True]",,
# acini,acini,WTA,PC_multi_250219,"[False, True]",,
# TCMR_interstitium,TCMR_interstitium,WTA,Kidney TPL_GeoMx_R1,"[True, False]",,
# TCMR,TCMR,WTA,Kidney TPL_GeoMx_R1,"[True, False]",,
# TCMR_Glom,TCMR_Glom,WTA,Kidney TPL_GeoMx_R1,"[False, True]",,
# Files with reading issues:
# /data/kjc1/projects/#999.GeoMxmeta/pooled/DKD_20240125.xlsx
# /data/kjc1/projects/#999.GeoMxmeta/pooled/t4p.xlsx
# /data/kjc1/projects/#999.GeoMxmeta/pooled/Keloid_LYI_4mm_20240528.xlsx
# /data/kjc1/projects/#999.GeoMxmeta/pooled/(empty)BK melanoma.xlsx
# /data/kjc1/projects/#999.GeoMxmeta/pooled/CRC(2).xlsx
# /data/kjc1/projects/#999.GeoMxmeta/pooled/(not aligned)20221207 bk,yk melanoma.xlsx
# /data/kjc1/projects/#999.GeoMxmeta/pooled/Final Thymus normal.xlsx
# /data/kjc1/projects/#999.GeoMxmeta/pooled/0408-2.xlsx
# /data/kjc1/projects/#999.GeoMxmeta/pooled/TA3814.xlsx
# /data/kjc1/projects/#999.GeoMxmeta/pooled/IFTA_250121_NEW_except1patient.xlsx
# /data/kjc1/projects/#999.GeoMxmeta/pooled/250114_TCR add on_final.xlsx
# /data/kjc1/projects/#999.GeoMxmeta/pooled/20210315 analysis.xlsx
# /data/kjc1/projects/#999.GeoMxmeta/pooled/IgAN_KMJ_BYJ_20221004.xlsx
# /data/kjc1/projects/#999.GeoMxmeta/pooled/IFTA_20241028.xlsx
# /data/kjc1/projects/#999.GeoMxmeta/pooled/Lupus Nephritis.xlsx
# /data/kjc1/projects/#999.GeoMxmeta/pooled/CRC.xlsx
# /data/kjc1/projects/#999.GeoMxmeta/pooled/20230615_LE_Rosa_1st.xlsx
# /data/kjc1/projects/#999.GeoMxmeta/pooled/MN_D1.E3.X1.C4.C3.C2.D4.xlsx
# /data/kjc1/projects/#999.GeoMxmeta/pooled/MN_D1.E3.X1.C4.C3.C2.D4_.xlsx
# /data/kjc1/projects/#999.GeoMxmeta/pooled/SMC0408.xlsx
# /data/kjc1/projects/#999.GeoMxmeta/pooled/H Chung_Thymus #1_240921.xlsx
# /data/kjc1/projects/#999.GeoMxmeta/pooled/HCC_VETC_HSH.xlsx
# /data/kjc1/projects/#999.GeoMxmeta/pooled/HCC_NTvsTC_48_KDJ_real.xlsx
# /data/kjc1/projects/#999.GeoMxmeta/pooled/HCC_NT_vs_TC_48_KMJ.xlsx
# /data/kjc1/projects/#999.GeoMxmeta/pooled/SJ_HY geomx Thymus.xlsx
# /data/kjc1/projects/#999.GeoMxmeta/pooled/syringoma re.xlsx
# /data/kjc1/projects/#999.GeoMxmeta/pooled/thymus normal.xlsx
# /data/kjc1/projects/#999.GeoMxmeta/pooled/thymus240401.xlsx

# %%
# %%bash
# # 4. Metadata 통합
# xlsx_folder="/data/kjc1/projects/#999.GeoMxmeta/pooled/"
# python geomx_processor_v2.py merge $xlsx_folder ./output/column_mapping_template.csv -o ./output
# Out:
# [INFO] Found 114 xlsx files
# [INFO]
# Processing: DKD_20240125.xlsx
# [WARNING] Warning: Could not read SegmentProperties from /data/kjc1/projects/#999.GeoMxmeta/pooled/DKD_20240125.xlsx
# [INFO]
# Processing: t4p.xlsx
# [WARNING] Warning: Could not read SegmentProperties from /data/kjc1/projects/#999.GeoMxmeta/pooled/t4p.xlsx
# [INFO]
# Processing: #124_mIBD_biologics_95AOI.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/#124_mIBD_biologics_95AOI.xlsx using openpyxl
# [INFO] File: #124_mIBD_biologics_95AOI
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 30
# [INFO]   Unique Columns: 2
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: e.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/e.xlsx using openpyxl
# [INFO] File: e
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 29
# [INFO]   Unique Columns: 1
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: PC_multi_250219.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/PC_multi_250219.xlsx using openpyxl
# [INFO] File: PC_multi_250219
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 33
# [INFO]   Unique Columns: 4
# [INFO]   Ignored Columns: 1
# [INFO]   Ignored: ['ROIComments']
# [INFO]
# Processing: #124_mIBD_bologics_44AOI.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/#124_mIBD_bologics_44AOI.xlsx using openpyxl
# [INFO] File: #124_mIBD_bologics_44AOI
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 30
# [INFO]   Unique Columns: 2
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: Kidney TPL_GeoMx_R1.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/Kidney TPL_GeoMx_R1.xlsx using openpyxl
# [INFO] File: Kidney TPL_GeoMx_R1
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 40
# [INFO]   Unique Columns: 6
# [INFO]   Ignored Columns: 7
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA', 'Scan_ID_1', 'ROI_ID_1', 'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1', 'Scan_ID_2']...
# [INFO]
# Processing: #377 Ari_ILC_mo.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/#377 Ari_ILC_mo.xlsx using openpyxl
# [INFO] File: #377 Ari_ILC_mo
# [INFO]   Data Type: MOUSE
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 0
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: Keloid_LYI_4mm_20240528.xlsx
# [WARNING] Warning: Could not read SegmentProperties from /data/kjc1/projects/#999.GeoMxmeta/pooled/Keloid_LYI_4mm_20240528.xlsx
# [INFO]
# Processing: #377 ILC_Ari_Revision.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/#377 ILC_Ari_Revision.xlsx using openpyxl
# [INFO] File: #377 ILC_Ari_Revision
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 35
# [INFO]   Unique Columns: 7
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: (empty)BK melanoma.xlsx
# [WARNING] Warning: Could not read SegmentProperties from /data/kjc1/projects/#999.GeoMxmeta/pooled/(empty)BK melanoma.xlsx
# [INFO]
# Processing: CRC(2).xlsx
# [WARNING] Warning: Could not read SegmentProperties from /data/kjc1/projects/#999.GeoMxmeta/pooled/CRC(2).xlsx
# [INFO]
# Processing: NHS.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/NHS.xlsx using openpyxl
# [INFO] File: NHS
# [INFO]   Data Type: MOUSE
# [INFO]   Total Columns: 29
# [INFO]   Unique Columns: 0
# [INFO]   Ignored Columns: 1
# [INFO]   Ignored: ['Segment 1']
# [INFO]
# Processing: (not aligned)20221207 bk,yk melanoma.xlsx
# [ERROR] Direct reading failed for /data/kjc1/projects/#999.GeoMxmeta/pooled/(not aligned)20221207 bk,yk melanoma.xlsx: invalid literal for int() with base 10: 'NaN'
# [WARNING] Warning: Could not read SegmentProperties from /data/kjc1/projects/#999.GeoMxmeta/pooled/(not aligned)20221207 bk,yk melanoma.xlsx
# [INFO]
# Processing: IgAN_KMJ_BYJ_final.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/IgAN_KMJ_BYJ_final.xlsx using openpyxl
# [INFO] File: IgAN_KMJ_BYJ_final
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 34
# [INFO]   Unique Columns: 3
# [INFO]   Ignored Columns: 4
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA', 'Scan_ID_1', 'ROI_ID_1', 'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1']
# [INFO]
# Processing: 22.12.08 GeoMx Analysis(2).xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/22.12.08 GeoMx Analysis(2).xlsx using openpyxl
# [INFO] File: 22.12.08 GeoMx Analysis(2)
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 33
# [INFO]   Unique Columns: 5
# [INFO]   Ignored Columns: 1
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA']
# [INFO]
# Processing: Kidney TPL_GeoMx_R2.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/Kidney TPL_GeoMx_R2.xlsx using openpyxl
# [INFO] File: Kidney TPL_GeoMx_R2
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 43
# [INFO]   Unique Columns: 12
# [INFO]   Ignored Columns: 4
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA', 'Scan_ID_1', 'ROI_ID_1', 'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1']
# [INFO]
# Processing: 23.01.06(2) HCC.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/23.01.06(2) HCC.xlsx using openpyxl
# [INFO] File: 23.01.06(2) HCC
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 39
# [INFO]   Unique Columns: 5
# [INFO]   Ignored Columns: 7
# [INFO]   Ignored: ['Scan_ID_1', 'ROI_ID_1', 'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1', 'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA', 'Scan_ID_2']...
# [INFO]
# Processing: Final Thymus normal.xlsx
# [WARNING] Warning: Could not read SegmentProperties from /data/kjc1/projects/#999.GeoMxmeta/pooled/Final Thymus normal.xlsx
# [INFO]
# Processing: 23.01.06_HY GeoMx analysis.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/23.01.06_HY GeoMx analysis.xlsx using openpyxl
# [INFO] File: 23.01.06_HY GeoMx analysis
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 54
# [INFO]   Unique Columns: 20
# [INFO]   Ignored Columns: 7
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA', 'Scan_ID_1', 'ROI_ID_1', 'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1', 'Scan_ID_2']...
# [INFO]
# Processing: MN_A1.2.3.4_B1.2.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/MN_A1.2.3.4_B1.2.xlsx using openpyxl
# [INFO] File: MN_A1.2.3.4_B1.2
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 0
# [INFO]   Ignored Columns: 1
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA']
# [INFO]
# Processing: 23.06.27 HCC2 vs HCC.x.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/23.06.27 HCC2 vs HCC.x.xlsx using openpyxl
# [INFO] File: 23.06.27 HCC2 vs HCC.x
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 0
# [INFO]   Ignored Columns: 1
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA']
# [INFO]
# Processing: Koh_Breast cancer.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/Koh_Breast cancer.xlsx using openpyxl
# [INFO] File: Koh_Breast cancer
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 43
# [INFO]   Unique Columns: 14
# [INFO]   Ignored Columns: 2
# [INFO]   Ignored: ['ROI_ID_1', 'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA']
# [INFO]
# Processing: 24.06.04 HCC final_GW2.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/24.06.04 HCC final_GW2.xlsx using openpyxl
# [INFO] File: 24.06.04 HCC final_GW2
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 29
# [INFO]   Unique Columns: 1
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: KSJ2.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/KSJ2.xlsx using openpyxl
# [INFO] File: KSJ2
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 30
# [INFO]   Unique Columns: 2
# [INFO]   Ignored Columns: 1
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA']
# [INFO]
# Processing: TA3815.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/TA3815.xlsx using openpyxl
# [INFO] File: TA3815
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 0
# [INFO]   Ignored Columns: 1
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA']
# [INFO]
# Processing: 307 Breast cancer.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/307 Breast cancer.xlsx using openpyxl
# [INFO] File: 307 Breast cancer
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 42
# [INFO]   Unique Columns: 14
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: 0408-2.xlsx
# [WARNING] Warning: Could not read SegmentProperties from /data/kjc1/projects/#999.GeoMxmeta/pooled/0408-2.xlsx
# [INFO]
# Processing: KT2_NEW_20230419.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/KT2_NEW_20230419.xlsx using openpyxl
# [INFO] File: KT2_NEW_20230419
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 35
# [INFO]   Unique Columns: 4
# [INFO]   Ignored Columns: 4
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA', 'Scan_ID_1', 'ROI_ID_1', 'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1']
# [INFO]
# Processing: 220905_AA Analysis_SHY.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/220905_AA Analysis_SHY.xlsx using openpyxl
# [INFO] File: 220905_AA Analysis_SHY
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 34
# [INFO]   Unique Columns: 6
# [INFO]   Ignored Columns: 1
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA']
# [INFO]
# Processing: KSJ.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/KSJ.xlsx using openpyxl
# [INFO] File: KSJ
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 64
# [INFO]   Unique Columns: 30
# [INFO]   Ignored Columns: 7
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA', 'Scan_ID_1', 'ROI_ID_1', 'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1', 'Scan_ID_2']...
# [INFO]
# Processing: TA3814.xlsx
# [WARNING] Warning: Could not read SegmentProperties from /data/kjc1/projects/#999.GeoMxmeta/pooled/TA3814.xlsx
# [INFO]
# Processing: 221226_AA GeoMx_SHY.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/221226_AA GeoMx_SHY.xlsx using openpyxl
# [INFO] File: 221226_AA GeoMx_SHY
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 31
# [INFO]   Unique Columns: 3
# [INFO]   Ignored Columns: 1
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA']
# [INFO]
# Processing: GeoMx_Thuy,HY.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/GeoMx_Thuy,HY.xlsx using openpyxl
# [INFO] File: GeoMx_Thuy,HY
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 45
# [INFO]   Unique Columns: 17
# [INFO]   Ignored Columns: 1
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA']
# [INFO]
# Processing: TA3854.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/TA3854.xlsx using openpyxl
# [INFO] File: TA3854
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 30
# [INFO]   Unique Columns: 2
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: 240708_TMA_Halo_nevus_FINAL.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/240708_TMA_Halo_nevus_FINAL.xlsx using openpyxl
# [INFO] File: 240708_TMA_Halo_nevus_FINAL
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 36
# [INFO]   Unique Columns: 7
# [INFO]   Ignored Columns: 1
# [INFO]   Ignored: ['Segment Tags']
# [INFO]
# Processing: IFTA_250121_NEW_except1patient.xlsx
# [WARNING] Warning: Could not read SegmentProperties from /data/kjc1/projects/#999.GeoMxmeta/pooled/IFTA_250121_NEW_except1patient.xlsx
# [INFO]
# Processing: 250114_TCR add on_final.xlsx
# [WARNING] Warning: Could not read SegmentProperties from /data/kjc1/projects/#999.GeoMxmeta/pooled/250114_TCR add on_final.xlsx
# [INFO]
# Processing: 20210315 analysis.xlsx
# [WARNING] Warning: Could not read SegmentProperties from /data/kjc1/projects/#999.GeoMxmeta/pooled/20210315 analysis.xlsx
# [INFO]
# Processing: Lupus Nephritis2_202302224.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/Lupus Nephritis2_202302224.xlsx using openpyxl
# [INFO] File: Lupus Nephritis2_202302224
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 1
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: 20220729 Th2 Psoriasis.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/20220729 Th2 Psoriasis.xlsx using openpyxl
# [INFO] File: 20220729 Th2 Psoriasis
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 44
# [INFO]   Unique Columns: 17
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: IgAN_KMJ_BYJ_20221004.xlsx
# [ERROR] Direct reading failed for /data/kjc1/projects/#999.GeoMxmeta/pooled/IgAN_KMJ_BYJ_20221004.xlsx: invalid literal for int() with base 10: 'NaN'
# [WARNING] Warning: Could not read SegmentProperties from /data/kjc1/projects/#999.GeoMxmeta/pooled/IgAN_KMJ_BYJ_20221004.xlsx
# [INFO]
# Processing: 20220807 JSY HS analysis.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/20220807 JSY HS analysis.xlsx using openpyxl
# [INFO] File: 20220807 JSY HS analysis
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 73
# [INFO]   Unique Columns: 12
# [INFO]   Ignored Columns: 34
# [INFO]   Ignored: ['Scan_ID_6', 'Scan_ID_7', 'Scan_ID_8', 'Scan_ID_9', 'Scan_ID_10']...
# [INFO]
# Processing: IFTA_20241028.xlsx
# [WARNING] Warning: Could not read SegmentProperties from /data/kjc1/projects/#999.GeoMxmeta/pooled/IFTA_20241028.xlsx
# [INFO]
# Processing: TA3855.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/TA3855.xlsx using openpyxl
# [INFO] File: TA3855
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 30
# [INFO]   Unique Columns: 2
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: 20221207 melanoma_bk,yk final.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/20221207 melanoma_bk,yk final.xlsx using openpyxl
# [INFO] File: 20221207 melanoma_bk,yk final
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 40
# [INFO]   Unique Columns: 9
# [INFO]   Ignored Columns: 4
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA', 'Scan_ID_1', 'ROI_ID_1', 'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1']
# [INFO]
# Processing: JHK_Sebaceous carinoma.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/JHK_Sebaceous carinoma.xlsx using openpyxl
# [INFO] File: JHK_Sebaceous carinoma
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 77
# [INFO]   Unique Columns: 48
# [INFO]   Ignored Columns: 2
# [INFO]   Ignored: ['Group', 'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA']
# [INFO]
# Processing: 20221209 melanoma_macrophage.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/20221209 melanoma_macrophage.xlsx using openpyxl
# [INFO] File: 20221209 melanoma_macrophage
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 34
# [INFO]   Unique Columns: 6
# [INFO]   Ignored Columns: 1
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA']
# [INFO]
# Processing: KMJ_Crescent.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/KMJ_Crescent.xlsx using openpyxl
# [INFO] File: KMJ_Crescent
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 0
# [INFO]   Ignored Columns: 1
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA']
# [INFO]
# Processing: tnbc_ln.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/tnbc_ln.xlsx using openpyxl
# [INFO] File: tnbc_ln
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 55
# [INFO]   Unique Columns: 12
# [INFO]   Ignored Columns: 16
# [INFO]   Ignored: ['ROI_ID_3', 'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_3', 'Scan_ID_3', 'Scan_ID_4', 'ROI_ID_4']...
# [INFO]
# Processing: 20221228_psoriasis_jsp, bk.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/20221228_psoriasis_jsp, bk.xlsx using openpyxl
# [INFO] File: 20221228_psoriasis_jsp, bk
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 41
# [INFO]   Unique Columns: 7
# [INFO]   Ignored Columns: 7
# [INFO]   Ignored: ['Scan_ID_2', 'ROI_ID_2', 'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_2', 'Scan_ID_1', 'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA']...
# [INFO]
# Processing: Lupus Nephritis.xlsx
# [WARNING] Warning: Could not read SegmentProperties from /data/kjc1/projects/#999.GeoMxmeta/pooled/Lupus Nephritis.xlsx
# [INFO]
# Processing: 20230103 macrophage .xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/20230103 macrophage .xlsx using openpyxl
# [INFO] File: 20230103 macrophage
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 42
# [INFO]   Unique Columns: 11
# [INFO]   Ignored Columns: 4
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA', 'Scan_ID_1', 'ROI_ID_1', 'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1']
# [INFO]
# Processing: JSY WTA.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/JSY WTA.xlsx using openpyxl
# [INFO] File: JSY WTA
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 30
# [INFO]   Unique Columns: 2
# [INFO]   Ignored Columns: 1
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA']
# [INFO]
# Processing: placenta_KHW.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/placenta_KHW.xlsx using openpyxl
# [INFO] File: placenta_KHW
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 36
# [INFO]   Unique Columns: 6
# [INFO]   Ignored Columns: 2
# [INFO]   Ignored: ['ROI_ID_1', 'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1_1']
# [INFO]
# Processing: 20230512 Brain preliminary 2.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/20230512 Brain preliminary 2.xlsx using openpyxl
# [INFO] File: 20230512 Brain preliminary 2
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 33
# [INFO]   Unique Columns: 3
# [INFO]   Ignored Columns: 3
# [INFO]   Ignored: ['Scan_ID_1', 'ROI_ID_1', 'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1']
# [INFO]
# Processing: CRC.xlsx
# [WARNING] Warning: Could not read SegmentProperties from /data/kjc1/projects/#999.GeoMxmeta/pooled/CRC.xlsx
# [INFO]
# Processing: MuOPKidney.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/MuOPKidney.xlsx using openpyxl
# [INFO] File: MuOPKidney
# [INFO]   Data Type: MOUSE
# [INFO]   Total Columns: 33
# [INFO]   Unique Columns: 5
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: 20230515 brain original rna probe.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/20230515 brain original rna probe.xlsx using openpyxl
# [INFO] File: 20230515 brain original rna probe
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 1
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: Pancreatic Cancer 2.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/Pancreatic Cancer 2.xlsx using openpyxl
# [INFO] File: Pancreatic Cancer 2
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 74
# [INFO]   Unique Columns: 19
# [INFO]   Ignored Columns: 27
# [INFO]   Ignored: ['ROI_ID_5', 'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1_5', 'Scan_ID_6', 'ROI_ID_6', 'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1_6']...
# [INFO]
# Processing: 20230609_GI_2.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/20230609_GI_2.xlsx using openpyxl
# [INFO] File: 20230609_GI_2
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 0
# [INFO]   Ignored Columns: 1
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA']
# [INFO]
# Processing: Marmoset_EAE_ODS.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/Marmoset_EAE_ODS.xlsx using openpyxl
# [INFO] File: Marmoset_EAE_ODS
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 43
# [INFO]   Unique Columns: 11
# [INFO]   Ignored Columns: 4
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1_2', 'ROI_ID_1', 'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1_1', 'ROI_ID_2']
# [INFO]
# Processing: 20230615_LE_Rosa_1st.xlsx
# [WARNING] Warning: Could not read SegmentProperties from /data/kjc1/projects/#999.GeoMxmeta/pooled/20230615_LE_Rosa_1st.xlsx
# [INFO]
# Processing: MN_D1.E3.X1.C4.C3.C2.D4.xlsx
# [WARNING] Warning: Could not read SegmentProperties from /data/kjc1/projects/#999.GeoMxmeta/pooled/MN_D1.E3.X1.C4.C3.C2.D4.xlsx
# [INFO]
# Processing: 20230703_GI_control.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/20230703_GI_control.xlsx using openpyxl
# [INFO] File: 20230703_GI_control
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 0
# [INFO]   Ignored Columns: 1
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA']
# [INFO]
# Processing: MN_D1.E3.X1.C4.C3.C2.D4_.xlsx
# [WARNING] Warning: Could not read SegmentProperties from /data/kjc1/projects/#999.GeoMxmeta/pooled/MN_D1.E3.X1.C4.C3.C2.D4_.xlsx
# [INFO]
# Processing: 20240214_Brain_PD.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/20240214_Brain_PD.xlsx using openpyxl
# [INFO] File: 20240214_Brain_PD
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 0
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: MN_D1.E3.X1.C4.C3.C2.D4__.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/MN_D1.E3.X1.C4.C3.C2.D4__.xlsx using openpyxl
# [INFO] File: MN_D1.E3.X1.C4.C3.C2.D4__
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 0
# [INFO]   Ignored Columns: 1
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA']
# [INFO]
# Processing: 20240723 PV_ChoiSeoyoung_GeoMx.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/20240723 PV_ChoiSeoyoung_GeoMx.xlsx using openpyxl
# [INFO] File: 20240723 PV_ChoiSeoyoung_GeoMx
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 0
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: Breast_Cancer_KHW.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/Breast_Cancer_KHW.xlsx using openpyxl
# [INFO] File: Breast_Cancer_KHW
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 30
# [INFO]   Unique Columns: 2
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: Dermatomyositis.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/Dermatomyositis.xlsx using openpyxl
# [INFO] File: Dermatomyositis
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 37
# [INFO]   Unique Columns: 9
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: Placenta_GeoMx.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/Placenta_GeoMx.xlsx using openpyxl
# [INFO] File: Placenta_GeoMx
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 49
# [INFO]   Unique Columns: 21
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: BC_stage_240607.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/BC_stage_240607.xlsx using openpyxl
# [INFO] File: BC_stage_240607
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 167
# [INFO]   Unique Columns: 49
# [INFO]   Ignored Columns: 90
# [INFO]   Ignored: ['Scan_ID_1', 'ROI_ID_1', 'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1_1', 'Scan_ID_2', 'ROI_ID_2']...
# [INFO]
# Processing: SMC0408.xlsx
# [WARNING] Warning: Could not read SegmentProperties from /data/kjc1/projects/#999.GeoMxmeta/pooled/SMC0408.xlsx
# [INFO]
# Processing: 20240910 Steatosis WTA_BYJ.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/20240910 Steatosis WTA_BYJ.xlsx using openpyxl
# [INFO] File: 20240910 Steatosis WTA_BYJ
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 37
# [INFO]   Unique Columns: 9
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: MN_X3.B4.C1.X2.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/MN_X3.B4.C1.X2.xlsx using openpyxl
# [INFO] File: MN_X3.B4.C1.X2
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 0
# [INFO]   Ignored Columns: 1
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA']
# [INFO]
# Processing: bk melanoma.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/bk melanoma.xlsx using openpyxl
# [INFO] File: bk melanoma
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 88
# [INFO]   Unique Columns: 9
# [INFO]   Ignored Columns: 52
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA', 'Scan_ID_1', 'ROI_ID_1', 'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1', 'Scan_ID_2']...
# [INFO]
# Processing: Keloid GeoMx.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/Keloid GeoMx.xlsx using openpyxl
# [INFO] File: Keloid GeoMx
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 42
# [INFO]   Unique Columns: 14
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: yu.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/yu.xlsx using openpyxl
# [INFO] File: yu
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 32
# [INFO]   Unique Columns: 4
# [INFO]   Ignored Columns: 1
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA']
# [INFO]
# Processing: BK_colon cancer.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/BK_colon cancer.xlsx using openpyxl
# [INFO] File: BK_colon cancer
# [INFO]   Data Type: CTA
# [INFO]   Total Columns: 29
# [INFO]   Unique Columns: 0
# [INFO]   Ignored Columns: 1
# [INFO]   Ignored: ['w/o tumor']
# [INFO]
# Processing: MT analysis_20220920.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/MT analysis_20220920.xlsx using openpyxl
# [INFO] File: MT analysis_20220920
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 30
# [INFO]   Unique Columns: 2
# [INFO]   Ignored Columns: 1
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA']
# [INFO]
# Processing: Bladder_Cancer_Final.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/Bladder_Cancer_Final.xlsx using openpyxl
# [INFO] File: Bladder_Cancer_Final
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 69
# [INFO]   Unique Columns: 26
# [INFO]   Ignored Columns: 16
# [INFO]   Ignored: ['Scan_ID_4', 'ROI_ID_4', 'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_4', 'Scan_ID_5', 'ROI_ID_5']...
# [INFO]
# Processing: Bladder_Cancer_20230913.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/Bladder_Cancer_20230913.xlsx using openpyxl
# [INFO] File: Bladder_Cancer_20230913
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 45
# [INFO]   Unique Columns: 11
# [INFO]   Ignored Columns: 7
# [INFO]   Ignored: ['Scan_ID_1', 'ROI_ID_1', 'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1', 'Scan_ID_2', 'ROI_ID_2']...
# [INFO]
# Processing: BYC_Thymus_B cell_2021.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/BYC_Thymus_B cell_2021.xlsx using openpyxl
# [INFO] File: BYC_Thymus_B cell_2021
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 34
# [INFO]   Unique Columns: 5
# [INFO]   Ignored Columns: 1
# [INFO]   Ignored: ['Segment Tags']
# [INFO]
# Processing: Keloid_LYI_2mm_20240528.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/Keloid_LYI_2mm_20240528.xlsx using openpyxl
# [INFO] File: Keloid_LYI_2mm_20240528
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 37
# [INFO]   Unique Columns: 9
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: BSB_Dermatomyositis.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/BSB_Dermatomyositis.xlsx using openpyxl
# [INFO] File: BSB_Dermatomyositis
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 37
# [INFO]   Unique Columns: 6
# [INFO]   Ignored Columns: 3
# [INFO]   Ignored: ['Scan_ID_1', 'ROI_ID_1', 'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1_1']
# [INFO]
# Processing: NC_20231011.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/NC_20231011.xlsx using openpyxl
# [INFO] File: NC_20231011
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 0
# [INFO]   Ignored Columns: 1
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA']
# [INFO]
# Processing: bullous real data.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/bullous real data.xlsx using openpyxl
# [INFO] File: bullous real data
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 45
# [INFO]   Unique Columns: 16
# [INFO]   Ignored Columns: 2
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA', 'ROI_ID_1']
# [INFO]
# Processing: EoD_analysis_yjbaik.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/EoD_analysis_yjbaik.xlsx using openpyxl
# [INFO] File: EoD_analysis_yjbaik
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 48
# [INFO]   Unique Columns: 20
# [INFO]   Ignored Columns: 1
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA']
# [INFO]
# Processing: HCC_7_10_Final.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/HCC_7_10_Final.xlsx using openpyxl
# [INFO] File: HCC_7_10_Final
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 29
# [INFO]   Unique Columns: 1
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: H Chung_Thymus #1_240921.xlsx
# [WARNING] Warning: Could not read SegmentProperties from /data/kjc1/projects/#999.GeoMxmeta/pooled/H Chung_Thymus #1_240921.xlsx
# [INFO]
# Processing: HCC_VETC_HSH.xlsx
# [WARNING] Warning: Could not read SegmentProperties from /data/kjc1/projects/#999.GeoMxmeta/pooled/HCC_VETC_HSH.xlsx
# [INFO]
# Processing: IgAN_TPL_20240329.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/IgAN_TPL_20240329.xlsx using openpyxl
# [INFO] File: IgAN_TPL_20240329
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 28
# [INFO]   Unique Columns: 0
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: HCC_NTvsTC_48_KDJ_real.xlsx
# [WARNING] Warning: Could not read SegmentProperties from /data/kjc1/projects/#999.GeoMxmeta/pooled/HCC_NTvsTC_48_KDJ_real.xlsx
# [INFO]
# Processing: HCC_NT_vs_TC_48_KMJ.xlsx
# [WARNING] Warning: Could not read SegmentProperties from /data/kjc1/projects/#999.GeoMxmeta/pooled/HCC_NT_vs_TC_48_KMJ.xlsx
# [INFO]
# Processing: HS_LYI_20240411.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/HS_LYI_20240411.xlsx using openpyxl
# [INFO] File: HS_LYI_20240411
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 30
# [INFO]   Unique Columns: 2
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: mouse_nasal_polyp....xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/mouse_nasal_polyp....xlsx using openpyxl
# [INFO] File: mouse_nasal_polyp...
# [INFO]   Data Type: MOUSE
# [INFO]   Total Columns: 29
# [INFO]   Unique Columns: 0
# [INFO]   Ignored Columns: 1
# [INFO]   Ignored: ['Segment 1']
# [INFO]
# Processing: HCC_TMA_KMS.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/HCC_TMA_KMS.xlsx using openpyxl
# [INFO] File: HCC_TMA_KMS
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 30
# [INFO]   Unique Columns: 2
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: HS_LYI_2023922.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/HS_LYI_2023922.xlsx using openpyxl
# [INFO] File: HS_LYI_2023922
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 48
# [INFO]   Unique Columns: 14
# [INFO]   Ignored Columns: 7
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA', 'Scan_ID_1', 'ROI_ID_1', 'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1', 'Scan_ID_2']...
# [INFO]
# Processing: RCC_56+28AOI.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/RCC_56+28AOI.xlsx using openpyxl
# [INFO] File: RCC_56+28AOI
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 35
# [INFO]   Unique Columns: 7
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: Pancreatic Cancer_HSH_231218.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/Pancreatic Cancer_HSH_231218.xlsx using openpyxl
# [INFO] File: Pancreatic Cancer_HSH_231218
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 39
# [INFO]   Unique Columns: 6
# [INFO]   Ignored Columns: 5
# [INFO]   Ignored: ['Scan_ID_1', 'ROI_ID_1', 'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1_1', 'Scan_ID_2', 'ROI_ID_2']
# [INFO]
# Processing: Preliminary MSA Brain 2023.03.22.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/Preliminary MSA Brain 2023.03.22.xlsx using openpyxl
# [INFO] File: Preliminary MSA Brain 2023.03.22
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 1787
# [INFO]   Unique Columns: 34
# [INFO]   Ignored Columns: 1726
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA', 'Scan_ID_1', 'ROI_ID_1', 'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1', 'Scan_ID_2']...
# [INFO]
# Processing: Preliminary230404_GI.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/Preliminary230404_GI.xlsx using openpyxl
# [INFO] File: Preliminary230404_GI
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 79
# [INFO]   Unique Columns: 30
# [INFO]   Ignored Columns: 22
# [INFO]   Ignored: ['LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA', 'Scan_ID_1', 'ROI_ID_1', 'LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1', 'Scan_ID_2']...
# [INFO]
# Processing: SCC GeoMx.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/SCC GeoMx.xlsx using openpyxl
# [INFO] File: SCC GeoMx
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 39
# [INFO]   Unique Columns: 11
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: SJ_HY geomx Thymus.xlsx
# [WARNING] Warning: Could not read SegmentProperties from /data/kjc1/projects/#999.GeoMxmeta/pooled/SJ_HY geomx Thymus.xlsx
# [INFO]
# Processing: SDR_Hu_HT.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/SDR_Hu_HT.xlsx using openpyxl
# [INFO] File: SDR_Hu_HT
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 30
# [INFO]   Unique Columns: 2
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: steatosis cta.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/steatosis cta.xlsx using openpyxl
# [INFO] File: steatosis cta
# [INFO]   Data Type: CTA
# [INFO]   Total Columns: 31
# [INFO]   Unique Columns: 3
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: syringoma re.xlsx
# [WARNING] Warning: Could not read SegmentProperties from /data/kjc1/projects/#999.GeoMxmeta/pooled/syringoma re.xlsx
# [INFO]
# Processing: thymus normal.xlsx
# [WARNING] Warning: Could not read SegmentProperties from /data/kjc1/projects/#999.GeoMxmeta/pooled/thymus normal.xlsx
# [INFO]
# Processing: thymus240401.xlsx
# [WARNING] Warning: Could not read SegmentProperties from /data/kjc1/projects/#999.GeoMxmeta/pooled/thymus240401.xlsx
# [INFO]
# Processing: Total(Ubiased clustering_DRESS123).xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/Total(Ubiased clustering_DRESS123).xlsx using openpyxl
# [INFO] File: Total(Ubiased clustering_DRESS123)
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 52
# [INFO]   Unique Columns: 24
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: TOF_geomx_analysis.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/TOF_geomx_analysis.xlsx using openpyxl
# [INFO] File: TOF_geomx_analysis
# [INFO]   Data Type: WTA
# [INFO]   Total Columns: 31
# [INFO]   Unique Columns: 3
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: Wound_GeoMx.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/Wound_GeoMx.xlsx using openpyxl
# [INFO] File: Wound_GeoMx
# [INFO]   Data Type: MOUSE
# [INFO]   Total Columns: 110
# [INFO]   Unique Columns: 82
# [INFO]   Ignored Columns: 0
# [INFO]
# Processing: Wound_KHW.xlsx
# [INFO] Successfully read /data/kjc1/projects/#999.GeoMxmeta/pooled/Wound_KHW.xlsx using openpyxl
# [INFO] File: Wound_KHW
# [INFO]   Data Type: MOUSE
# [INFO]   Total Columns: 32
# [INFO]   Unique Columns: 4
# [INFO]   Ignored Columns: 0
# [WARNING]
# 28 files had issues:
# [WARNING]   - DKD_20240125.xlsx
# [WARNING]   - t4p.xlsx
# [WARNING]   - Keloid_LYI_4mm_20240528.xlsx
# [WARNING]   - (empty)BK melanoma.xlsx
# [WARNING]   - CRC(2).xlsx
# [WARNING]   - (not aligned)20221207 bk,yk melanoma.xlsx
# [WARNING]   - Final Thymus normal.xlsx
# [WARNING]   - 0408-2.xlsx
# [WARNING]   - TA3814.xlsx
# [WARNING]   - IFTA_250121_NEW_except1patient.xlsx
# [WARNING]   - 250114_TCR add on_final.xlsx
# [WARNING]   - 20210315 analysis.xlsx
# [WARNING]   - IgAN_KMJ_BYJ_20221004.xlsx
# [WARNING]   - IFTA_20241028.xlsx
# [WARNING]   - Lupus Nephritis.xlsx
# [WARNING]   - CRC.xlsx
# [WARNING]   - 20230615_LE_Rosa_1st.xlsx
# [WARNING]   - MN_D1.E3.X1.C4.C3.C2.D4.xlsx
# [WARNING]   - MN_D1.E3.X1.C4.C3.C2.D4_.xlsx
# [WARNING]   - SMC0408.xlsx
# [WARNING]   - H Chung_Thymus #1_240921.xlsx
# [WARNING]   - HCC_VETC_HSH.xlsx
# [WARNING]   - HCC_NTvsTC_48_KDJ_real.xlsx
# [WARNING]   - HCC_NT_vs_TC_48_KMJ.xlsx
# [WARNING]   - SJ_HY geomx Thymus.xlsx
# [WARNING]   - syringoma re.xlsx
# [WARNING]   - thymus normal.xlsx
# [WARNING]   - thymus240401.xlsx
# Traceback (most recent call last):
#   File "/data/kjc1/mylit/ipynb/geomx_processor_v2.py", line 653, in <module>
#     main()
#   File "/data/kjc1/mylit/ipynb/geomx_processor_v2.py", line 643, in main
#     processor.apply_mappings_and_merge(args.mapping_file, args.output)
#   File "/data/kjc1/mylit/ipynb/geomx_processor_v2.py", line 460, in apply_mappings_and_merge
#     merged_metadata = pd.concat(merged_dfs, ignore_index=True, sort=False)
#   File "/home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/pandas/core/reshape/concat.py", line 395, in concat
#     return op.get_result()
#   File "/home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/pandas/core/reshape/concat.py", line 680, in get_result
#     indexers[ax] = obj_labels.get_indexer(new_labels)
#   File "/home/jaecheon/miniconda3/envs/scenvi/lib/python3.10/site-packages/pandas/core/indexes/base.py", line 3885, in get_indexer
#     raise InvalidIndexError(self._requires_unique_msg)
# pandas.errors.InvalidIndexError: Reindexing only valid with uniquely valued Index objects
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 get_ipython().run_cell_magic('bash', '', '# 4. Metadata 통합\nxlsx_folder="/data/kjc1/projects/#999.GeoMxmeta/pooled/"\npython geomx_processor_v2.py merge $xlsx_folder ./output/column_mapping_template.csv -o ./output\n')
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2478, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2476 with self.builtin_trap:
#    2477     args = (magic_arg_s, cell)
# -> 2478     result = fn(*args, **kwargs)
#    2480 # The code below prevents the output from being displayed
#    2481 # when using magics with decodator @output_can_be_silenced
#    2482 # when the last Python token in the expression is a ';'.
#    2483 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/magics/script.py:153, in ScriptMagics._make_script_magic.<locals>.named_script_magic(line, cell)
#     151 else:
#     152     line = script
# --> 153 return self.shebang(line, cell)
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/magics/script.py:305, in ScriptMagics.shebang(self, line, cell)
#     300 if args.raise_error and p.returncode != 0:
#     301     # If we get here and p.returncode is still None, we must have
#     302     # killed it but not yet seen its return code. We don't wait for it,
#     303     # in case it's stuck in uninterruptible sleep. -9 = SIGKILL
#     304     rc = p.returncode or -9
# --> 305     raise CalledProcessError(rc, cell)
#
# CalledProcessError: Command 'b'# 4. Metadata \xed\x86\xb5\xed\x95\xa9\nxlsx_folder="/data/kjc1/projects/#999.GeoMxmeta/pooled/"\npython geomx_processor_v2.py merge $xlsx_folder ./output/column_mapping_template.csv -o ./output\n'' returned non-zero exit status 1.

# %% [markdown]
# ### ver2. jupyter 실행용

# %%
"""
GeomX Data Processor - Jupyter Notebook 버전
직접 함수를 호출하여 사용할 수 있는 버전
"""

import pandas as pd
import numpy as np
import re
from pathlib import Path
from typing import Dict, List, Optional
import json

# 무시할 column 패턴들
IGNORE_PATTERNS = [
    r'LOT_.*_RNA_\d+$',
    r'Scan_ID_\d+$', 
    r'ROI_ID_\d+$',
    r'^\d+$'
]

def quick_analyze(xlsx_folder: str, output_folder: str = './output'):
    """
    빠른 분석 및 매핑 템플릿 생성
    
    사용 예시:
    >>> quick_analyze('/data/kjc1/projects/#999.GeoMxmeta/pooled/')
    """
    from pathlib import Path
    import warnings
    warnings.filterwarnings('ignore')
    
    # 출력 폴더 생성
    Path(output_folder).mkdir(exist_ok=True)
    
    # xlsx 파일 찾기
    xlsx_files = list(Path(xlsx_folder).glob("*.xlsx"))
    print(f"Found {len(xlsx_files)} xlsx files")
    
    all_unique_cols = []
    problematic_files = []
    
    for file_path in xlsx_files:
        print(f"\nProcessing: {file_path.name}")
        
        try:
            # SegmentProperties 시트 읽기
            df = read_segment_properties_safe(str(file_path))
            
            if df is None:
                problematic_files.append(file_path.name)
                continue
            
            # 고유 column 찾기
            unique_cols = find_meaningful_columns(df)
            
            # 분석 결과 저장
            for col in unique_cols:
                unique_values = df[col].dropna().unique()[:10]
                all_unique_cols.append({
                    'file': file_path.stem,
                    'column': col,
                    'dtype': infer_dtype(df[col]),
                    'samples': ', '.join(map(str, unique_values)),
                    'count': len(df[col].dropna().unique())
                })
                
        except Exception as e:
            print(f"  Error: {str(e)}")
            problematic_files.append(file_path.name)
    
    # 결과 저장
    if all_unique_cols:
        df_result = pd.DataFrame(all_unique_cols)
        
        # 분석 결과 저장
        analysis_file = Path(output_folder) / 'unique_columns_analysis.csv'
        df_result.to_csv(analysis_file, index=False)
        print(f"\nSaved analysis to {analysis_file}")
        
        # 매핑 템플릿 생성
        template = create_mapping_template(df_result)
        template_file = Path(output_folder) / 'column_mapping_template.csv'
        template.to_csv(template_file, index=False)
        print(f"Saved template to {template_file}")
        
        # 요약 출력
        print("\n=== Summary ===")
        print(f"Total unique columns: {df_result['column'].nunique()}")
        print(f"Total files processed: {len(xlsx_files) - len(problematic_files)}")
        
        if problematic_files:
            print(f"\nProblematic files ({len(problematic_files)}):")
            for f in problematic_files[:5]:
                print(f"  - {f}")
            if len(problematic_files) > 5:
                print(f"  ... and {len(problematic_files)-5} more")
    else:
        print("No unique columns found!")
    
    return df_result if all_unique_cols else None


def read_segment_properties_safe(file_path: str) -> Optional[pd.DataFrame]:
    """손상된 xlsx 파일도 안전하게 읽기"""
    import warnings
    warnings.filterwarnings('ignore')
    
    # 여러 방법 시도
    methods = [
        lambda: pd.read_excel(file_path, sheet_name='SegmentProperties', engine='openpyxl'),
        lambda: pd.read_excel(file_path, sheet_name=0, engine='openpyxl'),  # 첫 번째 시트
        lambda: pd.read_excel(file_path, sheet_name='SegmentProperties'),  # 기본 엔진
    ]
    
    for method in methods:
        try:
            df = method()
            
            # 데이터 정리
            if df is not None and not df.empty:
                # NaN column 제거
                df = df.loc[:, df.columns.notna()]
                
                # 숫자 column 이름 정리
                new_cols = []
                for col in df.columns:
                    if isinstance(col, (int, float)):
                        new_cols.append(f"Column_{int(col)}")
                    else:
                        new_cols.append(str(col))
                df.columns = new_cols
                
                return df
        except:
            continue
    
    # 마지막 시도: openpyxl 직접 사용
    try:
        import openpyxl
        wb = openpyxl.load_workbook(file_path, data_only=True, read_only=True)
        
        # 시트 찾기
        sheet_name = None
        for name in wb.sheetnames:
            if 'SegmentProperties' in name or name == wb.sheetnames[0]:
                sheet_name = name
                break
        
        if sheet_name:
            ws = wb[sheet_name]
            data = list(ws.values)
            if data:
                df = pd.DataFrame(data[1:], columns=data[0])
                wb.close()
                return df
        wb.close()
    except:
        pass
    
    return None


def find_meaningful_columns(df: pd.DataFrame) -> List[str]:
    """의미있는 고유 column만 찾기"""
    # 공통 column 패턴
    common_patterns = [
        'SlideName', 'ScanLabel', 'ROILabel', 'SegmentLabel', 'SegmentDisplayName',
        'Origin', 'QCFlags', 'AOISurfaceArea', 'AOINucleiCount',
        'Coordinate', 'Reads', 'Sequencing', 'UMIQ30', 'RTSQ30',
        'GeoMxNgsPipelineVersion', 'ROIID', 'SegmentID',
        'ScanWidth', 'ScanHeight', 'ScanOffset'
    ]
    
    meaningful_cols = []
    
    for col in df.columns:
        if not col:
            continue
            
        col_str = str(col)
        
        # 공통 column인지 확인
        is_common = any(pattern in col_str for pattern in common_patterns)
        if is_common:
            continue
        
        # 무시할 패턴인지 확인
        should_ignore = any(re.match(pattern, col_str) for pattern in IGNORE_PATTERNS)
        if should_ignore:
            continue
        
        # 의미없는 column인지 확인 (모든 값이 같거나, 90% 이상 고유)
        non_null = df[col].dropna()
        if len(non_null) == 0:
            continue
        
        unique_ratio = len(non_null.unique()) / len(non_null)
        if unique_ratio == 1.0 or unique_ratio > 0.9:
            continue
            
        # NULL이 90% 이상인 경우
        if len(non_null) < len(df) * 0.1:
            continue
        
        meaningful_cols.append(col)
    
    return meaningful_cols


def infer_dtype(series: pd.Series) -> str:
    """데이터 타입 추론"""
    non_null = series.dropna()
    if len(non_null) == 0:
        return 'Empty'
    
    # Boolean
    unique_lower = set(str(v).lower() for v in non_null.unique())
    if unique_lower.issubset({'true', 'false', 'yes', 'no', '1', '0'}):
        return 'Boolean'
    
    # Numeric
    try:
        pd.to_numeric(non_null)
        return 'Numeric'
    except:
        pass
    
    # Category (고유값 < 10%)
    if len(non_null.unique()) < len(non_null) * 0.1:
        return 'Category'
    
    return 'String'


def create_mapping_template(df_analysis: pd.DataFrame) -> pd.DataFrame:
    """매핑 템플릿 생성"""
    template = []
    
    for col_name in df_analysis['column'].unique():
        col_data = df_analysis[df_analysis['column'] == col_name]
        
        # 샘플 값 수집
        all_samples = []
        for samples_str in col_data['samples']:
            if samples_str:
                all_samples.extend(str(samples_str).split(', ')[:5])
        
        # 유사한 column 이름 추천 (예: PanCK+, Panck, PANCK → PanCK)
        suggested_name = suggest_unified_name(col_name)
        
        template.append({
            'original_column': col_name,
            'unified_name': suggested_name,
            'appears_in': ', '.join(col_data['file'].unique()[:5]),
            'sample_values': ', '.join(list(set(all_samples))[:10]),
            'value_mapping': '',
            'notes': ''
        })
    
    return pd.DataFrame(template)


def suggest_unified_name(col_name: str) -> str:
    """통일된 column 이름 제안"""
    # 일반적인 패턴들
    patterns = {
        r'(?i)panck?\+?': 'PanCK',
        r'(?i)cd45\+?': 'CD45', 
        r'(?i)ck\+?': 'CK',
        r'(?i)segment[\s_]?(\d+)': r'Segment_\1',
        r'(?i)tumor': 'Tumor',
        r'(?i)stage': 'Stage',
        r'(?i)treatment': 'Treatment'
    }
    
    for pattern, replacement in patterns.items():
        if re.search(pattern, col_name):
            return re.sub(pattern, replacement, col_name, flags=re.IGNORECASE)
    
    return col_name


# Jupyter에서 직접 실행 예시
def demo():
    """
    데모 실행
    Jupyter cell에서:
    >>> from geomx_jupyter import demo
    >>> demo()
    """
    print("GeomX Data Processor - Jupyter Version")
    print("=" * 50)
    print("\n사용 방법:")
    print("1. quick_analyze('/path/to/xlsx/folder/')")
    print("2. 생성된 column_mapping_template.csv 편집")
    print("3. 필요시 merge 및 match 기능 사용")
    print("\n예시:")
    print(">>> result = quick_analyze('/data/kjc1/projects/#999.GeoMxmeta/pooled/')")
    print(">>> result.head()")


if __name__ == "__main__":
    # 직접 실행 시
    import sys
    if len(sys.argv) > 1:
        quick_analyze(sys.argv[1])
    else:
        demo()

# %%
# geomx_jupyter.py 파일 import
from geomx_jupyter import quick_analyze

# 한 줄로 실행
result = quick_analyze('/data/kjc1/projects/#999.GeoMxmeta/pooled/')

# 결과 확인
result.head()

# %% [markdown]
# 수동 복구

# %%
# %%bash
# # Excel에서 복구 후 다시 저장하거나
# # LibreOffice 사용
# libreoffice --headless --convert-to xlsx:"Calc MS Excel 2007 XML" damaged_file.xlsx

# %% [markdown]
# 수동 복구 - 자동화 (작동은 하는데 복구 제대로 안됨) -> 그냥 손으로 해야할듯.

# %%
# %%bash
# set -euo pipefail
#
# LIST="/data/kjc1/mylit/ipynb/output/problematic_files.txt"
# OUTDIR="/data/kjc1/mylit/ipynb/output/fixed"
# mkdir -p "$OUTDIR"
#
# # libreoffice(또는 soffice) 선택
# CONVERT="libreoffice"
# command -v libreoffice >/dev/null 2>&1 || CONVERT="soffice"
# echo "[info] using converter: $CONVERT"
#
# # 깨끗한 임시 사용자 프로필 (LO 헤드리스 안정화)
# PROFILE_DIR="$(mktemp -d -p /tmp lo-prof-XXXXXX)"
# PROFILE_URL="file://$PROFILE_DIR"
# echo "[info] using LO profile: $PROFILE_URL"
#
# # outdir 쓰기 테스트
# touch "$OUTDIR/.write_test" && rm -f "$OUTDIR/.write_test" || {
#   echo "❌ OUTDIR에 쓰기 권한이 없습니다: $OUTDIR" >&2; exit 1; }
#
# while IFS= read -r path; do
#   # 헤더/빈줄/주석/비xlsx 스킵
#   [[ -z "$path" ]] && continue
#   [[ "$path" == Files\ with\ reading\ issues:* ]] && continue
#   [[ "$path" =~ ^# ]] && continue
#   [[ "${path,,}" != *.xlsx ]] && continue
#
#   if [[ ! -f "$path" ]]; then
#     echo "[skip] not a file: $path" >&2
#     continue
#   fi
#
#   base="$(basename "$path")"
#   out_xlsx="$OUTDIR/$base"
#   echo "[RUN] $path"
#
#   # A) 자동 필터
#   if "$CONVERT" --headless --nologo --nodefault --norestore --nolockcheck \
#       -env:UserInstallation="$PROFILE_URL" \
#       --convert-to xlsx --outdir "$OUTDIR" "$path"; then
#     echo "[OK] auto-filter -> $out_xlsx"; continue
#   fi
#
#   # B) 명시 필터
#   if "$CONVERT" --headless --nologo --nodefault --norestore --nolockcheck \
#       -env:UserInstallation="$PROFILE_URL" \
#       --convert-to 'xlsx:"Calc MS Excel 2007 XML"' \
#       --outdir "$OUTDIR" "$path"; then
#     echo "[OK] explicit-filter -> $out_xlsx"; continue
#   fi
#
#   # C) ODS로 우회 후 XLSX 재저장
#   tmp_ods="$OUTDIR/${base%.xlsx}.ods"
#   if "$CONVERT" --headless --nologo --nodefault --norestore --nolockcheck \
#       -env:UserInstallation="$PROFILE_URL" \
#       --convert-to ods --outdir "$OUTDIR" "$path"; then
#     echo "[OK] to ODS -> $tmp_ods"
#     if "$CONVERT" --headless --nologo --nodefault --norestore --nolockcheck \
#         -env:UserInstallation="$PROFILE_URL" \
#         --convert-to xlsx --outdir "$OUTDIR" "$tmp_ods"; then
#       echo "[OK] ODS -> XLSX -> $out_xlsx"
#       rm -f "$tmp_ods" || true
#       continue
#     fi
#   fi
#
#   echo "❌ FAIL: $path" >&2
# done < "$LIST"
#
# echo "Done. Output -> $OUTDIR"
# Out:
# [info] using converter: libreoffice
# [info] using LO profile: file:///tmp/lo-prof-z5djbq
# [RUN] /data/kjc1/projects/#999.GeoMxmeta/pooled/DKD_20240125.xlsx
# Warning: failed to launch javaldx - java may not function correctly
# convert /data/kjc1/projects/#999.GeoMxmeta/pooled/DKD_20240125.xlsx -> /data/kjc1/mylit/ipynb/output/fixed/DKD_20240125.xlsx using filter : Calc Office Open XML
# [OK] auto-filter -> /data/kjc1/mylit/ipynb/output/fixed/DKD_20240125.xlsx
# [RUN] /data/kjc1/projects/#999.GeoMxmeta/pooled/t4p.xlsx
# Warning: failed to launch javaldx - java may not function correctly
# convert /data/kjc1/projects/#999.GeoMxmeta/pooled/t4p.xlsx -> /data/kjc1/mylit/ipynb/output/fixed/t4p.xlsx using filter : Calc Office Open XML
# [OK] auto-filter -> /data/kjc1/mylit/ipynb/output/fixed/t4p.xlsx
# [RUN] /data/kjc1/projects/#999.GeoMxmeta/pooled/Keloid_LYI_4mm_20240528.xlsx
# Warning: failed to launch javaldx - java may not function correctly
# convert /data/kjc1/projects/#999.GeoMxmeta/pooled/Keloid_LYI_4mm_20240528.xlsx -> /data/kjc1/mylit/ipynb/output/fixed/Keloid_LYI_4mm_20240528.xlsx using filter : Calc Office Open XML
# [OK] auto-filter -> /data/kjc1/mylit/ipynb/output/fixed/Keloid_LYI_4mm_20240528.xlsx
# [RUN] /data/kjc1/projects/#999.GeoMxmeta/pooled/(empty)BK melanoma.xlsx
# Warning: failed to launch javaldx - java may not function correctly
# convert /data/kjc1/projects/#999.GeoMxmeta/pooled/(empty)BK melanoma.xlsx -> /data/kjc1/mylit/ipynb/output/fixed/(empty)BK melanoma.xlsx using filter : Calc Office Open XML
# [OK] auto-filter -> /data/kjc1/mylit/ipynb/output/fixed/(empty)BK melanoma.xlsx
# [RUN] /data/kjc1/projects/#999.GeoMxmeta/pooled/CRC(2).xlsx
# Warning: failed to launch javaldx - java may not function correctly
# convert /data/kjc1/projects/#999.GeoMxmeta/pooled/CRC(2).xlsx -> /data/kjc1/mylit/ipynb/output/fixed/CRC(2).xlsx using filter : Calc Office Open XML
# [OK] auto-filter -> /data/kjc1/mylit/ipynb/output/fixed/CRC(2).xlsx
# [RUN] /data/kjc1/projects/#999.GeoMxmeta/pooled/(not aligned)20221207 bk,yk melanoma.xlsx
# Warning: failed to launch javaldx - java may not function correctly
# convert /data/kjc1/projects/#999.GeoMxmeta/pooled/(not aligned)20221207 bk,yk melanoma.xlsx -> /data/kjc1/mylit/ipynb/output/fixed/(not aligned)20221207 bk,yk melanoma.xlsx using filter : Calc Office Open XML
# [OK] auto-filter -> /data/kjc1/mylit/ipynb/output/fixed/(not aligned)20221207 bk,yk melanoma.xlsx
# [RUN] /data/kjc1/projects/#999.GeoMxmeta/pooled/Final Thymus normal.xlsx
# Warning: failed to launch javaldx - java may not function correctly
# convert /data/kjc1/projects/#999.GeoMxmeta/pooled/Final Thymus normal.xlsx -> /data/kjc1/mylit/ipynb/output/fixed/Final Thymus normal.xlsx using filter : Calc Office Open XML
# [OK] auto-filter -> /data/kjc1/mylit/ipynb/output/fixed/Final Thymus normal.xlsx
# [RUN] /data/kjc1/projects/#999.GeoMxmeta/pooled/0408-2.xlsx
# Warning: failed to launch javaldx - java may not function correctly
# convert /data/kjc1/projects/#999.GeoMxmeta/pooled/0408-2.xlsx -> /data/kjc1/mylit/ipynb/output/fixed/0408-2.xlsx using filter : Calc Office Open XML
# [OK] auto-filter -> /data/kjc1/mylit/ipynb/output/fixed/0408-2.xlsx
# [RUN] /data/kjc1/projects/#999.GeoMxmeta/pooled/TA3814.xlsx
# Warning: failed to launch javaldx - java may not function correctly
# convert /data/kjc1/projects/#999.GeoMxmeta/pooled/TA3814.xlsx -> /data/kjc1/mylit/ipynb/output/fixed/TA3814.xlsx using filter : Calc Office Open XML
# [OK] auto-filter -> /data/kjc1/mylit/ipynb/output/fixed/TA3814.xlsx
# [RUN] /data/kjc1/projects/#999.GeoMxmeta/pooled/IFTA_250121_NEW_except1patient.xlsx
# Warning: failed to launch javaldx - java may not function correctly
# convert /data/kjc1/projects/#999.GeoMxmeta/pooled/IFTA_250121_NEW_except1patient.xlsx -> /data/kjc1/mylit/ipynb/output/fixed/IFTA_250121_NEW_except1patient.xlsx using filter : Calc Office Open XML
# [OK] auto-filter -> /data/kjc1/mylit/ipynb/output/fixed/IFTA_250121_NEW_except1patient.xlsx
# [RUN] /data/kjc1/projects/#999.GeoMxmeta/pooled/250114_TCR add on_final.xlsx
# Warning: failed to launch javaldx - java may not function correctly
# convert /data/kjc1/projects/#999.GeoMxmeta/pooled/250114_TCR add on_final.xlsx -> /data/kjc1/mylit/ipynb/output/fixed/250114_TCR add on_final.xlsx using filter : Calc Office Open XML
# [OK] auto-filter -> /data/kjc1/mylit/ipynb/output/fixed/250114_TCR add on_final.xlsx
# [RUN] /data/kjc1/projects/#999.GeoMxmeta/pooled/20210315 analysis.xlsx
# Warning: failed to launch javaldx - java may not function correctly
# convert /data/kjc1/projects/#999.GeoMxmeta/pooled/20210315 analysis.xlsx -> /data/kjc1/mylit/ipynb/output/fixed/20210315 analysis.xlsx using filter : Calc Office Open XML
# [OK] auto-filter -> /data/kjc1/mylit/ipynb/output/fixed/20210315 analysis.xlsx
# [RUN] /data/kjc1/projects/#999.GeoMxmeta/pooled/IgAN_KMJ_BYJ_20221004.xlsx
# Warning: failed to launch javaldx - java may not function correctly
# convert /data/kjc1/projects/#999.GeoMxmeta/pooled/IgAN_KMJ_BYJ_20221004.xlsx -> /data/kjc1/mylit/ipynb/output/fixed/IgAN_KMJ_BYJ_20221004.xlsx using filter : Calc Office Open XML
# [OK] auto-filter -> /data/kjc1/mylit/ipynb/output/fixed/IgAN_KMJ_BYJ_20221004.xlsx
# [RUN] /data/kjc1/projects/#999.GeoMxmeta/pooled/IFTA_20241028.xlsx
# Warning: failed to launch javaldx - java may not function correctly
# convert /data/kjc1/projects/#999.GeoMxmeta/pooled/IFTA_20241028.xlsx -> /data/kjc1/mylit/ipynb/output/fixed/IFTA_20241028.xlsx using filter : Calc Office Open XML
# [OK] auto-filter -> /data/kjc1/mylit/ipynb/output/fixed/IFTA_20241028.xlsx
# [RUN] /data/kjc1/projects/#999.GeoMxmeta/pooled/Lupus Nephritis.xlsx
# Warning: failed to launch javaldx - java may not function correctly
# convert /data/kjc1/projects/#999.GeoMxmeta/pooled/Lupus Nephritis.xlsx -> /data/kjc1/mylit/ipynb/output/fixed/Lupus Nephritis.xlsx using filter : Calc Office Open XML
# [OK] auto-filter -> /data/kjc1/mylit/ipynb/output/fixed/Lupus Nephritis.xlsx
# [RUN] /data/kjc1/projects/#999.GeoMxmeta/pooled/CRC.xlsx
# Warning: failed to launch javaldx - java may not function correctly
# convert /data/kjc1/projects/#999.GeoMxmeta/pooled/CRC.xlsx -> /data/kjc1/mylit/ipynb/output/fixed/CRC.xlsx using filter : Calc Office Open XML
# [OK] auto-filter -> /data/kjc1/mylit/ipynb/output/fixed/CRC.xlsx
# [RUN] /data/kjc1/projects/#999.GeoMxmeta/pooled/20230615_LE_Rosa_1st.xlsx
# Warning: failed to launch javaldx - java may not function correctly
# convert /data/kjc1/projects/#999.GeoMxmeta/pooled/20230615_LE_Rosa_1st.xlsx -> /data/kjc1/mylit/ipynb/output/fixed/20230615_LE_Rosa_1st.xlsx using filter : Calc Office Open XML
# [OK] auto-filter -> /data/kjc1/mylit/ipynb/output/fixed/20230615_LE_Rosa_1st.xlsx
# [RUN] /data/kjc1/projects/#999.GeoMxmeta/pooled/MN_D1.E3.X1.C4.C3.C2.D4.xlsx
# Warning: failed to launch javaldx - java may not function correctly
# convert /data/kjc1/projects/#999.GeoMxmeta/pooled/MN_D1.E3.X1.C4.C3.C2.D4.xlsx -> /data/kjc1/mylit/ipynb/output/fixed/MN_D1.E3.X1.C4.C3.C2.D4.xlsx using filter : Calc Office Open XML
# [OK] auto-filter -> /data/kjc1/mylit/ipynb/output/fixed/MN_D1.E3.X1.C4.C3.C2.D4.xlsx
# [RUN] /data/kjc1/projects/#999.GeoMxmeta/pooled/MN_D1.E3.X1.C4.C3.C2.D4_.xlsx
# Warning: failed to launch javaldx - java may not function correctly
# convert /data/kjc1/projects/#999.GeoMxmeta/pooled/MN_D1.E3.X1.C4.C3.C2.D4_.xlsx -> /data/kjc1/mylit/ipynb/output/fixed/MN_D1.E3.X1.C4.C3.C2.D4_.xlsx using filter : Calc Office Open XML
# [OK] auto-filter -> /data/kjc1/mylit/ipynb/output/fixed/MN_D1.E3.X1.C4.C3.C2.D4_.xlsx
# [RUN] /data/kjc1/projects/#999.GeoMxmeta/pooled/SMC0408.xlsx
# Warning: failed to launch javaldx - java may not function correctly
# convert /data/kjc1/projects/#999.GeoMxmeta/pooled/SMC0408.xlsx -> /data/kjc1/mylit/ipynb/output/fixed/SMC0408.xlsx using filter : Calc Office Open XML
# [OK] auto-filter -> /data/kjc1/mylit/ipynb/output/fixed/SMC0408.xlsx
# [RUN] /data/kjc1/projects/#999.GeoMxmeta/pooled/H Chung_Thymus #1_240921.xlsx
# Warning: failed to launch javaldx - java may not function correctly
# convert /data/kjc1/projects/#999.GeoMxmeta/pooled/H Chung_Thymus #1_240921.xlsx -> /data/kjc1/mylit/ipynb/output/fixed/H Chung_Thymus #1_240921.xlsx using filter : Calc Office Open XML
# [OK] auto-filter -> /data/kjc1/mylit/ipynb/output/fixed/H Chung_Thymus #1_240921.xlsx
# [RUN] /data/kjc1/projects/#999.GeoMxmeta/pooled/HCC_VETC_HSH.xlsx
# Warning: failed to launch javaldx - java may not function correctly
# convert /data/kjc1/projects/#999.GeoMxmeta/pooled/HCC_VETC_HSH.xlsx -> /data/kjc1/mylit/ipynb/output/fixed/HCC_VETC_HSH.xlsx using filter : Calc Office Open XML
# [OK] auto-filter -> /data/kjc1/mylit/ipynb/output/fixed/HCC_VETC_HSH.xlsx
# [RUN] /data/kjc1/projects/#999.GeoMxmeta/pooled/HCC_NTvsTC_48_KDJ_real.xlsx
# Warning: failed to launch javaldx - java may not function correctly
# convert /data/kjc1/projects/#999.GeoMxmeta/pooled/HCC_NTvsTC_48_KDJ_real.xlsx -> /data/kjc1/mylit/ipynb/output/fixed/HCC_NTvsTC_48_KDJ_real.xlsx using filter : Calc Office Open XML
# [OK] auto-filter -> /data/kjc1/mylit/ipynb/output/fixed/HCC_NTvsTC_48_KDJ_real.xlsx
# [RUN] /data/kjc1/projects/#999.GeoMxmeta/pooled/HCC_NT_vs_TC_48_KMJ.xlsx
# Warning: failed to launch javaldx - java may not function correctly
# convert /data/kjc1/projects/#999.GeoMxmeta/pooled/HCC_NT_vs_TC_48_KMJ.xlsx -> /data/kjc1/mylit/ipynb/output/fixed/HCC_NT_vs_TC_48_KMJ.xlsx using filter : Calc Office Open XML
# [OK] auto-filter -> /data/kjc1/mylit/ipynb/output/fixed/HCC_NT_vs_TC_48_KMJ.xlsx
# [RUN] /data/kjc1/projects/#999.GeoMxmeta/pooled/SJ_HY geomx Thymus.xlsx
# Warning: failed to launch javaldx - java may not function correctly
# convert /data/kjc1/projects/#999.GeoMxmeta/pooled/SJ_HY geomx Thymus.xlsx -> /data/kjc1/mylit/ipynb/output/fixed/SJ_HY geomx Thymus.xlsx using filter : Calc Office Open XML
# [OK] auto-filter -> /data/kjc1/mylit/ipynb/output/fixed/SJ_HY geomx Thymus.xlsx
# [RUN] /data/kjc1/projects/#999.GeoMxmeta/pooled/syringoma re.xlsx
# Warning: failed to launch javaldx - java may not function correctly
# convert /data/kjc1/projects/#999.GeoMxmeta/pooled/syringoma re.xlsx -> /data/kjc1/mylit/ipynb/output/fixed/syringoma re.xlsx using filter : Calc Office Open XML
# [OK] auto-filter -> /data/kjc1/mylit/ipynb/output/fixed/syringoma re.xlsx
# [RUN] /data/kjc1/projects/#999.GeoMxmeta/pooled/thymus normal.xlsx
# Warning: failed to launch javaldx - java may not function correctly
# convert /data/kjc1/projects/#999.GeoMxmeta/pooled/thymus normal.xlsx -> /data/kjc1/mylit/ipynb/output/fixed/thymus normal.xlsx using filter : Calc Office Open XML
# [OK] auto-filter -> /data/kjc1/mylit/ipynb/output/fixed/thymus normal.xlsx
# [RUN] /data/kjc1/projects/#999.GeoMxmeta/pooled/thymus240401.xlsx
# Warning: failed to launch javaldx - java may not function correctly
# convert /data/kjc1/projects/#999.GeoMxmeta/pooled/thymus240401.xlsx -> /data/kjc1/mylit/ipynb/output/fixed/thymus240401.xlsx using filter : Calc Office Open XML
# [OK] auto-filter -> /data/kjc1/mylit/ipynb/output/fixed/thymus240401.xlsx
# Done. Output -> /data/kjc1/mylit/ipynb/output/fixed

# %% [markdown]
# ## Metadata Merger

# %% [markdown]
# ### ver2.
